# %%
import pandas as pd
import nltk.data
from os import listdir
from os.path import isfile, join
from nltk.util import bigrams 
from nltk.tokenize import TreebankWordTokenizer
sentence_tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
treebank_tokenizer = TreebankWordTokenizer()
stop_words = nltk.corpus.stopwords.words('english')
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

# %%
# load in each candidate data
bernie = pd.read_csv("Bernie_Sanders.csv")
biden = pd.read_csv("Joe_Biden.csv")
trump = pd.read_csv("Donald_Trump.csv")

# %%
bernie.head()
# Out:
#                                                title  \
# 0  A Sign of the Times? The Democratic Primary Ha...
# 1  Tops in Iowa, Under Attack At Every Turn: [Nat...
# 2  Gender and War Dominate Debate by 6 Democrats:...
# 3  Once Hawking Big-Ticket Ideas, Democrats Refoc...
# 4  Sanders Gets Endorsement Of Young Climate Grou...
#
#                                                 text           media  \
# 0  Hide highlightingFull TextTranslateUndo Transl...  New York Times
# 1  Hide highlightingFull TextTranslateUndo Transl...  New York Times
# 2  Hide highlightingFull TextTranslateUndo Transl...  New York Times
# 3  Hide highlightingFull TextTranslateUndo Transl...  New York Times
# 4  Hide highlightingFull TextTranslateUndo Transl...  New York Times
#
#    word_count  candidate_name
# 0      1122.0  Bernie Sanders
# 1      1995.0  Bernie Sanders
# 2      2154.0  Bernie Sanders
# 3      1892.0  Bernie Sanders
# 4      1005.0  Bernie Sanders

# %%
# separate by news outlet
# bernie
bernie_NYT = bernie.loc[bernie['media']=='New York Times']
bernie_TWP = bernie.loc[bernie['media']=='The Washington Post']
bernie_WSJ = bernie.loc[bernie['media']=='Wall Street Journal']

# %%
# biden
biden_NYT = biden.loc[biden['media']=='New York Times']
biden_TWP = biden.loc[biden['media']=='The Washington Post']
biden_WSJ = biden.loc[biden['media']=='Wall Street Journal']

# %%
# trump
trump_NYT = trump.loc[trump['media']=='New York Times']
trump_TWP = trump.loc[trump['media']=='The Washington Post']
trump_WSJ = trump.loc[trump['media']=='Wall Street Journal']

# %%
# merge each news outlet together
NYT = pd.concat([bernie_NYT, biden_NYT, trump_NYT], axis=0)
TWP = pd.concat([bernie_TWP, biden_TWP, trump_TWP], axis=0)
WSJ = pd.concat([bernie_WSJ, biden_WSJ, trump_WSJ], axis=0)

# %%
# extract text
bernie_text = bernie.iloc[:,1]

biden_text = biden.iloc[:,1]

trump_text = trump.iloc[:,1]

# %%
#extract text for each candidate each news company
bernie_NYT_text = bernie_NYT.iloc[:,1]
biden_NYT_text = biden_NYT.iloc[:,1]
trump_NYT_text = trump_NYT.iloc[:,1]

bernie_TWP_text = bernie_TWP.iloc[:,1]
biden_TWP_text = biden_TWP.iloc[:,1]
trump_TWP_text = trump_TWP.iloc[:,1]

bernie_WSJ_text = bernie_WSJ.iloc[:,1]
biden_WSJ_text = biden_WSJ.iloc[:,1]
trump_WSJ_text = trump_WSJ.iloc[:,1]

# %%
# extract text for each news outlet
NYT_text = NYT.iloc[:,1]
TWP_text = TWP.iloc[:,1]
WSJ_text = WSJ.iloc[:,1]

# %%
# take a look at what is actually in the text
bernie_text.head()
# Out:
# 0    Hide highlightingFull TextTranslateUndo Transl...
# 1    Hide highlightingFull TextTranslateUndo Transl...
# 2    Hide highlightingFull TextTranslateUndo Transl...
# 3    Hide highlightingFull TextTranslateUndo Transl...
# 4    Hide highlightingFull TextTranslateUndo Transl...
# Name: text, dtype: object

# %%
bernie_NYT_text.head()
# Out:
# 0    Hide highlightingFull TextTranslateUndo Transl...
# 1    Hide highlightingFull TextTranslateUndo Transl...
# 2    Hide highlightingFull TextTranslateUndo Transl...
# 3    Hide highlightingFull TextTranslateUndo Transl...
# 4    Hide highlightingFull TextTranslateUndo Transl...
# Name: text, dtype: object

# %%
# words I have found in the beggining & end of each text due to scraping
remove = ['hide',
 'highlightingfull',
 'texttranslateundo',
 'translation',
 'fromtotranslatetranslation',
 'progress',
 'missing',
 'key',
 'loadinganimation',
 'full',
 'text',
 'may',
 'take',
 'second',
 'translate',
 'larger',
 'document',
 'may',
 'take',
 'longer',
 'cancel',
 'overlayendturn',
 'search',
 'term',
 'navigationturn',
 'navigation',
 'jump',
 'first',
 'hit','article',
 'write',
 'julie',
 'bykowicz',
 'credit',
 'julie',
 'bykowicz',
 'word',
 'count',
 'lessyou',
 'requested',
 'machine',
 'selected',
 'content',
 'database',
 'functionality',
 'provided',
 'solely',
 'convenience',
 'way',
 'intended',
 'replace',
 'human',
 'show',
 'disclaimerneither',
 'proquest',
 'licensors',
 'make',
 'representation',
 'warranty',
 'respect',
 'automatically',
 'generated',
 'available',
 'retained',
 'system',
 'proquest',
 'licensors',
 'specifically',
 'disclaim',
 'express',
 'implied',
 'warranty',
 'including',
 'without',
 'limitation',
 'warranty',
 'availability',
 'accuracy',
 'timeliness',
 'completeness',
 'merchantability',
 'fitness',
 'particular',
 'purpose',
 'use',
 'subject',
 'use',
 'restriction',
 'contained',
 'electronic',
 'product',
 'license',
 'agreement',
 'using',
 'functionality',
 'agree',
 'forgo',
 'claim',
 'proquest',
 'licensors',
 'use',
 'functionality',
 'output',
 'derived',
 'disclaimer',
 'rather',
 'keep',
 'waiting',
 'translated',
 'paragraph',
 'click',
 'button',
 'want',
 'rest',
 'allcopyright',
 'dow',
 'jones',
 'company',
 'right',
 'reserved', 'said', 'ha', 'wa', 'biden', 'trump', 'sander', 'would','new', 'two', 'one']

# %%
# include removed words in stop words
stopwords = stop_words + remove

# %%
# function to pre-process data

def pre_process_text(text):

    # split into tokens
    #tokens = treebank_tokenizer.tokenize(text)
    
    # take out puncutation and numbers
    words = [word for word in text if word.isalpha()]
    
    # convert to lower case
    words_l = [word.lower() for word in words]
    
    # get lemmas
    lemmatized_words = [wordnet_lemmatizer.lemmatize(word) for word in words_l]
    
    # taking out stop_words + remove
    output = [w for w in lemmatized_words if w not in stopwords]
    
    # the later function assumes you are returning a list of terms
    return output

# %%
# create list of tokenized articles for each candidate

bernie_tokens = []
for news in bernie_text[:]:
    content = nltk.word_tokenize(news)
    bernie_tokens.append(pre_process_text(content))

biden_tokens = []
for news in biden_text[:]:
    content = nltk.word_tokenize(news)
    biden_tokens.append(pre_process_text(content))

trump_tokens = []
for news in trump_text[:]:
    content = nltk.word_tokenize(news)
    trump_tokens.append(pre_process_text(content))

# %%
# create list of tokenized articles for each candidate NYT

bernie_NYT_tokens = []
for news in bernie_NYT_text[:]:
    content = nltk.word_tokenize(news)
    bernie_NYT_tokens.append(pre_process_text(content))

biden_NYT_tokens = []
for news in biden_NYT_text[:]:
    content = nltk.word_tokenize(news)
    biden_NYT_tokens.append(pre_process_text(content))

trump_NYT_tokens = []
for news in trump_NYT_text[:]:
    content = nltk.word_tokenize(news)
    trump_NYT_tokens.append(pre_process_text(content))

# %%
# create list of tokenized articles for each candidate TWP

bernie_TWP_tokens = []
for news in bernie_TWP_text[:]:
    content = nltk.word_tokenize(news)
    bernie_TWP_tokens.append(pre_process_text(content))

biden_TWP_tokens = []
for news in biden_TWP_text[:]:
    content = nltk.word_tokenize(news)
    biden_TWP_tokens.append(pre_process_text(content))

trump_TWP_tokens = []
for news in trump_TWP_text[:]:
    content = nltk.word_tokenize(news)
    trump_TWP_tokens.append(pre_process_text(content))

# %%
# create list of tokenized articles for each candidate WSJ

bernie_WSJ_tokens = []
for news in bernie_WSJ_text[:]:
    content = nltk.word_tokenize(news)
    bernie_WSJ_tokens.append(pre_process_text(content))

biden_WSJ_tokens = []
for news in biden_WSJ_text[:]:
    content = nltk.word_tokenize(news)
    biden_WSJ_tokens.append(pre_process_text(content))

trump_WSJ_tokens = []
for news in trump_WSJ_text[:]:
    content = nltk.word_tokenize(news)
    trump_WSJ_tokens.append(pre_process_text(content))

# %%
# create list of tokenized articles for each news outlet

NYT_tokens = []
for news in NYT_text[:]:
    content = nltk.word_tokenize(news)
    NYT_tokens.append(pre_process_text(content))
    
TWP_tokens = []
for news in TWP_text[:]:
    content = nltk.word_tokenize(news)
    TWP_tokens.append(pre_process_text(content))
    
WSJ_tokens = []
for news in WSJ_text[:]:
    content = nltk.word_tokenize(news)
    WSJ_tokens.append(pre_process_text(content))

# %%
# check out list of token articles
bernie_tokens[0:5]
# Out:
# [['hitas',
#   'primary',
#   'race',
#   'becomes',
#   'battle',
#   'field',
#   'suddenly',
#   'seems',
#   'constricting',
#   'divisiveness',
#   'negative',
#   'attack',
#   'tagged',
#   'rival',
#   'nickname',
#   'like',
#   'sleepy',
#   'liddle',
#   'push',
#   'come',
#   'shove',
#   'democratic',
#   'primary',
#   'candidate',
#   'surrogate',
#   'descended',
#   'level',
#   'personal',
#   'animus',
#   'rare',
#   'era',
#   'president',
#   'monday',
#   'joseph',
#   'launched',
#   'digital',
#   'ad',
#   'south',
#   'carolina',
#   'saying',
#   'bernie',
#   'ca',
#   'trusted',
#   'weighing',
#   'primary',
#   'president',
#   'barack',
#   'pete',
#   'buttigieg',
#   'attacked',
#   'victory',
#   'nevada',
#   'mayor',
#   'bill',
#   'de',
#   'blasio',
#   'york',
#   'lectured',
#   'buttigieg',
#   'twitter',
#   'saying',
#   'smug',
#   'got',
#   'kicked',
#   'lest',
#   'last',
#   'week',
#   'democratic',
#   'debate',
#   'recede',
#   'history',
#   'five',
#   'day',
#   'ago',
#   'memorable',
#   'searing',
#   'moment',
#   'highly',
#   'personal',
#   'exchange',
#   'buttigieg',
#   'amy',
#   'klobuchar',
#   'dripped',
#   'contempt',
#   'klobuchar',
#   'saying',
#   'wish',
#   'everyone',
#   'perfect',
#   'pete',
#   'primary',
#   'race',
#   'becomes',
#   'battle',
#   'hunger',
#   'game',
#   'field',
#   'suddenly',
#   'seems',
#   'constricting',
#   'divisiveness',
#   'negative',
#   'attack',
#   'rising',
#   'commanding',
#   'win',
#   'nevada',
#   'earned',
#   'pledged',
#   'delegate',
#   'final',
#   'result',
#   'tallied',
#   'monday',
#   'taking',
#   'nine',
#   'buttigieg',
#   'three',
#   'triggered',
#   'alarm',
#   'among',
#   'democratic',
#   'official',
#   'voter',
#   'moderate',
#   'challenger',
#   'sought',
#   'vain',
#   'push',
#   'another',
#   'exit',
#   'consolidate',
#   'presidential',
#   'primary',
#   'certainly',
#   'share',
#   'negative',
#   'campaigning',
#   'much',
#   'intraparty',
#   'warfare',
#   'used',
#   'waged',
#   'behind',
#   'scene',
#   'oppo',
#   'dump',
#   'compromising',
#   'research',
#   'opponent',
#   'anonymous',
#   'criticism',
#   'newspaper',
#   'story',
#   'today',
#   'combination',
#   'social',
#   'medium',
#   'democratization',
#   'habit',
#   'lobbing',
#   'nasty',
#   'personal',
#   'attack',
#   'removed',
#   'filter',
#   'candidate',
#   'always',
#   'tried',
#   'stay',
#   'never',
#   'get',
#   'deeply',
#   'mud',
#   'joe',
#   'lockhart',
#   'former',
#   'press',
#   'secretary',
#   'former',
#   'president',
#   'bill',
#   'clinton',
#   'changed',
#   'modeled',
#   'idea',
#   'presidential',
#   'candidate',
#   'sharpest',
#   'attack',
#   'bottom',
#   'saturday',
#   'night',
#   'de',
#   'blasio',
#   'surrogate',
#   'tweeted',
#   'buttigieg',
#   'saying',
#   'dude',
#   'humility',
#   'lockhart',
#   'immediately',
#   'replied',
#   'york',
#   'mayor',
#   'care',
#   'think',
#   'four',
#   'five',
#   'year',
#   'ago',
#   'lockhart',
#   'interview',
#   'phone',
#   'reporter',
#   'weigh',
#   'mainstream',
#   'press',
#   'acting',
#   'gatekeeper',
#   'might',
#   'might',
#   'quoted',
#   'ability',
#   'people',
#   'platform',
#   'tweeted',
#   'got',
#   'back',
#   'dinner',
#   'david',
#   'pepper',
#   'chairman',
#   'ohio',
#   'democratic',
#   'party',
#   'lamented',
#   'last',
#   'debate',
#   'smashed',
#   'record',
#   'watched',
#   'democratic',
#   'presidential',
#   'debate',
#   'ever',
#   'intensely',
#   'negative',
#   'worry',
#   'everyone',
#   'looked',
#   'mad',
#   'every',
#   'person',
#   'stage',
#   'oppo',
#   'ready',
#   'go',
#   'delivers',
#   'ferocity',
#   'win',
#   'individual',
#   'skirmish',
#   'giving',
#   'away',
#   'bigger',
#   'picture',
#   'need',
#   'people',
#   'inspired',
#   'yes',
#   'many',
#   'example',
#   'democratic',
#   'rival',
#   'turning',
#   'negative',
#   'past',
#   'primary',
#   'race',
#   'strategist',
#   'hillary',
#   'clinton',
#   'dangled',
#   'obama',
#   'youthful',
#   'drug',
#   'clinton',
#   'accused',
#   'smearing',
#   'receiving',
#   'donation',
#   'rich',
#   'dig',
#   'feel',
#   'pretty',
#   'innocent',
#   'compared',
#   'year',
#   'burst',
#   'negativity',
#   'seems',
#   'triggered',
#   'prospect',
#   'staunchly',
#   'leftist',
#   'nominee',
#   'late',
#   'entry',
#   'michael',
#   'bloomberg',
#   'fierce',
#   'fight',
#   'moderate',
#   'candidate',
#   'ought',
#   'leading',
#   'sunday',
#   'night',
#   'praised',
#   'fidel',
#   'castro',
#   'cuba',
#   'literacy',
#   'program',
#   'minute',
#   'many',
#   'response',
#   'fellow',
#   'democrat',
#   'searing',
#   'congresswoman',
#   'florida',
#   'sizable',
#   'cuban',
#   'electorate',
#   'south',
#   'american',
#   'immigrant',
#   'member',
#   'congress',
#   'proudly',
#   'represents',
#   'thousand',
#   'cuban',
#   'american',
#   'find',
#   'senator',
#   'bernie',
#   'comment',
#   'castro',
#   'cuba',
#   'absolutely',
#   'unacceptable',
#   'representative',
#   'debbi',
#   'florida',
#   'congresswoman',
#   'amandi',
#   'pollster',
#   'political',
#   'consultant',
#   'south',
#   'florida',
#   'went',
#   'democrat',
#   'nominating',
#   'man',
#   'absolutely',
#   'realdonaldtrump',
#   'end',
#   'constitutional',
#   'republic',
#   'seven',
#   'democrat',
#   'set',
#   'appear',
#   'another',
#   'presidential',
#   'debate',
#   'tuesday',
#   'south',
#   'carolina',
#   'negativity',
#   'unlikely',
#   'let',
#   'buttigieg',
#   'previewed',
#   'continue',
#   'try',
#   'undermine',
#   'choice',
#   'monday',
#   'tweeted',
#   'minute',
#   'interview',
#   'disastrous',
#   'nominate',
#   'democratic',
#   'socialist',
#   'four',
#   'year',
#   'looking',
#   'horror',
#   'cozied',
#   'dictator',
#   'election',
#   'night',
#   'nevada',
#   'buttigieg',
#   'aggressive',
#   'taking',
#   'rival',
#   'belief',
#   'inflexible',
#   'ideological',
#   'revolution',
#   'leaf',
#   'democrat',
#   'mention',
#   'mr',
#   'bloomberg',
#   'former',
#   'york',
#   'mayor',
#   'also',
#   'highly',
#   'likely',
#   'broad',
#   'target',
#   'debate',
#   'last',
#   'week',
#   'elizabeth',
#   'warren',
#   'pushed',
#   'bloomberg',
#   'hard',
#   'derogatory',
#   'comment',
#   'made',
#   'woman',
#   'settlement',
#   'former',
#   'employee',
#   'kept',
#   'woman',
#   'discussing',
#   'incident',
#   'blowback',
#   'led',
#   'bloomberg',
#   'later',
#   'release',
#   'three',
#   'woman',
#   'nondisclosure',
#   'everyone',
#   'unhappy',
#   'fierce',
#   'primary',
#   'gov',
#   'terry',
#   'mcauliffe',
#   'virginia',
#   'entirely',
#   'reasonable',
#   'candidate',
#   'probing',
#   'another',
#   'vulnerability',
#   'senator',
#   'current',
#   'faced',
#   'true',
#   'sustained',
#   'scrutiny',
#   'either',
#   'run',
#   'president',
#   'mcauliffe',
#   'much',
#   'better',
#   'understand',
#   'electability',
#   'primary',
#   'know',
#   'facing',
#   'donald',
#   'smear',
#   'jesse',
#   'ferguson',
#   'democratic',
#   'strategist',
#   'glad',
#   'tenor',
#   'primary',
#   'reveals',
#   'steel',
#   'coming',
#   'showdown',
#   'general',
#   'election',
#   'thing',
#   'tell',
#   'people',
#   'agenda',
#   'another',
#   'people',
#   'hard',
#   'fight',
#   'candidate',
#   'starting',
#   'time',
#   'ferguson',
#   'worked',
#   'clinton',
#   'democrat',
#   'nominee',
#   'general',
#   'lead',
#   'u',
#   'battle',
#   'donald',
#   'continued',
#   'going',
#   'promote',
#   'someone',
#   'role',
#   'unless',
#   'proven',
#   'win',
#   'skirmish',
#   'photographsenator',
#   'bernie',
#   'former',
#   'vice',
#   'president',
#   'joseph',
#   'debate',
#   'last',
#   'week',
#   'la',
#   'vega',
#   'attacking',
#   'trustworthiness',
#   'south',
#   'carolina',
#   'primary',
#   'approach',
#   'photograph',
#   'erin',
#   'york',
#   'time',
#   'york',
#   'time',
#   'york',
#   'time',
#   'feb'],
#  ['hitin',
#   'contentious',
#   'debate',
#   'far',
#   'joseph',
#   'challenged',
#   'bernie',
#   'gun',
#   'regulation',
#   'amy',
#   'klobuchar',
#   'accused',
#   'pete',
#   'buttigieg',
#   'presenting',
#   'cool',
#   'newcomer',
#   'manchester',
#   'victor',
#   'iowa',
#   'caucus',
#   'senator',
#   'bernie',
#   'vermont',
#   'former',
#   'mayor',
#   'pete',
#   'buttigieg',
#   'south',
#   'bend',
#   'came',
#   'sharp',
#   'sustained',
#   'criticism',
#   'democratic',
#   'presidential',
#   'debate',
#   'friday',
#   'rival',
#   'tried',
#   'stop',
#   'momentum',
#   'assailing',
#   'idea',
#   'past',
#   'opposition',
#   'gun',
#   'control',
#   'targeting',
#   'buttigieg',
#   'thin',
#   'tie',
#   'big',
#   'contentious',
#   'debate',
#   'far',
#   'taking',
#   'place',
#   'four',
#   'day',
#   'hampshire',
#   'primary',
#   'iowa',
#   'charged',
#   'buttigieg',
#   'appeared',
#   'best',
#   'position',
#   'among',
#   'top',
#   'candidate',
#   'win',
#   'hampshire',
#   'perhaps',
#   'command',
#   'opponent',
#   'several',
#   'significant',
#   'advantage',
#   'showed',
#   'give',
#   'fight',
#   'buttigieg',
#   'especially',
#   'came',
#   'bruising',
#   'treatment',
#   'drawing',
#   'tough',
#   'challenge',
#   'every',
#   'candidate',
#   'onstage',
#   'record',
#   'mayor',
#   'failure',
#   'far',
#   'appeal',
#   'black',
#   'latino',
#   'vice',
#   'president',
#   'joseph',
#   'seeking',
#   'recover',
#   'limp',
#   'finish',
#   'iowa',
#   'raised',
#   'issue',
#   'buttigieg',
#   'lack',
#   'support',
#   'among',
#   'minority',
#   'opening',
#   'moment',
#   'debate',
#   'saying',
#   'buttigieg',
#   'shown',
#   'could',
#   'get',
#   'broad',
#   'scope',
#   'support',
#   'repeatedly',
#   'alluded',
#   'throughout',
#   'evening',
#   'base',
#   'among',
#   'especially',
#   'south',
#   'carolina',
#   'whose',
#   'primary',
#   'month',
#   'considered',
#   'political',
#   'firewall',
#   'flagging',
#   'campaign',
#   'doe',
#   'recover',
#   'buttigieg',
#   'target',
#   'also',
#   'warned',
#   'nominating',
#   'taint',
#   'democratic',
#   'candidate',
#   'label',
#   'socialism',
#   'blunt',
#   'attack',
#   'far',
#   'rebuked',
#   'opposed',
#   'gun',
#   'control',
#   'legislation',
#   'long',
#   'since',
#   'disavowed',
#   'stance',
#   'called',
#   'function',
#   'representing',
#   'rural',
#   'state',
#   'gun',
#   'issue',
#   'major',
#   'point',
#   'vulnerability',
#   'bid',
#   'democratic',
#   'nomination',
#   'significant',
#   'part',
#   'year',
#   'candidate',
#   'entered',
#   'race',
#   'main',
#   'divide',
#   'party',
#   'whether',
#   'enact',
#   'incremental',
#   'policy',
#   'step',
#   'pursue',
#   'transformational',
#   'change',
#   'vivid',
#   'display',
#   'throughout',
#   'night',
#   'question',
#   'approach',
#   'appealing',
#   'general',
#   'election',
#   'voter',
#   'major',
#   'candidate',
#   'senator',
#   'elizabeth',
#   'warren',
#   'massachusetts',
#   'amy',
#   'klobuchar',
#   'minnesota',
#   'debate',
#   'crucial',
#   'perhaps',
#   'final',
#   'opportunity',
#   'reassert',
#   'race',
#   'prevent',
#   'buttigieg',
#   'establishing',
#   'tight',
#   'grip',
#   'respective',
#   'wing',
#   'party',
#   'left',
#   'buttigieg',
#   'closer',
#   'political',
#   'despite',
#   'high',
#   'stake',
#   'standout',
#   'moment',
#   'sort',
#   'transformed',
#   'past',
#   'primary',
#   'aggressive',
#   'seven',
#   'candidate',
#   'stage',
#   'klobuchar',
#   'polling',
#   'well',
#   'behind',
#   'hampshire',
#   'benefited',
#   'iowa',
#   'moderate',
#   'challenger',
#   'slicing',
#   'share',
#   'voter',
#   'enjoyed',
#   'speaking',
#   'time',
#   'friday',
#   'used',
#   'much',
#   'reprise',
#   'progressive',
#   'argument',
#   'rival',
#   'often',
#   'assailed',
#   'another',
#   'warren',
#   'declined',
#   'multiple',
#   'opportunity',
#   'attack',
#   'however',
#   'taken',
#   'heat',
#   'presidential',
#   'debate',
#   'buttigieg',
#   'apparently',
#   'joint',
#   'winner',
#   'iowa',
#   'caucus',
#   'debate',
#   'friday',
#   'far',
#   'strenuous',
#   'test',
#   'klobuchar',
#   'reprising',
#   'familiar',
#   'role',
#   'buttigieg',
#   'sternest',
#   'critic',
#   'presenting',
#   'cool',
#   'newcomer',
#   'dismissing',
#   'value',
#   'government',
#   'experience',
#   'easy',
#   'go',
#   'washington',
#   'popular',
#   'thing',
#   'much',
#   'harder',
#   'lead',
#   'much',
#   'harder',
#   'difficult',
#   'klobuchar',
#   'added',
#   'got',
#   'newcomer',
#   'white',
#   'house',
#   'look',
#   'got',
#   'u',
#   'candidate',
#   'go',
#   'buttigieg',
#   'former',
#   'mayor',
#   'repeatedly',
#   'deflected',
#   'moderator',
#   'question',
#   'racial',
#   'disparity',
#   'drug',
#   'arrest',
#   'south',
#   'bend',
#   'police',
#   'warren',
#   'flatly',
#   'buttigieg',
#   'given',
#   'substantial',
#   'answer',
#   'fact',
#   'took',
#   'buttigieg',
#   'despite',
#   'largely',
#   'ignored',
#   'previous',
#   'debate',
#   'buttigieg',
#   'attacked',
#   'rival',
#   'signature',
#   'health',
#   'care',
#   'proposal',
#   'known',
#   'medicare',
#   'swiped',
#   'buttigieg',
#   'close',
#   'tie',
#   'big',
#   'money',
#   'interest',
#   'unlike',
#   'campaign',
#   'billionaire',
#   'pete',
#   'contributing',
#   'campaign',
#   'even',
#   'andrew',
#   'yang',
#   'former',
#   'tech',
#   'entrepreneur',
#   'rarely',
#   'used',
#   'debate',
#   'appearance',
#   'target',
#   'rival',
#   'saw',
#   'opportunity',
#   'buttigieg',
#   'pete',
#   'fundamentally',
#   'lesson',
#   'donald',
#   'victory',
#   'yang',
#   'buttigieg',
#   'denounced',
#   'presidency',
#   'donald',
#   'cause',
#   'problem',
#   'making',
#   'mistake',
#   'act',
#   'like',
#   'like',
#   'moment',
#   'attack',
#   'buttigieg',
#   'gave',
#   'ground',
#   'arguing',
#   'determinedly',
#   'distinctive',
#   'approach',
#   'race',
#   'batted',
#   'away',
#   'skepticism',
#   'lack',
#   'service',
#   'highest',
#   'level',
#   'government',
#   'rejected',
#   'demand',
#   'purity',
#   'political',
#   'campaign',
#   'coming',
#   'eventual',
#   'democratic',
#   'nominee',
#   'immense',
#   'war',
#   'chest',
#   'buttigieg',
#   'arguing',
#   'need',
#   'go',
#   'fight',
#   'everything',
#   'got',
#   'sign',
#   'confidence',
#   'positioning',
#   'washington',
#   'outsider',
#   'buttigieg',
#   'conceded',
#   'point',
#   'lack',
#   'traditional',
#   'qualification',
#   'presidency',
#   'seeming',
#   'imply',
#   'voter',
#   'looking',
#   'candidate',
#   'profile',
#   'already',
#   'option',
#   'mr',
#   'freely',
#   'admit',
#   'looking',
#   'person',
#   'year',
#   'washington',
#   'establishment',
#   'experience',
#   'belt',
#   'buttigieg',
#   'got',
#   'candidate',
#   'course',
#   'countered',
#   'criticism',
#   'klobuchar',
#   'accused',
#   'minimizing',
#   'party',
#   'work',
#   'washington',
#   'respectfully',
#   'relegating',
#   'accomplishment',
#   'past',
#   'achievement',
#   'phenomenally',
#   'important',
#   'met',
#   'moment',
#   'buttigieg',
#   'meet',
#   'moment',
#   'moment',
#   'different',
#   'flurry',
#   'attack',
#   'reprisal',
#   'unsurprising',
#   'close',
#   'primary',
#   'poll',
#   'showing',
#   'iowa',
#   'candidate',
#   'also',
#   'leading',
#   'hampshire',
#   'striking',
#   'though',
#   'finishing',
#   'distant',
#   'third',
#   'iowa',
#   'warren',
#   'recited',
#   'familiar',
#   'attack',
#   'corruption',
#   'largely',
#   'shied',
#   'away',
#   'confronting',
#   'rival',
#   'even',
#   'given',
#   'chance',
#   'buttigieg',
#   'offered',
#   'glancing',
#   'critique',
#   'returning',
#   'broader',
#   'debate',
#   'came',
#   'moment',
#   'tumult',
#   'anxiety',
#   'democrat',
#   'whose',
#   'leadoff',
#   'contest',
#   'iowa',
#   'monday',
#   'turned',
#   'fiasco',
#   'technical',
#   'breakdown',
#   'stalled',
#   'fumbled',
#   'accusation',
#   'electoral',
#   'illegitimacy',
#   'multiple',
#   'presidential',
#   'campaign',
#   'friday',
#   'afternoon',
#   'buttigieg',
#   'claimed',
#   'victory',
#   'iowa',
#   'different',
#   'ground',
#   'brandishing',
#   'lead',
#   'popular',
#   'vote',
#   'buttigieg',
#   'staking',
#   'hairbreadth',
#   'lead',
#   'state',
#   'delegate',
#   'traditional',
#   'metric',
#   'judging',
#   'winner',
#   'caucus',
#   'answer',
#   'night',
#   'conceded',
#   'political',
#   'current',
#   'hampshire',
#   'primary',
#   'tuesday',
#   'tried',
#   'set',
#   'high',
#   'expectation',
#   'captured',
#   'state',
#   'easily',
#   'took',
#   'iowa',
#   'probably',
#   'adding',
#   'bernie',
#   'point',
#   'last',
#   'time',
#   'discussion',
#   'electability',
#   'confined',
#   'buttigieg',
#   'warren',
#   'hammering',
#   'theme',
#   'come',
#   'define',
#   'campaign',
#   'argued',
#   'democrat',
#   'could',
#   'unite',
#   'party',
#   'win',
#   'crossover',
#   'support',
#   'general',
#   'election',
#   'campaigning',
#   'corruption',
#   'bring',
#   'independent',
#   'republican',
#   'warren',
#   'hate',
#   'corruption',
#   'well',
#   'tom',
#   'steyer',
#   'wealthy',
#   'investor',
#   'party',
#   'nominee',
#   'able',
#   'win',
#   'support',
#   'minority',
#   'voter',
#   'feat',
#   'noted',
#   'buttigieg',
#   'yet',
#   'managed',
#   'contrast',
#   'steyer',
#   'added',
#   'awkwardly',
#   'clinical',
#   'turn',
#   'phrase',
#   'recent',
#   'poll',
#   'showed',
#   'percent',
#   'black',
#   'south',
#   'carolina',
#   'supporting',
#   'searing',
#   'exchange',
#   'involved',
#   'record',
#   'gun',
#   'regulation',
#   'defending',
#   'criticism',
#   'noted',
#   'poor',
#   'rating',
#   'national',
#   'rifle',
#   'association',
#   'vote',
#   'past',
#   'owed',
#   'part',
#   'representing',
#   'state',
#   'tradition',
#   'represented',
#   'perspective',
#   'world',
#   'changed',
#   'sensing',
#   'opening',
#   'noted',
#   'represented',
#   'gun',
#   'owner',
#   'delaware',
#   'still',
#   'pushed',
#   'gun',
#   'control',
#   'legislation',
#   'senator',
#   'pushing',
#   'brady',
#   'background',
#   'check',
#   'bernie',
#   'voted',
#   'five',
#   'time',
#   'house',
#   'former',
#   'vice',
#   'president',
#   'went',
#   'even',
#   'alluding',
#   'wave',
#   'gun',
#   'violence',
#   'bernie',
#   'representing',
#   'constituency',
#   'lot',
#   'people',
#   'came',
#   'around',
#   'citing',
#   'getting',
#   'killed',
#   'thousand',
#   'period',
#   'candidate',
#   'attacked',
#   'counterattacked',
#   'another',
#   'gusto',
#   'saved',
#   'searing',
#   'critique',
#   'president',
#   'played',
#   'live',
#   'audience',
#   'campus',
#   'anselm',
#   'college',
#   'urging',
#   'everyone',
#   'stand',
#   'applaud',
#   'alexander',
#   'vindman',
#   'decorated',
#   'iraq',
#   'war',
#   'veteran',
#   'national',
#   'security',
#   'council',
#   'testified',
#   'impeachment',
#   'hearing',
#   'marched',
#   'white',
#   'house',
#   'friday',
#   'stand',
#   'clap',
#   'vindman',
#   'series',
#   'exchange',
#   'foreign',
#   'policy',
#   'candidate',
#   'expressed',
#   'overlapping',
#   'skepticism',
#   'continuing',
#   'american',
#   'military',
#   'involvement',
#   'iraq',
#   'afghanistan',
#   'warren',
#   'departing',
#   'usual',
#   'focus',
#   'domestic',
#   'policy',
#   'believed',
#   'time',
#   'stop',
#   'endless',
#   'war',
#   'afghanistan',
#   'noting',
#   'naming',
#   'name',
#   'candidate',
#   'willing',
#   'leave',
#   'troop',
#   'year',
#   'come',
#   'wait',
#   'five',
#   'year',
#   'year',
#   'turn',
#   'corner',
#   'mr',
#   'faced',
#   'criticism',
#   'number',
#   'time',
#   'buttigieg',
#   'friday',
#   'night',
#   'supported',
#   'invasion',
#   'iraq',
#   'time',
#   'debate',
#   'disagreed',
#   'obama',
#   'administration',
#   'approach',
#   'afghanistan',
#   'totally',
#   'opposed',
#   'whole',
#   'notion',
#   'afghanistan',
#   'adding',
#   'still',
#   'believed',
#   'possible',
#   'stop',
#   'attack',
#   'region',
#   'targeting',
#   'united',
#   'sweeping',
#   'expression',
#   'skepticism',
#   'military',
#   'engagement',
#   'overseas',
#   'came',
#   'stood',
#   'criticism',
#   'american',
#   'strike',
#   'last',
#   'month',
#   'killed',
#   'qassim',
#   'suleimani',
#   'iranian',
#   'military',
#   'commander',
#   'senator',
#   'characterized',
#   'assassination',
#   'go',
#   'around',
#   'saying',
#   'bad',
#   'guy',
#   'going',
#   'assassinate',
#   'predicting',
#   'lead',
#   'international',
#   'anarchy',
#   'photographfrom',
#   'left',
#   'pete',
#   'buttigieg',
#   'bernie',
#   'joseph',
#   'elizabeth',
#   'warren',
#   'amy',
#   'klobuchar',
#   'tom',
#   'steyer',
#   'start',
#   'friday',
#   'night',
#   'debate',
#   'photograph',
#   'elizabeth',
#   'frantz',
#   'york',
#   'time',
#   'supporter',
#   'warren',
#   'left',
#   'watched',
#   'debate',
#   'great',
#   'north',
#   'aleworks',
#   'manchester',
#   'fan',
#   'buttigieg',
#   'gathered',
#   'breezeway',
#   'pub',
#   'photograph',
#   'ruth',
#   'york',
#   'time',
#   'alyssa',
#   'schukar',
#   'york',
#   'time',
#   'york',
#   'time',
#   'feb'],
#  ['hitthe',
#   'rift',
#   'bernie',
#   'elizabeth',
#   'warren',
#   'electability',
#   'rose',
#   'surface',
#   'democratic',
#   'debate',
#   'candidate',
#   'also',
#   'sparred',
#   'stance',
#   'moines',
#   'democratic',
#   'presidential',
#   'candidate',
#   'clashed',
#   'starkly',
#   'personal',
#   'tuesday',
#   'best',
#   'chance',
#   'defeat',
#   'president',
#   'senator',
#   'elizabeth',
#   'warren',
#   'sought',
#   'campaign',
#   'last',
#   'debate',
#   'iowa',
#   'caucus',
#   'highlighting',
#   'electoral',
#   'success',
#   'female',
#   'candidate',
#   'moderator',
#   'warren',
#   'senator',
#   'bernie',
#   'continued',
#   'fraught',
#   'whether',
#   'woman',
#   'could',
#   'elected',
#   'president',
#   'issue',
#   'recent',
#   'day',
#   'caused',
#   'serious',
#   'breach',
#   'relationship',
#   'day',
#   'confirmed',
#   'report',
#   'told',
#   'private',
#   'meeting',
#   'think',
#   'woman',
#   'could',
#   'defeat',
#   'warren',
#   'trumpeted',
#   'senate',
#   'victory',
#   'incumbent',
#   'republican',
#   'gestured',
#   'debate',
#   'stage',
#   'toward',
#   'four',
#   'male',
#   'candidate',
#   'collectively',
#   'lost',
#   'election',
#   'acknowledging',
#   'female',
#   'candidate',
#   'present',
#   'senator',
#   'amy',
#   'klobuchar',
#   'people',
#   'stage',
#   'every',
#   'single',
#   'election',
#   'woman',
#   'amy',
#   'person',
#   'stage',
#   'beaten',
#   'incumbent',
#   'republican',
#   'past',
#   'year',
#   'mr',
#   'warren',
#   'top',
#   'rival',
#   'progressive',
#   'support',
#   'flatly',
#   'denied',
#   'made',
#   'comment',
#   'lawmaker',
#   'met',
#   'aide',
#   'incomprehensible',
#   'think',
#   'woman',
#   'could',
#   'president',
#   'united',
#   'state',
#   'noting',
#   'hillary',
#   'clinton',
#   'popular',
#   'vote',
#   'general',
#   'le',
#   'three',
#   'week',
#   'iowan',
#   'vote',
#   'democrat',
#   'disagreed',
#   'international',
#   'affair',
#   'keeping',
#   'troop',
#   'middle',
#   'east',
#   'whether',
#   'support',
#   'trade',
#   'deal',
#   'north',
#   'america',
#   'aggressively',
#   'tackle',
#   'climate',
#   'change',
#   'yet',
#   'health',
#   'care',
#   'issue',
#   'animating',
#   'much',
#   'evening',
#   'question',
#   'shaped',
#   'primary',
#   'race',
#   'past',
#   'year',
#   'formidable',
#   'contender',
#   'contest',
#   'increasingly',
#   'revolved',
#   'around',
#   'question',
#   'electability',
#   'matter',
#   'become',
#   'urgent',
#   'week',
#   'since',
#   'hostility',
#   'increased',
#   'united',
#   'state',
#   'tehran',
#   'killing',
#   'qassim',
#   'suleimani',
#   'powerful',
#   'iranian',
#   'commander',
#   'much',
#   'tuesday',
#   'debate',
#   'featured',
#   'six',
#   'remaining',
#   'candidate',
#   'touched',
#   'national',
#   'security',
#   'democrat',
#   'excoriated',
#   'urged',
#   'caution',
#   'middle',
#   'east',
#   'laid',
#   'mantle',
#   'best',
#   'potential',
#   'commander',
#   'vice',
#   'president',
#   'joseph',
#   'came',
#   'far',
#   'le',
#   'scrutiny',
#   'standing',
#   'national',
#   'might',
#   'merited',
#   'final',
#   'debate',
#   'voting',
#   'begin',
#   'iowa',
#   'notable',
#   'pete',
#   'buttigieg',
#   'former',
#   'mayor',
#   'south',
#   'bend',
#   'slipped',
#   'iowa',
#   'seemed',
#   'satisfied',
#   'case',
#   'sharply',
#   'criticizing',
#   'top',
#   'poll',
#   'iowa',
#   'democratic',
#   'voter',
#   'roughly',
#   'split',
#   'four',
#   'top',
#   'candidate',
#   'vermont',
#   'warren',
#   'massachusetts',
#   'criticized',
#   'cost',
#   'plan',
#   'warren',
#   'many',
#   'people',
#   'turned',
#   'buttigieg',
#   'scope',
#   'ambition',
#   'went',
#   'long',
#   'stretch',
#   'tuesday',
#   'receiving',
#   'scant',
#   'debate',
#   'unfolded',
#   'extraordinarily',
#   'volatile',
#   'moment',
#   'american',
#   'politics',
#   'impeachment',
#   'looming',
#   'escalated',
#   'tension',
#   'iran',
#   'yet',
#   'befitting',
#   'setting',
#   'stake',
#   'debate',
#   'multiple',
#   'candidate',
#   'warren',
#   'buttigieg',
#   'klobuchar',
#   'eager',
#   'invoke',
#   'iowa',
#   'story',
#   'specific',
#   'iowan',
#   'met',
#   'along',
#   'campaign',
#   'trail',
#   'tailoring',
#   'pitch',
#   'crucial',
#   'contretemps',
#   'warren',
#   'memorable',
#   'moment',
#   'caucus',
#   'remarkable',
#   'exchange',
#   'senator',
#   'part',
#   'friend',
#   'labored',
#   'abide',
#   'de',
#   'facto',
#   'nonaggression',
#   'pact',
#   'past',
#   'year',
#   'important',
#   'also',
#   'crystallized',
#   'competing',
#   'case',
#   'leading',
#   'democratic',
#   'contender',
#   'making',
#   'best',
#   'positioned',
#   'defeat',
#   'warren',
#   'bernie',
#   'friend',
#   'try',
#   'fight',
#   'bernie',
#   'flashed',
#   'smile',
#   'noted',
#   'like',
#   'warren',
#   'defeated',
#   'incumbent',
#   'republican',
#   'set',
#   'record',
#   'straight',
#   'defeated',
#   'incumbent',
#   'republican',
#   'running',
#   'congress',
#   'warren',
#   'pointed',
#   'year',
#   'facing',
#   'doubt',
#   'chance',
#   'defeat',
#   'pointed',
#   'john',
#   'kennedy',
#   'addressed',
#   'question',
#   'catholicism',
#   'recently',
#   'barack',
#   'obama',
#   'overcome',
#   'doubt',
#   'could',
#   'win',
#   'presidency',
#   'black',
#   'time',
#   'warren',
#   'democratic',
#   'party',
#   'stepped',
#   'yes',
#   'unusual',
#   'closing',
#   'argument',
#   'iowa',
#   'candidate',
#   'rose',
#   'contention',
#   'basis',
#   'policy',
#   'proposal',
#   'reflected',
#   'urgency',
#   'facing',
#   'reverse',
#   'decline',
#   'state',
#   'led',
#   'poll',
#   'last',
#   'part',
#   'seem',
#   'rattled',
#   'confrontation',
#   'least',
#   'forum',
#   'immediate',
#   'aftermath',
#   'debate',
#   'cnn',
#   'camera',
#   'captured',
#   'warren',
#   'appearing',
#   'refuse',
#   'shake',
#   'hand',
#   'senator',
#   'engaged',
#   'seemed',
#   'pointed',
#   'steyer',
#   'california',
#   'billionaire',
#   'standing',
#   'nearby',
#   'exchange',
#   'later',
#   'spin',
#   'room',
#   'whatever',
#   'going',
#   'trying',
#   'get',
#   'fast',
#   'possible',
#   'debate',
#   'used',
#   'exchange',
#   'warren',
#   'case',
#   'electable',
#   'candidate',
#   'could',
#   'lure',
#   'stream',
#   'voter',
#   'poll',
#   'real',
#   'question',
#   'beat',
#   'beat',
#   'campaign',
#   'energy',
#   'excitement',
#   'campaign',
#   'far',
#   'largest',
#   'voter',
#   'turnout',
#   'history',
#   'mr',
#   'placed',
#   'polling',
#   'strength',
#   'center',
#   'candidacy',
#   'television',
#   'ad',
#   'timed',
#   'tuesday',
#   'debate',
#   'emphatic',
#   'best',
#   'equipped',
#   'win',
#   'general',
#   'election',
#   'real',
#   'issue',
#   'bring',
#   'whole',
#   'party',
#   'together',
#   'citing',
#   'endorsement',
#   'variety',
#   'democrat',
#   'many',
#   'racial',
#   'minority',
#   'broadest',
#   'coalition',
#   'anyone',
#   'running',
#   'later',
#   'alluding',
#   'attempt',
#   'press',
#   'ukrainian',
#   'investigate',
#   'work',
#   'son',
#   'ukraine',
#   'president',
#   'taken',
#   'klobuchar',
#   'cited',
#   'success',
#   'appealing',
#   'range',
#   'voter',
#   'home',
#   'state',
#   'minnesota',
#   'even',
#   'boasted',
#   'every',
#   'republican',
#   'opponent',
#   'left',
#   'politics',
#   'since',
#   'lost',
#   'think',
#   'sound',
#   'pretty',
#   'good',
#   'president',
#   'klobuchar',
#   'struggled',
#   'momentarily',
#   'sought',
#   'highlight',
#   'success',
#   'midwestern',
#   'democratic',
#   'woman',
#   'forgot',
#   'name',
#   'gov',
#   'laura',
#   'kelly',
#   'kansa',
#   'receiving',
#   'cue',
#   'kansa',
#   'woman',
#   'governor',
#   'beat',
#   'kris',
#   'kobach',
#   'began',
#   'name',
#   'um',
#   'proud',
#   'know',
#   'name',
#   'uh',
#   'governor',
#   'kelly',
#   'thank',
#   'mr',
#   'steyer',
#   'whose',
#   'television',
#   'ad',
#   'blanketed',
#   'iowa',
#   'state',
#   'economic',
#   'experience',
#   'position',
#   'well',
#   'businessman',
#   'turned',
#   'president',
#   'whoever',
#   'going',
#   'beat',
#   'donald',
#   'going',
#   'beat',
#   'economy',
#   'experience',
#   'expertise',
#   'fake',
#   'fraud',
#   'long',
#   'debate',
#   'responded',
#   'twitter',
#   'steyer',
#   'running',
#   'low',
#   'cash',
#   'nobody',
#   'know',
#   'made',
#   'money',
#   'coal',
#   'funny',
#   'rare',
#   'policy',
#   'split',
#   'warren',
#   'disagreed',
#   'north',
#   'american',
#   'trade',
#   'deal',
#   'trying',
#   'push',
#   'congress',
#   'worth',
#   'supporting',
#   'even',
#   'made',
#   'modest',
#   'improvement',
#   'much',
#   'better',
#   'trade',
#   'deal',
#   'warren',
#   'however',
#   'reason',
#   'support',
#   'farmer',
#   'iowa',
#   'hurting',
#   'example',
#   'warren',
#   'sought',
#   'position',
#   'progressive',
#   'willing',
#   'get',
#   'thing',
#   'done',
#   'candidate',
#   'clashed',
#   'debate',
#   'health',
#   'care',
#   'pressed',
#   'moderator',
#   'cost',
#   'medicare',
#   'package',
#   'unlike',
#   'warren',
#   'proposal',
#   'cost',
#   'revealed',
#   'tax',
#   'increase',
#   'pay',
#   'warren',
#   'found',
#   'defensive',
#   'embrace',
#   'medicare',
#   'recent',
#   'month',
#   'pitched',
#   'plan',
#   'expansive',
#   'offered',
#   'klobuchar',
#   'mr',
#   'buttigieg',
#   'kick',
#   'million',
#   'american',
#   'health',
#   'insurance',
#   'klobuchar',
#   'warren',
#   'point',
#   'true',
#   'plan',
#   'proposing',
#   'small',
#   'buttigieg',
#   'another',
#   'suggesting',
#   'warren',
#   'approach',
#   'turn',
#   'many',
#   'voter',
#   'got',
#   'move',
#   'past',
#   'washington',
#   'mentality',
#   'suggests',
#   'bigness',
#   'plan',
#   'consists',
#   'many',
#   'trillion',
#   'dollar',
#   'put',
#   'treasury',
#   'boldness',
#   'plan',
#   'consists',
#   'many',
#   'american',
#   'alienate',
#   'buttigieg',
#   'buttigieg',
#   'asked',
#   'directly',
#   'lack',
#   'support',
#   'among',
#   'black',
#   'voter',
#   'need',
#   'activate',
#   'win',
#   'nomination',
#   'also',
#   'potential',
#   'general',
#   'election',
#   'buttigieg',
#   'know',
#   'best',
#   'south',
#   'bend',
#   'support',
#   'cited',
#   'backer',
#   'iowa',
#   'noted',
#   'campaign',
#   'member',
#   'congressional',
#   'black',
#   'opportunity',
#   'start',
#   'emphasize',
#   'pacifist',
#   'credential',
#   'debate',
#   'opened',
#   'question',
#   'heightened',
#   'tension',
#   'iran',
#   'best',
#   'positioned',
#   'serve',
#   'commander',
#   'chief',
#   'immediately',
#   'seized',
#   'opportunity',
#   'trumpet',
#   'past',
#   'opposition',
#   'war',
#   'iraq',
#   'voted',
#   'war',
#   'helped',
#   'lead',
#   'effort',
#   'war',
#   'warned',
#   'iraq',
#   'vietnam',
#   'war',
#   'based',
#   'lie',
#   'fear',
#   'much',
#   'president',
#   'lying',
#   'could',
#   'drag',
#   'u',
#   'war',
#   'even',
#   'worse',
#   'war',
#   'iraq',
#   'drew',
#   'distinction',
#   'supported',
#   'iraq',
#   'war',
#   'resolution',
#   'senate',
#   'joe',
#   'listened',
#   'dick',
#   'cheney',
#   'george',
#   'bush',
#   'rumsfeld',
#   'say',
#   'thought',
#   'lying',
#   'joe',
#   'saw',
#   'mr',
#   'regretted',
#   'vote',
#   'war',
#   'mistake',
#   'acknowledge',
#   'noting',
#   'vice',
#   'president',
#   'brought',
#   'thousand',
#   'troop',
#   'home',
#   'middle',
#   'race',
#   'remains',
#   'extremely',
#   'fluid',
#   'large',
#   'part',
#   'electorate',
#   'grab',
#   'contest',
#   'many',
#   'campaign',
#   'believe',
#   'produce',
#   'turnout',
#   'de',
#   'moines',
#   'poll',
#   'last',
#   'week',
#   'indicated',
#   'percent',
#   'caucusgoers',
#   'could',
#   'still',
#   'persuaded',
#   'support',
#   'different',
#   'final',
#   'twist',
#   'potential',
#   'affect',
#   'race',
#   'iowa',
#   'four',
#   'candidate',
#   'deliberating',
#   'fate',
#   'confronting',
#   'looming',
#   'challenge',
#   'mount',
#   'successful',
#   'iowa',
#   'campaign',
#   'duty',
#   'congress',
#   'require',
#   'senator',
#   'likely',
#   'capitol',
#   'six',
#   'day',
#   'week',
#   'impeachment',
#   'trial',
#   'unable',
#   'final',
#   'appeal',
#   'iowa',
#   'voter',
#   'person',
#   'frequently',
#   'mr',
#   'buttigieg',
#   'thing',
#   'warren',
#   'important',
#   'politics',
#   'photographfrom',
#   'left',
#   'tom',
#   'steyer',
#   'elizabeth',
#   'warren',
#   'joseph',
#   'bernie',
#   'pete',
#   'buttigieg',
#   'amy',
#   'klobuchar',
#   'tuesday',
#   'night',
#   'photograph',
#   'tamir',
#   'kalifa',
#   'york',
#   'time',
#   'photo',
#   'six',
#   'democrat',
#   'took',
#   'stage',
#   'tuesday',
#   'final',
#   'debate',
#   'iowa',
#   'caucus',
#   'large',
#   'part',
#   'electorate',
#   'remains',
#   'grab',
#   'contest',
#   'could',
#   'produce',
#   'turnout',
#   'elizabeth',
#   'warren',
#   'bernie',
#   'debate',
#   'exchange',
#   'electability',
#   'highlighted',
#   'question',
#   'many',
#   'voter',
#   'photograph',
#   'tamir',
#   'kalifa',
#   'york',
#   'time',
#   'york',
#   'time',
#   'jan'],
#  ['hitwith',
#   'iowa',
#   'caucus',
#   'set',
#   'kick',
#   'primary',
#   'season',
#   'monday',
#   'night',
#   'democratic',
#   'race',
#   'began',
#   'contest',
#   'idea',
#   'ideology',
#   'given',
#   'fixation',
#   'city',
#   'iowa',
#   'long',
#   'campaign',
#   'ideological',
#   'clash',
#   'policy',
#   'debate',
#   'talk',
#   'grand',
#   'reckoning',
#   'direction',
#   'democratic',
#   'party',
#   'presidential',
#   'primary',
#   'starting',
#   'monday',
#   'shaped',
#   'le',
#   'lofty',
#   'increasingly',
#   'urgent',
#   'matter',
#   'determining',
#   'best',
#   'candidate',
#   'defeat',
#   'incumbent',
#   'already',
#   'proved',
#   'political',
#   'republican',
#   'ready',
#   'acquit',
#   'president',
#   'impeachment',
#   'charge',
#   'next',
#   'week',
#   'nation',
#   'political',
#   'table',
#   'set',
#   'congress',
#   'remove',
#   'office',
#   'despite',
#   'wish',
#   'many',
#   'liberal',
#   'leaving',
#   'fate',
#   'november',
#   'general',
#   'election',
#   'candidate',
#   'nominated',
#   'democrat',
#   'coming',
#   'liberal',
#   'left',
#   'moderate',
#   'middle',
#   'major',
#   'presidential',
#   'contender',
#   'honing',
#   'recalibrating',
#   'final',
#   'appeal',
#   'iowa',
#   'caucus',
#   'case',
#   'represent',
#   'party',
#   'best',
#   'chance',
#   'overcome',
#   'operation',
#   'win',
#   'back',
#   'white',
#   'house',
#   'impeachment',
#   'rarely',
#   'come',
#   'democratic',
#   'campaign',
#   'trail',
#   'imperative',
#   'beating',
#   'come',
#   'outweigh',
#   'consideration',
#   'many',
#   'voter',
#   'extraordinary',
#   'turn',
#   'event',
#   'party',
#   'spent',
#   'last',
#   'year',
#   'sparring',
#   'plan',
#   'implement',
#   'medicare',
#   'far',
#   'go',
#   'overhauling',
#   'immigration',
#   'law',
#   'financial',
#   'sector',
#   'criminal',
#   'justice',
#   'primary',
#   'season',
#   'initially',
#   'seen',
#   'contest',
#   'idea',
#   'liberal',
#   'activist',
#   'largely',
#   'setting',
#   'agenda',
#   'given',
#   'jockeying',
#   'notion',
#   'electability',
#   'assemble',
#   'strongest',
#   'coalition',
#   'voter',
#   'fall',
#   'think',
#   'increasingly',
#   'voter',
#   'mind',
#   'pete',
#   'buttigieg',
#   'leading',
#   'candidate',
#   'iowa',
#   'interview',
#   'referring',
#   'electability',
#   'making',
#   'mind',
#   'still',
#   'thinking',
#   'u',
#   'mean',
#   'appreciate',
#   'got',
#   'common',
#   'value',
#   'person',
#   'likely',
#   'beat',
#   'donald',
#   'five',
#   'leading',
#   'democratic',
#   'candidate',
#   'iowa',
#   'descended',
#   'state',
#   'saturday',
#   'ahead',
#   'caucus',
#   'monday',
#   'night',
#   'poll',
#   'showing',
#   'clear',
#   'voter',
#   'still',
#   'torn',
#   'support',
#   'three',
#   'contender',
#   'senator',
#   'bernie',
#   'elizabeth',
#   'warren',
#   'amy',
#   'klobuchar',
#   'returned',
#   'away',
#   'last',
#   'week',
#   'senate',
#   'impeachment',
#   'trial',
#   'say',
#   'certainty',
#   'absence',
#   'affect',
#   'chance',
#   'rally',
#   'pamphlet',
#   'television',
#   'advertising',
#   'even',
#   'electric',
#   'sign',
#   'placed',
#   'atop',
#   'car',
#   'resemble',
#   'pizza',
#   'delivery',
#   'advertisement',
#   'candidate',
#   'running',
#   'explicitly',
#   'purported',
#   'viability',
#   'modern',
#   'presidential',
#   'leading',
#   'progressive',
#   'field',
#   'increasingly',
#   'linking',
#   'populist',
#   'platform',
#   'argument',
#   'peel',
#   'away',
#   'disaffected',
#   'voter',
#   'moderate',
#   'candidate',
#   'like',
#   'former',
#   'vice',
#   'president',
#   'joseph',
#   'could',
#   'imperil',
#   'effort',
#   'closing',
#   'iowa',
#   'campaign',
#   'commercial',
#   'highlighting',
#   'advantage',
#   'national',
#   'poll',
#   'leading',
#   'supporter',
#   'iowa',
#   'introducing',
#   'voter',
#   'arguing',
#   'could',
#   'win',
#   'republican',
#   'buttigieg',
#   'warren',
#   'struggling',
#   'match',
#   'appeal',
#   'rival',
#   'party',
#   'ideological',
#   'pole',
#   'infusing',
#   'messaging',
#   'barely',
#   'veiled',
#   'safer',
#   'choice',
#   'wo',
#   'alienate',
#   'flank',
#   'party',
#   'like',
#   'iowa',
#   'campaign',
#   'trail',
#   'saturday',
#   'warren',
#   'presented',
#   'candidate',
#   'best',
#   'prepared',
#   'rally',
#   'democrat',
#   'general',
#   'election',
#   'addressed',
#   'group',
#   'volunteer',
#   'urbandale',
#   'wall',
#   'sign',
#   'reading',
#   'unite',
#   'party',
#   'cedar',
#   'rapid',
#   'gymnasium',
#   'representative',
#   'ayanna',
#   'pressley',
#   'massachusetts',
#   'praised',
#   'warren',
#   'empathetic',
#   'electable',
#   'must',
#   'come',
#   'together',
#   'party',
#   'beat',
#   'donald',
#   'warren',
#   'got',
#   'plan',
#   'turn',
#   'toward',
#   'pragmatism',
#   'reflects',
#   'simple',
#   'fact',
#   'political',
#   'life',
#   'contest',
#   'least',
#   'third',
#   'likely',
#   'caucusgoers',
#   'remain',
#   'undecided',
#   'day',
#   'vote',
#   'candidate',
#   'responding',
#   'marketplace',
#   'voter',
#   'deeply',
#   'split',
#   'across',
#   'ideological',
#   'generational',
#   'line',
#   'could',
#   'still',
#   'force',
#   'showdown',
#   'summer',
#   'convention',
#   'united',
#   'hunger',
#   'unseat',
#   'mr',
#   'focused',
#   'getting',
#   'fool',
#   'white',
#   'house',
#   'debbie',
#   'mcallister',
#   'attended',
#   'sioux',
#   'city',
#   'rally',
#   'friday',
#   'buttigieg',
#   'former',
#   'mayor',
#   'south',
#   'bend',
#   'leaning',
#   'toward',
#   'norris',
#   'caucused',
#   'every',
#   'four',
#   'year',
#   'since',
#   'leading',
#   'supporter',
#   'warren',
#   'fellow',
#   'iowa',
#   'democrat',
#   'feel',
#   'burden',
#   'heavier',
#   'recall',
#   'norris',
#   'saw',
#   'little',
#   'bit',
#   'got',
#   'stop',
#   'george',
#   'iraq',
#   'war',
#   'steroid',
#   'even',
#   'bluntly',
#   'negative',
#   'campaign',
#   'tactic',
#   'framed',
#   'odds',
#   'group',
#   'democratic',
#   'majority',
#   'israel',
#   'dedicated',
#   'advertising',
#   'last',
#   'week',
#   'caucus',
#   'race',
#   'put',
#   'whole',
#   'sum',
#   'behind',
#   'commercial',
#   'warning',
#   'platform',
#   'could',
#   'throw',
#   'election',
#   'mr',
#   'democrat',
#   'believe',
#   'nothing',
#   'important',
#   'replacing',
#   'donald',
#   'mark',
#   'mellman',
#   'president',
#   'democratic',
#   'majority',
#   'israel',
#   'longtime',
#   'democratic',
#   'pollster',
#   'regarding',
#   'added',
#   'lot',
#   'democrat',
#   'disagree',
#   'lot',
#   'position',
#   'others',
#   'concerned',
#   'electability',
#   'perhaps',
#   'remarkable',
#   'closing',
#   'appeal',
#   'vermont',
#   'whose',
#   'call',
#   'political',
#   'revolution',
#   'vaulted',
#   'contention',
#   'race',
#   'scarcely',
#   'mentioned',
#   'prospect',
#   'back',
#   'senator',
#   'ted',
#   'cruz',
#   'leading',
#   'republican',
#   'diluted',
#   'progressive',
#   'message',
#   'stake',
#   'lead',
#   'iowa',
#   'poll',
#   'democratic',
#   'socialist',
#   'turning',
#   'hardheaded',
#   'campaign',
#   'ad',
#   'warn',
#   'nominating',
#   'candidate',
#   'unblemished',
#   'record',
#   'opposing',
#   'cut',
#   'social',
#   'security',
#   'unmistakable',
#   'reference',
#   'past',
#   'support',
#   'overhauling',
#   'program',
#   'sioux',
#   'city',
#   'field',
#   'office',
#   'campaign',
#   'distributing',
#   'pamphlet',
#   'read',
#   'effective',
#   'leader',
#   'toughness',
#   'defeat',
#   'donald',
#   'addressing',
#   'supporter',
#   'saturday',
#   'indianola',
#   'iowa',
#   'wore',
#   'bernie',
#   'beat',
#   'argued',
#   'mammoth',
#   'volunteer',
#   'effort',
#   'iowa',
#   'presaged',
#   'sort',
#   'organization',
#   'could',
#   'build',
#   'fall',
#   'going',
#   'knock',
#   'door',
#   'month',
#   'january',
#   'day',
#   'february',
#   'adding',
#   'need',
#   'order',
#   'win',
#   'vowing',
#   'bring',
#   'million',
#   'people',
#   'political',
#   'process',
#   'normally',
#   'vote',
#   'warned',
#   'democrat',
#   'lose',
#   'low',
#   'turnout',
#   'mr',
#   'focus',
#   'electability',
#   'also',
#   'stand',
#   'go',
#   'rival',
#   'attempting',
#   'political',
#   'inspiration',
#   'cold',
#   'calculus',
#   'cobbling',
#   'together',
#   'electoral',
#   'college',
#   'vote',
#   'needed',
#   'defeat',
#   'mr',
#   'beat',
#   'nationally',
#   'state',
#   'win',
#   'narrator',
#   'say',
#   'concluding',
#   'iowa',
#   'television',
#   'appeal',
#   'subtle',
#   'event',
#   'iowa',
#   'often',
#   'feature',
#   'former',
#   'gov',
#   'tom',
#   'vilsack',
#   'iowa',
#   'wife',
#   'christie',
#   'rally',
#   'suburban',
#   'de',
#   'moines',
#   'vilsack',
#   'talked',
#   'potential',
#   'appeal',
#   'among',
#   'republican',
#   'friend',
#   'vilsack',
#   'rattled',
#   'former',
#   'vice',
#   'president',
#   'advantage',
#   'survey',
#   'traditional',
#   'swing',
#   'moment',
#   'underscored',
#   'horse',
#   'race',
#   'overtaken',
#   'policy',
#   'focus',
#   'vilsack',
#   'drew',
#   'loudest',
#   'applause',
#   'entire',
#   'event',
#   'making',
#   'observation',
#   'polling',
#   'within',
#   'margin',
#   'error',
#   'texas',
#   'candidate',
#   'warren',
#   'buttigieg',
#   'used',
#   'voter',
#   'fixation',
#   'electability',
#   'cast',
#   'candidate',
#   'broadest',
#   'appeal',
#   'within',
#   'buttigieg',
#   'organized',
#   'campaign',
#   'schedule',
#   'final',
#   'week',
#   'caucus',
#   'around',
#   'visiting',
#   'county',
#   'voted',
#   'former',
#   'president',
#   'barack',
#   'obama',
#   'flipping',
#   'support',
#   'aide',
#   'circulated',
#   'statistic',
#   'past',
#   'election',
#   'reporter',
#   'locale',
#   'buttigieg',
#   'sought',
#   'liken',
#   'kind',
#   'name',
#   'past',
#   'winner',
#   'like',
#   'bill',
#   'clinton',
#   'mr',
#   'obama',
#   'last',
#   'country',
#   'buttigieg',
#   'rally',
#   'marshalltown',
#   'iowa',
#   'every',
#   'single',
#   'time',
#   'party',
#   'white',
#   'house',
#   'exception',
#   'done',
#   'nominee',
#   'looking',
#   'future',
#   'moving',
#   'past',
#   'argument',
#   'past',
#   'creature',
#   'washington',
#   'opening',
#   'door',
#   'generation',
#   'ankeny',
#   'buttigieg',
#   'invoked',
#   'impeachment',
#   'trial',
#   'likely',
#   'acquittal',
#   'emphasize',
#   'stake',
#   'election',
#   'chance',
#   'unless',
#   'senate',
#   'really',
#   'surprise',
#   'u',
#   'laughter',
#   'warren',
#   'also',
#   'sought',
#   'portray',
#   'consensus',
#   'candidate',
#   'airing',
#   'commercial',
#   'feature',
#   'iowa',
#   'supporter',
#   'hillary',
#   'clinton',
#   'say',
#   'supporting',
#   'massachusetts',
#   'plain',
#   'acknowledgment',
#   'voter',
#   'concern',
#   'sexism',
#   'general',
#   'election',
#   'warren',
#   'released',
#   'another',
#   'spot',
#   'showing',
#   'former',
#   'supporter',
#   'older',
#   'man',
#   'rural',
#   'iowa',
#   'directly',
#   'addressing',
#   'worry',
#   'among',
#   'voter',
#   'nominating',
#   'woman',
#   'people',
#   'say',
#   'woman',
#   'ca',
#   'win',
#   'say',
#   'nonsense',
#   'say',
#   'holding',
#   'photograph',
#   'showing',
#   'sign',
#   'declaring',
#   'man',
#   'beat',
#   'elizabeth',
#   'kickoff',
#   'event',
#   'warren',
#   'canvasser',
#   'friday',
#   'morning',
#   'clive',
#   'suburb',
#   'de',
#   'moines',
#   'michelle',
#   'wu',
#   'boston',
#   'city',
#   'councilor',
#   'urged',
#   'reassure',
#   'anxious',
#   'voter',
#   'version',
#   'argument',
#   'stressing',
#   'warren',
#   'victory',
#   'popular',
#   'republican',
#   'senator',
#   'barn',
#   'pickup',
#   'scott',
#   'brown',
#   'promising',
#   'economic',
#   'message',
#   'appeal',
#   'independent',
#   'disaffected',
#   'outdone',
#   'electability',
#   'klobuchar',
#   'month',
#   'blunt',
#   'iowan',
#   'turn',
#   'every',
#   'race',
#   'run',
#   'increasingly',
#   'competitive',
#   'midwestern',
#   'state',
#   'pitch',
#   'made',
#   'competitive',
#   'iowa',
#   'outspent',
#   'polled',
#   'four',
#   'leading',
#   'campaign',
#   'closing',
#   'day',
#   'klobuchar',
#   'becoming',
#   'even',
#   'le',
#   'subtle',
#   'printed',
#   'signature',
#   'green',
#   'reading',
#   'amy',
#   'klobuchar',
#   'beat',
#   'donald',
#   'photographfor',
#   'democratic',
#   'candidate',
#   'voter',
#   'alike',
#   'overarching',
#   'factor',
#   'appears',
#   'boiling',
#   'best',
#   'positioned',
#   'defeat',
#   'president',
#   'former',
#   'vice',
#   'president',
#   'joseph',
#   'go',
#   'furthest',
#   'emphasizing',
#   'electoral',
#   'calculus',
#   'political',
#   'inspiration',
#   'pete',
#   'buttigieg',
#   'elizabeth',
#   'warren',
#   'casting',
#   'broadest',
#   'appeal',
#   'within',
#   'party',
#   'photograph',
#   'jordan',
#   'gale',
#   'york',
#   'time',
#   'ruth',
#   'york',
#   'time',
#   'todd',
#   'york',
#   'time',
#   'york',
#   'time',
#   'feb'],
#  ['hitthe',
#   'move',
#   'group',
#   'young',
#   'climate',
#   'activist',
#   'another',
#   'sign',
#   'advocacy',
#   'organization',
#   'increasingly',
#   'coalesced',
#   'around',
#   'vermont',
#   'senator',
#   'sunrise',
#   'movement',
#   'collection',
#   'young',
#   'climate',
#   'activist',
#   'roiled',
#   'capitol',
#   'hill',
#   'democratic',
#   'presidential',
#   'primary',
#   'announced',
#   'thursday',
#   'endorsing',
#   'senator',
#   'bernie',
#   'vermont',
#   'another',
#   'sign',
#   'advocacy',
#   'group',
#   'increasingly',
#   'coalesced',
#   'around',
#   'landslide',
#   'vote',
#   'percent',
#   'respondent',
#   'earned',
#   'backing',
#   'member',
#   'group',
#   'quickly',
#   'become',
#   'politically',
#   'influential',
#   'since',
#   'founding',
#   'fledgling',
#   'collection',
#   'college',
#   'student',
#   'frustrated',
#   'democrat',
#   'republican',
#   'acting',
#   'quickly',
#   'curb',
#   'climate',
#   'change',
#   'sunrise',
#   'grown',
#   'chapter',
#   'nationwide',
#   'host',
#   'event',
#   'iowa',
#   'city',
#   'formally',
#   'announce',
#   'endorsement',
#   'believe',
#   'bernie',
#   'presidency',
#   'provide',
#   'best',
#   'political',
#   'terrain',
#   'engage',
#   'ultimately',
#   'win',
#   'struggle',
#   'world',
#   'deserve',
#   'varshini',
#   'prakash',
#   'founder',
#   'executive',
#   'director',
#   'movement',
#   'statement',
#   'senator',
#   'made',
#   'clear',
#   'throughout',
#   'political',
#   'career',
#   'campaign',
#   'grasp',
#   'scale',
#   'climate',
#   'crisis',
#   'urgency',
#   'must',
#   'act',
#   'address',
#   'opportunity',
#   'coming',
#   'together',
#   'move',
#   'represents',
#   'another',
#   'step',
#   'electoral',
#   'politics',
#   'group',
#   'young',
#   'activist',
#   'midterm',
#   'election',
#   'group',
#   'made',
#   'national',
#   'headline',
#   'staging',
#   'protest',
#   'office',
#   'incoming',
#   'house',
#   'speaker',
#   'nancy',
#   'signature',
#   'policy',
#   'ambitious',
#   'proposal',
#   'known',
#   'green',
#   'deal',
#   'became',
#   'crucial',
#   'litmus',
#   'test',
#   'splitting',
#   'moderate',
#   'liberal',
#   'climate',
#   'change',
#   'embraced',
#   'candidate',
#   'like',
#   'senator',
#   'elizabeth',
#   'warren',
#   'massachusetts',
#   'former',
#   'mayor',
#   'pete',
#   'buttigieg',
#   'south',
#   'bend',
#   'ind',
#   'even',
#   'moderate',
#   'candidate',
#   'like',
#   'former',
#   'vice',
#   'president',
#   'joseph',
#   'race',
#   'current',
#   'cited',
#   'policy',
#   'inspiration',
#   'goal',
#   'drastically',
#   'reducing',
#   'greenhouse',
#   'gas',
#   'emission',
#   'also',
#   'addressing',
#   'economic',
#   'inequality',
#   'important',
#   'scorecard',
#   'sunrise',
#   'released',
#   'ranking',
#   'top',
#   'three',
#   'candidate',
#   'plan',
#   'support',
#   'green',
#   'deal',
#   'score',
#   'trailed',
#   'far',
#   'behind',
#   'warren',
#   'earned',
#   'respectively',
#   'received',
#   'low',
#   'mark',
#   'frequently',
#   'talk',
#   'proposal',
#   'green',
#   'deal',
#   'mr',
#   'also',
#   'tense',
#   'exchange',
#   'sunrise',
#   'organizer',
#   'september',
#   'pressed',
#   'commitment',
#   'environmental',
#   'issue',
#   'look',
#   'record',
#   'child',
#   'told',
#   'group',
#   'announcement',
#   'last',
#   'presidential',
#   'endorsement',
#   'arrive',
#   'major',
#   'progressive',
#   'group',
#   'almost',
#   'backed',
#   'candidacy',
#   'helped',
#   'develop',
#   'much',
#   'political',
#   'infrastructure',
#   'democratic',
#   'party',
#   'huge',
#   'support',
#   'among',
#   'young',
#   'democrat',
#   'campaign',
#   'cycle',
#   'began',
#   'inevitable',
#   'retain',
#   'democratic',
#   'voter',
#   'bevy',
#   'option',
#   'fresh',
#   'face',
#   'like',
#   'buttigieg',
#   'former',
#   'representative',
#   'beto',
#   'texas',
#   'senator',
#   'kamala',
#   'harris',
#   'california',
#   'warren',
#   'another',
#   'candidate',
#   'progressive',
#   'bona',
#   'fides',
#   'also',
#   'woman',
#   'oval',
#   'office',
#   'september',
#   'working',
#   'family',
#   'party',
#   'endorsed',
#   'warren',
#   'saying',
#   'better',
#   'positioned',
#   'create',
#   'coalition',
#   'around',
#   'liberal',
#   'value',
#   'group',
#   'needed',
#   'choose',
#   'side',
#   'next',
#   'several',
#   'month',
#   'however',
#   'warren',
#   'drew',
#   'significant',
#   'criticism',
#   'health',
#   'care',
#   'proposal',
#   'stepped',
#   'away',
#   'immediate',
#   'push',
#   'medicare',
#   'energy',
#   'democrat',
#   'left',
#   'flank',
#   'began',
#   'move',
#   'away',
#   'october',
#   'announced',
#   'endorsement',
#   'popular',
#   'house',
#   'democrat',
#   'ilhan',
#   'omar',
#   'minnesota',
#   'alexandria',
#   'york',
#   'sponsor',
#   'green',
#   'deal',
#   'legislation',
#   'also',
#   'gained',
#   'backing',
#   'labor',
#   'organization',
#   'national',
#   'nurse',
#   'united',
#   'advocacy',
#   'group',
#   'center',
#   'popular',
#   'democracy',
#   'action',
#   'people',
#   'week',
#   'endorsed',
#   'dream',
#   'defender',
#   'collection',
#   'activist',
#   'focus',
#   'criminal',
#   'justice',
#   'gave',
#   'member',
#   'choice',
#   'whether',
#   'back',
#   'presidential',
#   'candidate',
#   'percent',
#   'wanted',
#   'support',
#   'candidate',
#   'percent',
#   'chose',
#   'warren',
#   'sent',
#   'sunrise',
#   'positive',
#   'message',
#   'twitter',
#   'wake',
#   'announcement',
#   'restating',
#   'commitment',
#   'green',
#   'deal',
#   'recent',
#   'week',
#   'sunrise',
#   'likely',
#   'back',
#   'warren',
#   'announced',
#   'hold',
#   'event',
#   'hampshire',
#   'rolled',
#   'endorsement',
#   'rhiana',
#   'lead',
#   'author',
#   'green',
#   'deal',
#   'warren',
#   'called',
#   'trillion',
#   'investment',
#   'economy',
#   'implement',
#   'green',
#   'deal',
#   'create',
#   'call',
#   'green',
#   'job',
#   'also',
#   'released',
#   'proposal',
#   'specific',
#   'fighting',
#   'climate',
#   'change',
#   'call',
#   'trillion',
#   'spending',
#   'decade',
#   'released',
#   'trillion',
#   'plan',
#   'green',
#   'deal',
#   'called',
#   'united',
#   'state',
#   'eliminate',
#   'fossil',
#   'fuel',
#   'similarly',
#   'transforming',
#   'weber',
#   'political',
#   'director',
#   'sunrise',
#   'movement',
#   'group',
#   'advocacy',
#   'continue',
#   'matter',
#   'nominee',
#   'senator',
#   'become',
#   'next',
#   'president',
#   'united',
#   'state',
#   'push',
#   'ensure',
#   'delivering',
#   'upon',
#   'promise',
#   'green',
#   'deal',
#   'platform',
#   'top',
#   'priority',
#   'administration',
#   'senator',
#   'doe',
#   'win',
#   'nomination',
#   'stake',
#   'climate',
#   'crisis',
#   'also',
#   'demand',
#   'ca',
#   'sit',
#   'election',
#   'photographsenator',
#   'bernie',
#   'california',
#   'last',
#   'month',
#   'candidacy',
#   'helped',
#   'develop',
#   'much',
#   'political',
#   'infrastructure',
#   'photograph',
#   'september',
#   'dawn',
#   'bottom',
#   'york',
#   'time',
#   'york',
#   'time',
#   'jan']]

# %%
bernie_WSJ_tokens[0:5]
# Out:
# [['increasingly',
#   'strict',
#   'measure',
#   'designed',
#   'slow',
#   'spread',
#   'coronavirus',
#   'raising',
#   'concern',
#   'feasibility',
#   'holding',
#   'remaining',
#   'democratic',
#   'presidential',
#   'primary',
#   'contest',
#   'well',
#   'logistics',
#   'holding',
#   'november',
#   'general',
#   'election',
#   'pandemic',
#   'still',
#   'nation',
#   'election',
#   'complicated',
#   'thicket',
#   'state',
#   'federal',
#   'law',
#   'process',
#   'selecting',
#   'presidential',
#   'nominee',
#   'complicated',
#   'fact',
#   'political',
#   'party',
#   'private',
#   'organization',
#   'set',
#   'internal',
#   'rule',
#   'depending',
#   'jurisdiction',
#   'state',
#   'official',
#   'party',
#   'leader',
#   'flexibility',
#   'altering',
#   'date',
#   'possibly',
#   'format',
#   'remaining',
#   'presidential',
#   'primary',
#   'contest',
#   'response',
#   'growing',
#   'pandemic',
#   'expert',
#   'say',
#   'five',
#   'state',
#   'already',
#   'done',
#   'ohio',
#   'brief',
#   'struggle',
#   'governor',
#   'state',
#   'supreme',
#   'court',
#   'voting',
#   'follow',
#   'pandemic',
#   'persists',
#   'fall',
#   'official',
#   'fear',
#   'could',
#   'congress',
#   'need',
#   'step',
#   'picture',
#   'significant',
#   'alteration',
#   'general',
#   'election',
#   'date',
#   'date',
#   'fixed',
#   'tuesday',
#   'act',
#   'congress',
#   'president',
#   'state',
#   'election',
#   'absent',
#   'legislation',
#   'court',
#   'granted',
#   'strong',
#   'protection',
#   'citizen',
#   'cast',
#   'ballot',
#   'even',
#   'order',
#   'official',
#   'sweeping',
#   'emergency',
#   'authority',
#   'level',
#   'government',
#   'limit',
#   'gathering',
#   'impose',
#   'quarantine',
#   'could',
#   'trumped',
#   'think',
#   'state',
#   'authority',
#   'reasonable',
#   'measure',
#   'ensure',
#   'public',
#   'safety',
#   'ultimately',
#   'yield',
#   'vote',
#   'marc',
#   'elia',
#   'democratic',
#   'election',
#   'lawyer',
#   'worked',
#   'numerous',
#   'presidential',
#   'campaign',
#   'democratic',
#   'primary',
#   'contest',
#   'already',
#   'affected',
#   'virus',
#   'tuesday',
#   'joe',
#   'defeated',
#   'bernie',
#   'trio',
#   'state',
#   'turnout',
#   'level',
#   'appeared',
#   'low',
#   'compared',
#   'similar',
#   'contest',
#   'held',
#   'past',
#   'wall',
#   'street',
#   'journal',
#   'reported',
#   'many',
#   'voter',
#   'venturing',
#   'home',
#   'time',
#   'day',
#   'cast',
#   'ballot',
#   'pandemic',
#   'abate',
#   'coming',
#   'week',
#   'asia',
#   'life',
#   'slowly',
#   'returning',
#   'normal',
#   'early',
#   'outbreak',
#   'site',
#   'like',
#   'china',
#   'doe',
#   'diminish',
#   'return',
#   'fall',
#   'election',
#   'official',
#   'already',
#   'expressed',
#   'concern',
#   'might',
#   'hold',
#   'general',
#   'election',
#   'middle',
#   'deadly',
#   'virus',
#   'whether',
#   'extremely',
#   'election',
#   'seen',
#   'legitimate',
#   'voter',
#   'logistics',
#   'holding',
#   'election',
#   'raise',
#   'additional',
#   'concern',
#   'reliable',
#   'voter',
#   'elderly',
#   'group',
#   'risk',
#   'coronavirus',
#   'complication',
#   'addition',
#   'many',
#   'poll',
#   'worker',
#   'volunteer',
#   'staff',
#   'election',
#   'across',
#   'country',
#   'older',
#   'election',
#   'assistance',
#   'commission',
#   'found',
#   'poll',
#   'worker',
#   'age',
#   'coronavirus',
#   'newsletter',
#   'get',
#   'morning',
#   'coronavirus',
#   'briefing',
#   'weekday',
#   'plus',
#   'update',
#   'friday',
#   'sign',
#   'proposal',
#   'congress',
#   'mandate',
#   'state',
#   'expand',
#   'program',
#   'voter',
#   'limiting',
#   'need',
#   'sen',
#   'ron',
#   'wyden',
#   'amy',
#   'klobuchar',
#   'proposed',
#   'bill',
#   'also',
#   'provide',
#   'million',
#   'grant',
#   'state',
#   'prepaid',
#   'postage',
#   'equipment',
#   'upgrade',
#   'virtually',
#   'every',
#   'state',
#   'already',
#   'today',
#   'absentee',
#   'ballot',
#   'arrangement',
#   'klobuchar',
#   'making',
#   'significant',
#   'amount',
#   'federal',
#   'fund',
#   'state',
#   'move',
#   'ensure',
#   'fall',
#   'middle',
#   'pandemic',
#   'american',
#   'voter',
#   'going',
#   'forced',
#   'choose',
#   'health',
#   'voting',
#   'wyden',
#   'msnbc',
#   'week',
#   'ample',
#   'precedent',
#   'action',
#   'congress',
#   'previously',
#   'mandated',
#   'state',
#   'allow',
#   'military',
#   'voter',
#   'cast',
#   'absentee',
#   'ballot',
#   'mail',
#   'state',
#   'allow',
#   'voter',
#   'register',
#   'renewing',
#   'obtaining',
#   'driver',
#   'example',
#   'state',
#   'plus',
#   'washington',
#   'allow',
#   'voter',
#   'cast',
#   'ballot',
#   'reason',
#   'place',
#   'reason',
#   'requesting',
#   'ballot',
#   'vote',
#   'mail',
#   'controversial',
#   'though',
#   'liberal',
#   'activist',
#   'believe',
#   'dampens',
#   'turnout',
#   'among',
#   'demographic',
#   'group',
#   'concern',
#   'program',
#   'include',
#   'paid',
#   'postage',
#   'conservative',
#   'additional',
#   'concern',
#   'fraud',
#   'ballot',
#   'simply',
#   'support',
#   'single',
#   'nationwide',
#   'election',
#   'day',
#   'even',
#   'opponent',
#   'universal',
#   'say',
#   'year',
#   'might',
#   'exception',
#   'particularly',
#   'important',
#   'balloting',
#   'run',
#   'orderly',
#   'legitimate',
#   'personally',
#   'think',
#   'extensive',
#   'voting',
#   'mail',
#   'good',
#   'idea',
#   'hate',
#   'see',
#   'crisis',
#   'sneak',
#   'permanent',
#   'voting',
#   'mail',
#   'bradley',
#   'smith',
#   'former',
#   'republican',
#   'appointee',
#   'federal',
#   'election',
#   'commission',
#   'teach',
#   'capital',
#   'university',
#   'law',
#   'school',
#   'election',
#   'think',
#   'probably',
#   'good',
#   'current',
#   'circumstance',
#   'congress',
#   'pas',
#   'limited',
#   'legislation',
#   'providing',
#   'kind',
#   'byron',
#   'tau',
#   'byron',
#   'tau'],
#  ['official',
#   'informed',
#   'bernie',
#   'russia',
#   'actively',
#   'trying',
#   'support',
#   'campaign',
#   'democratic',
#   'nomination',
#   'part',
#   'moscow',
#   'broader',
#   'effort',
#   'interfere',
#   'election',
#   'according',
#   'people',
#   'familiar',
#   'matter',
#   'president',
#   'small',
#   'number',
#   'lawmaker',
#   'briefed',
#   'intelligence',
#   'people',
#   'classified',
#   'fbi',
#   'briefing',
#   'type',
#   'routinely',
#   'given',
#   'presidential',
#   'campaign',
#   'election',
#   'security',
#   'people',
#   'given',
#   'reaction',
#   'intelligence',
#   'considered',
#   'compelling',
#   'enough',
#   'needed',
#   'alerted',
#   'people',
#   'intelligence',
#   'suggested',
#   'russian',
#   'effort',
#   'bolster',
#   'approached',
#   'scale',
#   'scope',
#   'operation',
#   'support',
#   'campaign',
#   'person',
#   'washington',
#   'post',
#   'earlier',
#   'reported',
#   'received',
#   'briefing',
#   'russia',
#   'seeking',
#   'support',
#   'primary',
#   'speaking',
#   'reporter',
#   'friday',
#   'acknowledged',
#   'briefing',
#   'taken',
#   'place',
#   'clear',
#   'role',
#   'russia',
#   'attempting',
#   'play',
#   'election',
#   'told',
#   'russia',
#   'maybe',
#   'country',
#   'getting',
#   'involved',
#   'campaign',
#   'told',
#   'reporter',
#   'bakersfield',
#   'look',
#   'message',
#   'russia',
#   'american',
#   'election',
#   'criticized',
#   'online',
#   'vitriol',
#   'supporter',
#   'directed',
#   'opponent',
#   'also',
#   'statement',
#   'possible',
#   'ugly',
#   'stuff',
#   'attributed',
#   'campaign',
#   'actually',
#   'coming',
#   'fake',
#   'internet',
#   'account',
#   'office',
#   'director',
#   'national',
#   'intelligence',
#   'federal',
#   'bureau',
#   'investigation',
#   'department',
#   'homeland',
#   'security',
#   'declined',
#   'comment',
#   'report',
#   'emerged',
#   'month',
#   'briefing',
#   'day',
#   'nevada',
#   'caucus',
#   'currently',
#   'leading',
#   'democratic',
#   'rival',
#   'national',
#   'poll',
#   'following',
#   'finish',
#   'hampshire',
#   'primary',
#   'month',
#   'poll',
#   'suggested',
#   'positioned',
#   'strong',
#   'finish',
#   'nevada',
#   'let',
#   'guess',
#   'day',
#   'nevada',
#   'caucus',
#   'think',
#   'came',
#   'asked',
#   'last',
#   'week',
#   'intelligence',
#   'official',
#   'told',
#   'president',
#   'lawmaker',
#   'house',
#   'intelligence',
#   'committee',
#   'russia',
#   'apparent',
#   'preference',
#   'according',
#   'people',
#   'familiar',
#   'matter',
#   'oval',
#   'office',
#   'meeting',
#   'lashed',
#   'joseph',
#   'maguire',
#   'acting',
#   'director',
#   'national',
#   'intelligence',
#   'replaced',
#   'week',
#   'irate',
#   'lawmaker',
#   'received',
#   'information',
#   'people',
#   'president',
#   'also',
#   'agitated',
#   'intelligence',
#   'indicated',
#   'russia',
#   'seek',
#   'support',
#   'electoral',
#   'prospect',
#   'fall',
#   'could',
#   'determined',
#   'moscow',
#   'precise',
#   'motive',
#   'effort',
#   'support',
#   'social',
#   'medium',
#   'people',
#   'familiar',
#   'matter',
#   'russia',
#   'repeatedly',
#   'denied',
#   'interfering',
#   'election',
#   'campaign',
#   'rally',
#   'la',
#   'vega',
#   'friday',
#   'dismissed',
#   'report',
#   'intelligence',
#   'agency',
#   'believe',
#   'russia',
#   'interfere',
#   'year',
#   'behalf',
#   'calling',
#   'disinformation',
#   'russian',
#   'president',
#   'vladimir',
#   'putin',
#   'wait',
#   'democrat',
#   'pick',
#   'nominee',
#   'bernie',
#   'honeymooned',
#   'moscow',
#   'asked',
#   'president',
#   'remark',
#   'emerged',
#   'report',
#   'democratic',
#   'candidate',
#   'warned',
#   'moscow',
#   'interest',
#   'aiding',
#   'campaign',
#   'sequence',
#   'pointed',
#   'campaign',
#   'wife',
#   'traveled',
#   'russia',
#   'delegation',
#   'burlington',
#   'mayor',
#   'establish',
#   'program',
#   'city',
#   'yaroslavl',
#   'also',
#   'celebrated',
#   'honeymoon',
#   'intelligence',
#   'official',
#   'warning',
#   'year',
#   'russia',
#   'others',
#   'likely',
#   'seek',
#   'interfere',
#   'contest',
#   'former',
#   'special',
#   'counsel',
#   'robert',
#   'mueller',
#   'investigation',
#   'found',
#   'russia',
#   'interfered',
#   'sweeping',
#   'systematic',
#   'fashion',
#   'presidential',
#   'election',
#   'help',
#   'denigrate',
#   'democratic',
#   'challenger',
#   'hillary',
#   'clinton',
#   'mueller',
#   'probe',
#   'also',
#   'found',
#   'russian',
#   'intelligence',
#   'operative',
#   'spreading',
#   'propaganda',
#   'social',
#   'medium',
#   'also',
#   'showed',
#   'favoritism',
#   'opportunity',
#   'criticize',
#   'hillary',
#   'except',
#   'support',
#   'russian',
#   'operative',
#   'quoting',
#   'saying',
#   'indictment',
#   'elizabeth',
#   'warren',
#   'rival',
#   'democratic',
#   'nomination',
#   'told',
#   'reporter',
#   'friday',
#   'received',
#   'similar',
#   'briefing',
#   'believe',
#   'need',
#   'much',
#   'transparency',
#   'possible',
#   'russian',
#   'interference',
#   'understand',
#   'disinformation',
#   'fight',
#   'disinformation',
#   'call',
#   'give',
#   'everyone',
#   'information',
#   'quickly',
#   'possible',
#   'otherwise',
#   'russian',
#   'continue',
#   'much',
#   'influence',
#   'campaign',
#   'fight',
#   'national',
#   'security',
#   'official',
#   'struggled',
#   'respond',
#   'indication',
#   'foreign',
#   'adversary',
#   'meddling',
#   'election',
#   'obama',
#   'administration',
#   'criticized',
#   'republican',
#   'democrat',
#   'alike',
#   'disclosing',
#   'public',
#   'russia',
#   'interference',
#   'november',
#   'administration',
#   'outlined',
#   'plan',
#   'notify',
#   'public',
#   'campaign',
#   'foreign',
#   'election',
#   'interference',
#   'framework',
#   'received',
#   'criticism',
#   'election',
#   'official',
#   'vague',
#   'democrat',
#   'argued',
#   'could',
#   'allow',
#   'political',
#   'influence',
#   'notification',
#   'decision',
#   'made',
#   'interest',
#   'protect',
#   'integrity',
#   'political',
#   'social',
#   'discourse',
#   'according',
#   'public',
#   'summary',
#   'framework',
#   'joshua',
#   'jamerson',
#   'rebecca',
#   'ballhaus',
#   'eliza',
#   'collins',
#   'contributed',
#   'dustin',
#   'volz',
#   'dustin',
#   'volz'],
#  ['coronavirus',
#   'pandemic',
#   'jolting',
#   'political',
#   'debate',
#   'health',
#   'care',
#   'election',
#   'campaign',
#   'democrat',
#   'arguing',
#   'crisis',
#   'damage',
#   'administration',
#   'done',
#   'safety',
#   'net',
#   'need',
#   'federal',
#   'role',
#   'providing',
#   'coverage',
#   'health',
#   'care',
#   'already',
#   'top',
#   'issue',
#   'voter',
#   'virus',
#   'began',
#   'spreading',
#   'case',
#   'across',
#   'state',
#   'washington',
#   'coronavirus',
#   'providing',
#   'platform',
#   'democrat',
#   'highlight',
#   'high',
#   'medical',
#   'cost',
#   'lack',
#   'coverage',
#   'say',
#   'policy',
#   'proposal',
#   'fix',
#   'democratic',
#   'presidential',
#   'candidate',
#   'expected',
#   'criticize',
#   'president',
#   'response',
#   'virus',
#   'sunday',
#   'night',
#   'debate',
#   'administration',
#   'official',
#   'counter',
#   'expanded',
#   'access',
#   'affordable',
#   'plan',
#   'campaign',
#   'sought',
#   'criticize',
#   'polarizing',
#   'aspect',
#   'democratic',
#   'rival',
#   'health',
#   'plan',
#   'coverage',
#   'undocumented',
#   'immigrant',
#   'bernie',
#   'joe',
#   'side',
#   'extreme',
#   'coin',
#   'campaign',
#   'tweeted',
#   'march',
#   'support',
#   'making',
#   'american',
#   'family',
#   'worker',
#   'pay',
#   'health',
#   'care',
#   'illegal',
#   'alien',
#   'democrat',
#   'argue',
#   'administration',
#   'change',
#   'affordable',
#   'care',
#   'act',
#   'weakened',
#   'coverage',
#   'million',
#   'american',
#   'could',
#   'leave',
#   'people',
#   'need',
#   'treatment',
#   'coronavirus',
#   'high',
#   'bill',
#   'point',
#   'expansion',
#   'health',
#   'plan',
#   'deny',
#   'coverage',
#   'cover',
#   'aca',
#   'minimum',
#   'benefit',
#   'well',
#   'administration',
#   'plan',
#   'back',
#   'state',
#   'change',
#   'medicaid',
#   'federal',
#   'funding',
#   'limited',
#   'block',
#   'grant',
#   'democrat',
#   'say',
#   'hurt',
#   'enrollment',
#   'republican',
#   'praised',
#   'administration',
#   'response',
#   'action',
#   'say',
#   'white',
#   'house',
#   'taken',
#   'health',
#   'coverage',
#   'affordable',
#   'accused',
#   'democrat',
#   'coronavirus',
#   'score',
#   'political',
#   'point',
#   'mark',
#   'meadow',
#   'set',
#   'chief',
#   'staff',
#   'tweet',
#   'left',
#   'control',
#   'health',
#   'care',
#   'reference',
#   'coronavirus',
#   'recently',
#   'started',
#   'appear',
#   'political',
#   'advertising',
#   'group',
#   'aligned',
#   'democrat',
#   'try',
#   'leverage',
#   'topic',
#   'tv',
#   'ad',
#   'mention',
#   'virus',
#   'critical',
#   'republican',
#   'steve',
#   'daines',
#   'appeared',
#   'montana',
#   'thursday',
#   'data',
#   'firm',
#   'spot',
#   'sponsored',
#   'protect',
#   'care',
#   'group',
#   'support',
#   'affordable',
#   'care',
#   'act',
#   'many',
#   'montana',
#   'family',
#   'go',
#   'sleep',
#   'night',
#   'worried',
#   'health',
#   'care',
#   'coverage',
#   'cost',
#   'fear',
#   'coronavirus',
#   'say',
#   'ad',
#   'run',
#   'time',
#   'billing',
#   'missoula',
#   'thursday',
#   'absolutely',
#   'going',
#   'topic',
#   'ken',
#   'goldstein',
#   'university',
#   'san',
#   'francisco',
#   'professor',
#   'studied',
#   'campaign',
#   'advertising',
#   'decade',
#   'question',
#   'campaign',
#   'strategist',
#   'ad',
#   'maker',
#   'topic',
#   'topic',
#   'share',
#   'thought',
#   'might',
#   'democratic',
#   'plan',
#   'benefit',
#   'american',
#   'health',
#   'crisis',
#   'join',
#   'conversation',
#   'time',
#   'american',
#   'many',
#   'concern',
#   'related',
#   'outbreak',
#   'mind',
#   'running',
#   'political',
#   'ad',
#   'outbreak',
#   'advantage',
#   'disadvantage',
#   'best',
#   'time',
#   'inject',
#   'political',
#   'message',
#   'goldstein',
#   'hand',
#   'people',
#   'going',
#   'watching',
#   'lot',
#   'television',
#   'internet',
#   'seeing',
#   'ad',
#   'see',
#   'record',
#   'internet',
#   'usage',
#   'video',
#   'usage',
#   'tv',
#   'rating',
#   'democratic',
#   'presidential',
#   'candidate',
#   'offensive',
#   'campaign',
#   'trail',
#   'bernie',
#   'vermont',
#   'proponent',
#   'medicare',
#   'march',
#   'rally',
#   'coronavirus',
#   'outbreak',
#   'insanity',
#   'people',
#   'ca',
#   'afford',
#   'see',
#   'doctor',
#   'former',
#   'vice',
#   'president',
#   'joe',
#   'pushed',
#   'plan',
#   'expand',
#   'aca',
#   'add',
#   'option',
#   'people',
#   'buy',
#   'federal',
#   'health',
#   'plan',
#   'blamed',
#   'taking',
#   'step',
#   'weaken',
#   'health',
#   'protecting',
#   'health',
#   'safety',
#   'american',
#   'people',
#   'important',
#   'job',
#   'unfortunately',
#   'virus',
#   'laid',
#   'bare',
#   'severe',
#   'shortcoming',
#   'current',
#   'administration',
#   'thursday',
#   'government',
#   'ability',
#   'respond',
#   'effectively',
#   'undermined',
#   'agency',
#   'disparagement',
#   'billionaire',
#   'former',
#   'york',
#   'mayor',
#   'michael',
#   'bloomberg',
#   'among',
#   'virus',
#   'tv',
#   'ad',
#   'part',
#   'political',
#   'campaign',
#   'ran',
#   'different',
#   'spot',
#   'topic',
#   'three',
#   'minute',
#   'long',
#   'dropped',
#   'democratic',
#   'presidential',
#   'primary',
#   'support',
#   'aca',
#   'grew',
#   'american',
#   'february',
#   'highest',
#   'since',
#   'law',
#   'enacted',
#   'year',
#   'ago',
#   'according',
#   'kaiser',
#   'family',
#   'foundation',
#   'support',
#   'also',
#   'october',
#   'coronavirus',
#   'case',
#   'emerged',
#   'democratic',
#   'congressional',
#   'campaign',
#   'committee',
#   'ran',
#   'digital',
#   'ad',
#   'critical',
#   'official',
#   'initially',
#   'declined',
#   'ensure',
#   'vaccine',
#   'affordable',
#   'house',
#   'minority',
#   'leader',
#   'kevin',
#   'mccarthy',
#   'california',
#   'criticized',
#   'ad',
#   'playing',
#   'politics',
#   'coronavirus',
#   'criticism',
#   'tap',
#   'growing',
#   'public',
#   'angst',
#   'virus',
#   'administration',
#   'response',
#   'people',
#   'see',
#   'making',
#   'easier',
#   'get',
#   'coronavirus',
#   'harder',
#   'get',
#   'health',
#   'care',
#   'jesse',
#   'ferguson',
#   'democratic',
#   'strategist',
#   'seems',
#   'like',
#   'challenging',
#   'agenda',
#   'sell',
#   'voter',
#   'according',
#   'quinnipiac',
#   'university',
#   'poll',
#   'released',
#   'march',
#   'voter',
#   'disapprove',
#   'handling',
#   'coronavirus',
#   'response',
#   'approve',
#   'sharp',
#   'divide',
#   'along',
#   'political',
#   'party',
#   'similar',
#   'president',
#   'overall',
#   'job',
#   'approval',
#   'rating',
#   'republican',
#   'approve',
#   'democrat',
#   'disapprove',
#   'independent',
#   'disapprove',
#   'stephanie',
#   'armour',
#   'john',
#   'mccormick'],
#  ['bernie',
#   'early',
#   'strength',
#   'putting',
#   'track',
#   'scoop',
#   'delegate',
#   'super',
#   'tuesday',
#   'photo',
#   'victor',
#   'j',
#   'blue',
#   'wall',
#   'street',
#   'journal',
#   'joe',
#   'betting',
#   'victory',
#   'south',
#   'carolina',
#   'revitalize',
#   'campaign',
#   'amy',
#   'klobuchar',
#   'say',
#   'still',
#   'momentum',
#   'hampshire',
#   'elizabeth',
#   'warren',
#   'belief',
#   'recent',
#   'debate',
#   'performance',
#   'gave',
#   'fresh',
#   'boost',
#   'pete',
#   'buttigieg',
#   'delegate',
#   'hunt',
#   'race',
#   'michael',
#   'bloomberg',
#   'ballot',
#   'series',
#   'state',
#   'spent',
#   'million',
#   'advertising',
#   'democratic',
#   'presidential',
#   'candidate',
#   'different',
#   'reason',
#   'staying',
#   'race',
#   'bound',
#   'common',
#   'goal',
#   'stop',
#   'bernie',
#   'amassing',
#   'majority',
#   'delegate',
#   'share',
#   'thought',
#   'think',
#   'many',
#   'democrat',
#   'remain',
#   'race',
#   'join',
#   'conversation',
#   'early',
#   'strength',
#   'centrist',
#   'rival',
#   'splitting',
#   'vote',
#   'doe',
#   'go',
#   'putting',
#   'vermont',
#   'senator',
#   'track',
#   'scoop',
#   'delegate',
#   'voter',
#   'across',
#   'state',
#   'territory',
#   'party',
#   'member',
#   'living',
#   'abroad',
#   'head',
#   'poll',
#   'march',
#   'known',
#   'super',
#   'tuesday',
#   'rise',
#   'fueled',
#   'concern',
#   'within',
#   'establishment',
#   'among',
#   'party',
#   'moderate',
#   'identity',
#   'democratic',
#   'socialist',
#   'liberal',
#   'policy',
#   'agenda',
#   'doom',
#   'democrat',
#   'general',
#   'election',
#   'say',
#   'beat',
#   'president',
#   'recent',
#   'wall',
#   'street',
#   'news',
#   'poll',
#   'winning',
#   'hypothetical',
#   'matchup',
#   'small',
#   'percentage',
#   'delegate',
#   'awarded',
#   'far',
#   'trajectory',
#   'change',
#   'another',
#   'candidate',
#   'could',
#   'overtake',
#   'maintains',
#   'lead',
#   'hoping',
#   'picking',
#   'delegate',
#   'needed',
#   'secure',
#   'nomination',
#   'outright',
#   'prompting',
#   'contested',
#   'summer',
#   'convention',
#   'milwaukee',
#   'another',
#   'candidate',
#   'could',
#   'emerge',
#   'top',
#   'tuesday',
#   'contest',
#   'represent',
#   'coming',
#   'test',
#   'could',
#   'determine',
#   'whether',
#   'cruise',
#   'commanding',
#   'delegate',
#   'lead',
#   'california',
#   'texas',
#   'biggest',
#   'delegate',
#   'prize',
#   'offer',
#   'combined',
#   'delegate',
#   'nearly',
#   'half',
#   'delegate',
#   'awarded',
#   'tuesday',
#   'leading',
#   'california',
#   'poll',
#   'near',
#   'top',
#   'texas',
#   'candidate',
#   'cross',
#   'threshold',
#   'necessary',
#   'earn',
#   'delegate',
#   'could',
#   'give',
#   'much',
#   'easier',
#   'path',
#   'multiple',
#   'people',
#   'win',
#   'delegate',
#   'state',
#   'elizabeth',
#   'warren',
#   'address',
#   'crowd',
#   'rally',
#   'greenville',
#   'friday',
#   'photo',
#   'victor',
#   'j',
#   'blue',
#   'wall',
#   'street',
#   'journal',
#   'winning',
#   'minimize',
#   'margin',
#   'super',
#   'tuesday',
#   'rack',
#   'delegate',
#   'following',
#   'contest',
#   'field',
#   'winnow',
#   'buttigieg',
#   'campaign',
#   'memo',
#   'released',
#   'week',
#   'coming',
#   'schedule',
#   'trying',
#   'thwart',
#   'challenger',
#   'senator',
#   'set',
#   'hold',
#   'rally',
#   'friday',
#   'saturday',
#   'massachusetts',
#   'warren',
#   'home',
#   'state',
#   'monday',
#   'klobuchar',
#   'home',
#   'state',
#   'minnesota',
#   'returning',
#   'home',
#   'vermont',
#   'three',
#   'march',
#   'primary',
#   'flexing',
#   'think',
#   'every',
#   'reason',
#   'ian',
#   'sam',
#   'worked',
#   'presidential',
#   'campaign',
#   'kamala',
#   'harris',
#   'hillary',
#   'clinton',
#   'really',
#   'put',
#   'elizabeth',
#   'amy',
#   'corner',
#   'say',
#   'ca',
#   'even',
#   'win',
#   'home',
#   'state',
#   'still',
#   'pressing',
#   'race',
#   'came',
#   'third',
#   'place',
#   'hampshire',
#   'campaigned',
#   'practical',
#   'scheduled',
#   'super',
#   'tuesday',
#   'night',
#   'party',
#   'paul',
#   'also',
#   'competing',
#   'state',
#   'colorado',
#   'north',
#   'carolina',
#   'tennessee',
#   'virginia',
#   'aide',
#   'warren',
#   'believe',
#   'fiery',
#   'performance',
#   'debate',
#   'la',
#   'vega',
#   'improved',
#   'standing',
#   'race',
#   'touted',
#   'fundraising',
#   'haul',
#   'million',
#   'month',
#   'warren',
#   'also',
#   'received',
#   'giant',
#   'lift',
#   'committee',
#   'supporting',
#   'campaign',
#   'known',
#   'persist',
#   'pac',
#   'announced',
#   'million',
#   'television',
#   'digital',
#   'ad',
#   'buy',
#   'late',
#   'thursday',
#   'ad',
#   'run',
#   'nine',
#   'medium',
#   'market',
#   'across',
#   'three',
#   'super',
#   'tuesday',
#   'state',
#   'california',
#   'massachusetts',
#   'texas',
#   'seeking',
#   'comeback',
#   'banking',
#   'south',
#   'carolina',
#   'help',
#   'give',
#   'momentum',
#   'aide',
#   'believe',
#   'strength',
#   'voter',
#   'half',
#   'democratic',
#   'primary',
#   'electorate',
#   'south',
#   'carolina',
#   'could',
#   'help',
#   'win',
#   'delegate',
#   'group',
#   'southern',
#   'state',
#   'voting',
#   'march',
#   'people',
#   'super',
#   'tuesday',
#   'state',
#   'already',
#   'voted',
#   'many',
#   'voter',
#   'still',
#   'making',
#   'mind',
#   'cast',
#   'ballot',
#   'election',
#   'day',
#   'south',
#   'carolina',
#   'could',
#   'important',
#   'marker',
#   'happens',
#   'becca',
#   'siegel',
#   'campaign',
#   'chief',
#   'analytics',
#   'officer',
#   'related',
#   'bernie',
#   'aim',
#   'tax',
#   'hike',
#   'executive',
#   'retirement',
#   'plan',
#   'bernie',
#   'win',
#   'hampshire',
#   'primary',
#   'bernie',
#   'presidency',
#   'mean',
#   'business',
#   'received',
#   'boost',
#   'week',
#   'endorsed',
#   'james',
#   'clyburn',
#   'south',
#   'carolina',
#   'lawmaker',
#   'house',
#   'picked',
#   'support',
#   'friday',
#   'tim',
#   'kaine',
#   'virginia',
#   'former',
#   'governor',
#   'served',
#   'hillary',
#   'clinton',
#   'running',
#   'mate',
#   'campaign',
#   'launched',
#   'million',
#   'broadcast',
#   'digital',
#   'ad',
#   'buy',
#   'eight',
#   'state',
#   'amount',
#   'well',
#   'behind',
#   'many',
#   'rival',
#   'bloomberg',
#   'spent',
#   'million',
#   'tv',
#   'radio',
#   'advertising',
#   'state',
#   'billionaire',
#   'businessman',
#   'tom',
#   'steyer',
#   'spent',
#   'million',
#   'spent',
#   'nearly',
#   'million',
#   'according',
#   'data',
#   'division',
#   'pick',
#   'nominee',
#   'secures',
#   'majority',
#   'delegate',
#   'also',
#   'pitted',
#   'field',
#   'stood',
#   'alone',
#   'arguing',
#   'candidate',
#   'vote',
#   'top',
#   'even',
#   'individual',
#   'fails',
#   'win',
#   'majority',
#   'pledged',
#   'delegate',
#   'rival',
#   'nominee',
#   'chosen',
#   'democratic',
#   'convention',
#   'july',
#   'candidate',
#   'achieves',
#   'majority',
#   'delegate',
#   'primary',
#   'caucus',
#   'person',
#   'win',
#   'delegate',
#   'vote',
#   'nominee',
#   'ari',
#   'deputy',
#   'campaign',
#   'manager',
#   'democratic',
#   'national',
#   'committee',
#   'rule',
#   'stipulate',
#   'nominee',
#   'must',
#   'win',
#   'majority',
#   'delegate',
#   'doe',
#   'delegate',
#   'free',
#   'support',
#   'candidate',
#   'vote',
#   'mostly',
#   'party',
#   'insider',
#   'elected',
#   'weigh',
#   'speaking',
#   'cnn',
#   'town',
#   'hall',
#   'wednesday',
#   'warren',
#   'accused',
#   'reversing',
#   'position',
#   'argued',
#   'nomination',
#   'awarded',
#   'candidate',
#   'plurality',
#   'delegate',
#   'see',
#   'rule',
#   'know',
#   'everybody',
#   'stand',
#   'stick',
#   'rule',
#   'warren',
#   'warren',
#   'added',
#   'prepared',
#   'stay',
#   'race',
#   'fight',
#   'convention',
#   'floor',
#   'bloomberg',
#   'also',
#   'laying',
#   'groundwork',
#   'divided',
#   'convention',
#   'quietly',
#   'reaching',
#   'party',
#   'leader',
#   'donor',
#   'bid',
#   'corral',
#   'support',
#   'nominating',
#   'contest',
#   'go',
#   'ballot',
#   'according',
#   'people',
#   'familiar',
#   'matter',
#   'dynamic',
#   'drawn',
#   'contrast',
#   'insurgent',
#   'campaign',
#   'shocked',
#   'republican',
#   'establishment',
#   'similarly',
#   'left',
#   'crowded',
#   'field',
#   'rival',
#   'pinning',
#   'hope',
#   'brokered',
#   'convention',
#   'scenario',
#   'never',
#   'came',
#   'pas',
#   'terry',
#   'sullivan',
#   'former',
#   'senior',
#   'adviser',
#   'florida',
#   'marco',
#   'rubio',
#   'presidential',
#   'campaign',
#   'contested',
#   'convention',
#   'wishful',
#   'thinking',
#   'democrat',
#   'hanging',
#   'onto',
#   'thread',
#   'like',
#   'hanging',
#   'onto',
#   'hope',
#   'prayer',
#   'go',
#   'contested',
#   'convention',
#   'guy',
#   'gal',
#   'people',
#   'turn',
#   'end',
#   'day',
#   'bernie',
#   'lose',
#   'added',
#   'chad',
#   'day',
#   'contributed',
#   'sabrina',
#   'siddiqui',
#   'ken',
#   'thomas',
#   'sabrina',
#   'siddiqui',
#   'raleigh',
#   'ken',
#   'thomas',
#   'conway'],
#  ['many',
#   'voter',
#   'going',
#   'poll',
#   'tuesday',
#   'three',
#   'state',
#   'trip',
#   'time',
#   'home',
#   'since',
#   'started',
#   'practicing',
#   'social',
#   'distancing',
#   'deal',
#   'coronavirus',
#   'pandemic',
#   'successful',
#   'casting',
#   'hand',
#   'sanitizer',
#   'ready',
#   'others',
#   'trouble',
#   'even',
#   'locating',
#   'operating',
#   'polling',
#   'site',
#   'mike',
#   'kontos',
#   'agent',
#   'cast',
#   'ballot',
#   'fire',
#   'station',
#   'miami',
#   'voted',
#   'former',
#   'vice',
#   'president',
#   'joe',
#   'glove',
#   'disinfectant',
#   'wipe',
#   'brought',
#   'cooped',
#   'home',
#   'several',
#   'day',
#   'could',
#   'boosted',
#   'administration',
#   'handling',
#   'coronavirus',
#   'outbreak',
#   'play',
#   'could',
#   'good',
#   'chance',
#   'kontos',
#   'voter',
#   'trickled',
#   'polling',
#   'site',
#   'line',
#   'least',
#   'five',
#   'state',
#   'postponed',
#   'primary',
#   'pandemic',
#   'voter',
#   'florida',
#   'illinois',
#   'arizona',
#   'headed',
#   'poll',
#   'tuesday',
#   'many',
#   'county',
#   'reporting',
#   'low',
#   'turnout',
#   'voting',
#   'ohio',
#   'primary',
#   'also',
#   'scheduled',
#   'tuesday',
#   'governor',
#   'postponed',
#   'voting',
#   'polling',
#   'place',
#   'closed',
#   'democratic',
#   'presidential',
#   'primary',
#   'field',
#   'narrowed',
#   'recent',
#   'week',
#   'vermont',
#   'bernie',
#   'poll',
#   'three',
#   'state',
#   'shown',
#   'lead',
#   'stephen',
#   'watson',
#   'executive',
#   'also',
#   'voted',
#   'miami',
#   'trip',
#   'polling',
#   'station',
#   'outing',
#   'week',
#   'symptom',
#   'consistent',
#   'disease',
#   'caused',
#   'coronavirus',
#   'temperature',
#   'degree',
#   'cough',
#   'shortness',
#   'breath',
#   'able',
#   'confirm',
#   'virus',
#   'could',
#   'get',
#   'tested',
#   'watson',
#   'also',
#   'voted',
#   'need',
#   'revolution',
#   'echoing',
#   'line',
#   'need',
#   'good',
#   'leadership',
#   'illinois',
#   'widespread',
#   'report',
#   'voter',
#   'able',
#   'cast',
#   'ballot',
#   'polling',
#   'place',
#   'closed',
#   'election',
#   'judge',
#   'found',
#   'handwritten',
#   'sign',
#   'telling',
#   'polling',
#   'site',
#   'closed',
#   'posted',
#   'photo',
#   'social',
#   'medium',
#   'election',
#   'organizer',
#   'scrambling',
#   'find',
#   'worker',
#   'chicago',
#   'suburban',
#   'county',
#   'hundred',
#   'dropped',
#   'concern',
#   'virus',
#   'matthew',
#   'lindner',
#   'work',
#   'marketing',
#   'chicago',
#   'polling',
#   'site',
#   'moved',
#   'senior',
#   'citizen',
#   'home',
#   'church',
#   'neighborhood',
#   'communication',
#   'election',
#   'official',
#   'change',
#   'sign',
#   'senior',
#   'citizen',
#   'home',
#   'election',
#   'website',
#   'confirmed',
#   'location',
#   'got',
#   'church',
#   'vote',
#   'poll',
#   'worker',
#   'told',
#   'voting',
#   'made',
#   'site',
#   'yet',
#   'livid',
#   'state',
#   'election',
#   'chicago',
#   'think',
#   'related',
#   'pandemic',
#   'never',
#   'seen',
#   'anything',
#   'like',
#   'lindner',
#   'returned',
#   'polling',
#   'site',
#   'five',
#   'hour',
#   'later',
#   'cast',
#   'ballot',
#   'equipment',
#   'arrived',
#   'le',
#   'hour',
#   'dozen',
#   'people',
#   'spaced',
#   'foot',
#   'apart',
#   'hand',
#   'sanitizer',
#   'sight',
#   'reached',
#   'front',
#   'line',
#   'others',
#   'told',
#   'precinct',
#   'moved',
#   'local',
#   'library',
#   'ladonna',
#   'miller',
#   'clinical',
#   'counselor',
#   'chicago',
#   'voted',
#   'early',
#   'monday',
#   'hearing',
#   'official',
#   'still',
#   'trying',
#   'find',
#   'enough',
#   'election',
#   'worker',
#   'tuesday',
#   'shortage',
#   'judge',
#   'fear',
#   'polling',
#   'place',
#   'properly',
#   'staffed',
#   'miller',
#   'waited',
#   'hour',
#   'line',
#   'voter',
#   'grew',
#   'concerned',
#   'condition',
#   'faced',
#   'clustered',
#   'together',
#   'following',
#   'center',
#   'disease',
#   'control',
#   'prevention',
#   'guideline',
#   'christina',
#   'cosentino',
#   'graduate',
#   'student',
#   'joliet',
#   'decided',
#   'mail',
#   'ballot',
#   'instead',
#   'going',
#   'poll',
#   'outbreak',
#   'actually',
#   'know',
#   'people',
#   'voted',
#   'today',
#   'wsj',
#   'newsletter',
#   'get',
#   'coronavirus',
#   'briefing',
#   'weekday',
#   'plus',
#   'update',
#   'friday',
#   'sign',
#   'tarini',
#   'parti',
#   'arian',
#   'tarini',
#   'parti',
#   'washington',
#   'arian',
#   'miami']]

# %%
WSJ_tokens[0:5]
# Out:
# [['increasingly',
#   'strict',
#   'measure',
#   'designed',
#   'slow',
#   'spread',
#   'coronavirus',
#   'raising',
#   'concern',
#   'feasibility',
#   'holding',
#   'remaining',
#   'democratic',
#   'presidential',
#   'primary',
#   'contest',
#   'well',
#   'logistics',
#   'holding',
#   'november',
#   'general',
#   'election',
#   'pandemic',
#   'still',
#   'nation',
#   'election',
#   'complicated',
#   'thicket',
#   'state',
#   'federal',
#   'law',
#   'process',
#   'selecting',
#   'presidential',
#   'nominee',
#   'complicated',
#   'fact',
#   'political',
#   'party',
#   'private',
#   'organization',
#   'set',
#   'internal',
#   'rule',
#   'depending',
#   'jurisdiction',
#   'state',
#   'official',
#   'party',
#   'leader',
#   'flexibility',
#   'altering',
#   'date',
#   'possibly',
#   'format',
#   'remaining',
#   'presidential',
#   'primary',
#   'contest',
#   'response',
#   'growing',
#   'pandemic',
#   'expert',
#   'say',
#   'five',
#   'state',
#   'already',
#   'done',
#   'ohio',
#   'brief',
#   'struggle',
#   'governor',
#   'state',
#   'supreme',
#   'court',
#   'voting',
#   'follow',
#   'pandemic',
#   'persists',
#   'fall',
#   'official',
#   'fear',
#   'could',
#   'congress',
#   'need',
#   'step',
#   'picture',
#   'significant',
#   'alteration',
#   'general',
#   'election',
#   'date',
#   'date',
#   'fixed',
#   'tuesday',
#   'act',
#   'congress',
#   'president',
#   'state',
#   'election',
#   'absent',
#   'legislation',
#   'court',
#   'granted',
#   'strong',
#   'protection',
#   'citizen',
#   'cast',
#   'ballot',
#   'even',
#   'order',
#   'official',
#   'sweeping',
#   'emergency',
#   'authority',
#   'level',
#   'government',
#   'limit',
#   'gathering',
#   'impose',
#   'quarantine',
#   'could',
#   'trumped',
#   'think',
#   'state',
#   'authority',
#   'reasonable',
#   'measure',
#   'ensure',
#   'public',
#   'safety',
#   'ultimately',
#   'yield',
#   'vote',
#   'marc',
#   'elia',
#   'democratic',
#   'election',
#   'lawyer',
#   'worked',
#   'numerous',
#   'presidential',
#   'campaign',
#   'democratic',
#   'primary',
#   'contest',
#   'already',
#   'affected',
#   'virus',
#   'tuesday',
#   'joe',
#   'defeated',
#   'bernie',
#   'trio',
#   'state',
#   'turnout',
#   'level',
#   'appeared',
#   'low',
#   'compared',
#   'similar',
#   'contest',
#   'held',
#   'past',
#   'wall',
#   'street',
#   'journal',
#   'reported',
#   'many',
#   'voter',
#   'venturing',
#   'home',
#   'time',
#   'day',
#   'cast',
#   'ballot',
#   'pandemic',
#   'abate',
#   'coming',
#   'week',
#   'asia',
#   'life',
#   'slowly',
#   'returning',
#   'normal',
#   'early',
#   'outbreak',
#   'site',
#   'like',
#   'china',
#   'doe',
#   'diminish',
#   'return',
#   'fall',
#   'election',
#   'official',
#   'already',
#   'expressed',
#   'concern',
#   'might',
#   'hold',
#   'general',
#   'election',
#   'middle',
#   'deadly',
#   'virus',
#   'whether',
#   'extremely',
#   'election',
#   'seen',
#   'legitimate',
#   'voter',
#   'logistics',
#   'holding',
#   'election',
#   'raise',
#   'additional',
#   'concern',
#   'reliable',
#   'voter',
#   'elderly',
#   'group',
#   'risk',
#   'coronavirus',
#   'complication',
#   'addition',
#   'many',
#   'poll',
#   'worker',
#   'volunteer',
#   'staff',
#   'election',
#   'across',
#   'country',
#   'older',
#   'election',
#   'assistance',
#   'commission',
#   'found',
#   'poll',
#   'worker',
#   'age',
#   'coronavirus',
#   'newsletter',
#   'get',
#   'morning',
#   'coronavirus',
#   'briefing',
#   'weekday',
#   'plus',
#   'update',
#   'friday',
#   'sign',
#   'proposal',
#   'congress',
#   'mandate',
#   'state',
#   'expand',
#   'program',
#   'voter',
#   'limiting',
#   'need',
#   'sen',
#   'ron',
#   'wyden',
#   'amy',
#   'klobuchar',
#   'proposed',
#   'bill',
#   'also',
#   'provide',
#   'million',
#   'grant',
#   'state',
#   'prepaid',
#   'postage',
#   'equipment',
#   'upgrade',
#   'virtually',
#   'every',
#   'state',
#   'already',
#   'today',
#   'absentee',
#   'ballot',
#   'arrangement',
#   'klobuchar',
#   'making',
#   'significant',
#   'amount',
#   'federal',
#   'fund',
#   'state',
#   'move',
#   'ensure',
#   'fall',
#   'middle',
#   'pandemic',
#   'american',
#   'voter',
#   'going',
#   'forced',
#   'choose',
#   'health',
#   'voting',
#   'wyden',
#   'msnbc',
#   'week',
#   'ample',
#   'precedent',
#   'action',
#   'congress',
#   'previously',
#   'mandated',
#   'state',
#   'allow',
#   'military',
#   'voter',
#   'cast',
#   'absentee',
#   'ballot',
#   'mail',
#   'state',
#   'allow',
#   'voter',
#   'register',
#   'renewing',
#   'obtaining',
#   'driver',
#   'example',
#   'state',
#   'plus',
#   'washington',
#   'allow',
#   'voter',
#   'cast',
#   'ballot',
#   'reason',
#   'place',
#   'reason',
#   'requesting',
#   'ballot',
#   'vote',
#   'mail',
#   'controversial',
#   'though',
#   'liberal',
#   'activist',
#   'believe',
#   'dampens',
#   'turnout',
#   'among',
#   'demographic',
#   'group',
#   'concern',
#   'program',
#   'include',
#   'paid',
#   'postage',
#   'conservative',
#   'additional',
#   'concern',
#   'fraud',
#   'ballot',
#   'simply',
#   'support',
#   'single',
#   'nationwide',
#   'election',
#   'day',
#   'even',
#   'opponent',
#   'universal',
#   'say',
#   'year',
#   'might',
#   'exception',
#   'particularly',
#   'important',
#   'balloting',
#   'run',
#   'orderly',
#   'legitimate',
#   'personally',
#   'think',
#   'extensive',
#   'voting',
#   'mail',
#   'good',
#   'idea',
#   'hate',
#   'see',
#   'crisis',
#   'sneak',
#   'permanent',
#   'voting',
#   'mail',
#   'bradley',
#   'smith',
#   'former',
#   'republican',
#   'appointee',
#   'federal',
#   'election',
#   'commission',
#   'teach',
#   'capital',
#   'university',
#   'law',
#   'school',
#   'election',
#   'think',
#   'probably',
#   'good',
#   'current',
#   'circumstance',
#   'congress',
#   'pas',
#   'limited',
#   'legislation',
#   'providing',
#   'kind',
#   'byron',
#   'tau',
#   'byron',
#   'tau'],
#  ['official',
#   'informed',
#   'bernie',
#   'russia',
#   'actively',
#   'trying',
#   'support',
#   'campaign',
#   'democratic',
#   'nomination',
#   'part',
#   'moscow',
#   'broader',
#   'effort',
#   'interfere',
#   'election',
#   'according',
#   'people',
#   'familiar',
#   'matter',
#   'president',
#   'small',
#   'number',
#   'lawmaker',
#   'briefed',
#   'intelligence',
#   'people',
#   'classified',
#   'fbi',
#   'briefing',
#   'type',
#   'routinely',
#   'given',
#   'presidential',
#   'campaign',
#   'election',
#   'security',
#   'people',
#   'given',
#   'reaction',
#   'intelligence',
#   'considered',
#   'compelling',
#   'enough',
#   'needed',
#   'alerted',
#   'people',
#   'intelligence',
#   'suggested',
#   'russian',
#   'effort',
#   'bolster',
#   'approached',
#   'scale',
#   'scope',
#   'operation',
#   'support',
#   'campaign',
#   'person',
#   'washington',
#   'post',
#   'earlier',
#   'reported',
#   'received',
#   'briefing',
#   'russia',
#   'seeking',
#   'support',
#   'primary',
#   'speaking',
#   'reporter',
#   'friday',
#   'acknowledged',
#   'briefing',
#   'taken',
#   'place',
#   'clear',
#   'role',
#   'russia',
#   'attempting',
#   'play',
#   'election',
#   'told',
#   'russia',
#   'maybe',
#   'country',
#   'getting',
#   'involved',
#   'campaign',
#   'told',
#   'reporter',
#   'bakersfield',
#   'look',
#   'message',
#   'russia',
#   'american',
#   'election',
#   'criticized',
#   'online',
#   'vitriol',
#   'supporter',
#   'directed',
#   'opponent',
#   'also',
#   'statement',
#   'possible',
#   'ugly',
#   'stuff',
#   'attributed',
#   'campaign',
#   'actually',
#   'coming',
#   'fake',
#   'internet',
#   'account',
#   'office',
#   'director',
#   'national',
#   'intelligence',
#   'federal',
#   'bureau',
#   'investigation',
#   'department',
#   'homeland',
#   'security',
#   'declined',
#   'comment',
#   'report',
#   'emerged',
#   'month',
#   'briefing',
#   'day',
#   'nevada',
#   'caucus',
#   'currently',
#   'leading',
#   'democratic',
#   'rival',
#   'national',
#   'poll',
#   'following',
#   'finish',
#   'hampshire',
#   'primary',
#   'month',
#   'poll',
#   'suggested',
#   'positioned',
#   'strong',
#   'finish',
#   'nevada',
#   'let',
#   'guess',
#   'day',
#   'nevada',
#   'caucus',
#   'think',
#   'came',
#   'asked',
#   'last',
#   'week',
#   'intelligence',
#   'official',
#   'told',
#   'president',
#   'lawmaker',
#   'house',
#   'intelligence',
#   'committee',
#   'russia',
#   'apparent',
#   'preference',
#   'according',
#   'people',
#   'familiar',
#   'matter',
#   'oval',
#   'office',
#   'meeting',
#   'lashed',
#   'joseph',
#   'maguire',
#   'acting',
#   'director',
#   'national',
#   'intelligence',
#   'replaced',
#   'week',
#   'irate',
#   'lawmaker',
#   'received',
#   'information',
#   'people',
#   'president',
#   'also',
#   'agitated',
#   'intelligence',
#   'indicated',
#   'russia',
#   'seek',
#   'support',
#   'electoral',
#   'prospect',
#   'fall',
#   'could',
#   'determined',
#   'moscow',
#   'precise',
#   'motive',
#   'effort',
#   'support',
#   'social',
#   'medium',
#   'people',
#   'familiar',
#   'matter',
#   'russia',
#   'repeatedly',
#   'denied',
#   'interfering',
#   'election',
#   'campaign',
#   'rally',
#   'la',
#   'vega',
#   'friday',
#   'dismissed',
#   'report',
#   'intelligence',
#   'agency',
#   'believe',
#   'russia',
#   'interfere',
#   'year',
#   'behalf',
#   'calling',
#   'disinformation',
#   'russian',
#   'president',
#   'vladimir',
#   'putin',
#   'wait',
#   'democrat',
#   'pick',
#   'nominee',
#   'bernie',
#   'honeymooned',
#   'moscow',
#   'asked',
#   'president',
#   'remark',
#   'emerged',
#   'report',
#   'democratic',
#   'candidate',
#   'warned',
#   'moscow',
#   'interest',
#   'aiding',
#   'campaign',
#   'sequence',
#   'pointed',
#   'campaign',
#   'wife',
#   'traveled',
#   'russia',
#   'delegation',
#   'burlington',
#   'mayor',
#   'establish',
#   'program',
#   'city',
#   'yaroslavl',
#   'also',
#   'celebrated',
#   'honeymoon',
#   'intelligence',
#   'official',
#   'warning',
#   'year',
#   'russia',
#   'others',
#   'likely',
#   'seek',
#   'interfere',
#   'contest',
#   'former',
#   'special',
#   'counsel',
#   'robert',
#   'mueller',
#   'investigation',
#   'found',
#   'russia',
#   'interfered',
#   'sweeping',
#   'systematic',
#   'fashion',
#   'presidential',
#   'election',
#   'help',
#   'denigrate',
#   'democratic',
#   'challenger',
#   'hillary',
#   'clinton',
#   'mueller',
#   'probe',
#   'also',
#   'found',
#   'russian',
#   'intelligence',
#   'operative',
#   'spreading',
#   'propaganda',
#   'social',
#   'medium',
#   'also',
#   'showed',
#   'favoritism',
#   'opportunity',
#   'criticize',
#   'hillary',
#   'except',
#   'support',
#   'russian',
#   'operative',
#   'quoting',
#   'saying',
#   'indictment',
#   'elizabeth',
#   'warren',
#   'rival',
#   'democratic',
#   'nomination',
#   'told',
#   'reporter',
#   'friday',
#   'received',
#   'similar',
#   'briefing',
#   'believe',
#   'need',
#   'much',
#   'transparency',
#   'possible',
#   'russian',
#   'interference',
#   'understand',
#   'disinformation',
#   'fight',
#   'disinformation',
#   'call',
#   'give',
#   'everyone',
#   'information',
#   'quickly',
#   'possible',
#   'otherwise',
#   'russian',
#   'continue',
#   'much',
#   'influence',
#   'campaign',
#   'fight',
#   'national',
#   'security',
#   'official',
#   'struggled',
#   'respond',
#   'indication',
#   'foreign',
#   'adversary',
#   'meddling',
#   'election',
#   'obama',
#   'administration',
#   'criticized',
#   'republican',
#   'democrat',
#   'alike',
#   'disclosing',
#   'public',
#   'russia',
#   'interference',
#   'november',
#   'administration',
#   'outlined',
#   'plan',
#   'notify',
#   'public',
#   'campaign',
#   'foreign',
#   'election',
#   'interference',
#   'framework',
#   'received',
#   'criticism',
#   'election',
#   'official',
#   'vague',
#   'democrat',
#   'argued',
#   'could',
#   'allow',
#   'political',
#   'influence',
#   'notification',
#   'decision',
#   'made',
#   'interest',
#   'protect',
#   'integrity',
#   'political',
#   'social',
#   'discourse',
#   'according',
#   'public',
#   'summary',
#   'framework',
#   'joshua',
#   'jamerson',
#   'rebecca',
#   'ballhaus',
#   'eliza',
#   'collins',
#   'contributed',
#   'dustin',
#   'volz',
#   'dustin',
#   'volz'],
#  ['coronavirus',
#   'pandemic',
#   'jolting',
#   'political',
#   'debate',
#   'health',
#   'care',
#   'election',
#   'campaign',
#   'democrat',
#   'arguing',
#   'crisis',
#   'damage',
#   'administration',
#   'done',
#   'safety',
#   'net',
#   'need',
#   'federal',
#   'role',
#   'providing',
#   'coverage',
#   'health',
#   'care',
#   'already',
#   'top',
#   'issue',
#   'voter',
#   'virus',
#   'began',
#   'spreading',
#   'case',
#   'across',
#   'state',
#   'washington',
#   'coronavirus',
#   'providing',
#   'platform',
#   'democrat',
#   'highlight',
#   'high',
#   'medical',
#   'cost',
#   'lack',
#   'coverage',
#   'say',
#   'policy',
#   'proposal',
#   'fix',
#   'democratic',
#   'presidential',
#   'candidate',
#   'expected',
#   'criticize',
#   'president',
#   'response',
#   'virus',
#   'sunday',
#   'night',
#   'debate',
#   'administration',
#   'official',
#   'counter',
#   'expanded',
#   'access',
#   'affordable',
#   'plan',
#   'campaign',
#   'sought',
#   'criticize',
#   'polarizing',
#   'aspect',
#   'democratic',
#   'rival',
#   'health',
#   'plan',
#   'coverage',
#   'undocumented',
#   'immigrant',
#   'bernie',
#   'joe',
#   'side',
#   'extreme',
#   'coin',
#   'campaign',
#   'tweeted',
#   'march',
#   'support',
#   'making',
#   'american',
#   'family',
#   'worker',
#   'pay',
#   'health',
#   'care',
#   'illegal',
#   'alien',
#   'democrat',
#   'argue',
#   'administration',
#   'change',
#   'affordable',
#   'care',
#   'act',
#   'weakened',
#   'coverage',
#   'million',
#   'american',
#   'could',
#   'leave',
#   'people',
#   'need',
#   'treatment',
#   'coronavirus',
#   'high',
#   'bill',
#   'point',
#   'expansion',
#   'health',
#   'plan',
#   'deny',
#   'coverage',
#   'cover',
#   'aca',
#   'minimum',
#   'benefit',
#   'well',
#   'administration',
#   'plan',
#   'back',
#   'state',
#   'change',
#   'medicaid',
#   'federal',
#   'funding',
#   'limited',
#   'block',
#   'grant',
#   'democrat',
#   'say',
#   'hurt',
#   'enrollment',
#   'republican',
#   'praised',
#   'administration',
#   'response',
#   'action',
#   'say',
#   'white',
#   'house',
#   'taken',
#   'health',
#   'coverage',
#   'affordable',
#   'accused',
#   'democrat',
#   'coronavirus',
#   'score',
#   'political',
#   'point',
#   'mark',
#   'meadow',
#   'set',
#   'chief',
#   'staff',
#   'tweet',
#   'left',
#   'control',
#   'health',
#   'care',
#   'reference',
#   'coronavirus',
#   'recently',
#   'started',
#   'appear',
#   'political',
#   'advertising',
#   'group',
#   'aligned',
#   'democrat',
#   'try',
#   'leverage',
#   'topic',
#   'tv',
#   'ad',
#   'mention',
#   'virus',
#   'critical',
#   'republican',
#   'steve',
#   'daines',
#   'appeared',
#   'montana',
#   'thursday',
#   'data',
#   'firm',
#   'spot',
#   'sponsored',
#   'protect',
#   'care',
#   'group',
#   'support',
#   'affordable',
#   'care',
#   'act',
#   'many',
#   'montana',
#   'family',
#   'go',
#   'sleep',
#   'night',
#   'worried',
#   'health',
#   'care',
#   'coverage',
#   'cost',
#   'fear',
#   'coronavirus',
#   'say',
#   'ad',
#   'run',
#   'time',
#   'billing',
#   'missoula',
#   'thursday',
#   'absolutely',
#   'going',
#   'topic',
#   'ken',
#   'goldstein',
#   'university',
#   'san',
#   'francisco',
#   'professor',
#   'studied',
#   'campaign',
#   'advertising',
#   'decade',
#   'question',
#   'campaign',
#   'strategist',
#   'ad',
#   'maker',
#   'topic',
#   'topic',
#   'share',
#   'thought',
#   'might',
#   'democratic',
#   'plan',
#   'benefit',
#   'american',
#   'health',
#   'crisis',
#   'join',
#   'conversation',
#   'time',
#   'american',
#   'many',
#   'concern',
#   'related',
#   'outbreak',
#   'mind',
#   'running',
#   'political',
#   'ad',
#   'outbreak',
#   'advantage',
#   'disadvantage',
#   'best',
#   'time',
#   'inject',
#   'political',
#   'message',
#   'goldstein',
#   'hand',
#   'people',
#   'going',
#   'watching',
#   'lot',
#   'television',
#   'internet',
#   'seeing',
#   'ad',
#   'see',
#   'record',
#   'internet',
#   'usage',
#   'video',
#   'usage',
#   'tv',
#   'rating',
#   'democratic',
#   'presidential',
#   'candidate',
#   'offensive',
#   'campaign',
#   'trail',
#   'bernie',
#   'vermont',
#   'proponent',
#   'medicare',
#   'march',
#   'rally',
#   'coronavirus',
#   'outbreak',
#   'insanity',
#   'people',
#   'ca',
#   'afford',
#   'see',
#   'doctor',
#   'former',
#   'vice',
#   'president',
#   'joe',
#   'pushed',
#   'plan',
#   'expand',
#   'aca',
#   'add',
#   'option',
#   'people',
#   'buy',
#   'federal',
#   'health',
#   'plan',
#   'blamed',
#   'taking',
#   'step',
#   'weaken',
#   'health',
#   'protecting',
#   'health',
#   'safety',
#   'american',
#   'people',
#   'important',
#   'job',
#   'unfortunately',
#   'virus',
#   'laid',
#   'bare',
#   'severe',
#   'shortcoming',
#   'current',
#   'administration',
#   'thursday',
#   'government',
#   'ability',
#   'respond',
#   'effectively',
#   'undermined',
#   'agency',
#   'disparagement',
#   'billionaire',
#   'former',
#   'york',
#   'mayor',
#   'michael',
#   'bloomberg',
#   'among',
#   'virus',
#   'tv',
#   'ad',
#   'part',
#   'political',
#   'campaign',
#   'ran',
#   'different',
#   'spot',
#   'topic',
#   'three',
#   'minute',
#   'long',
#   'dropped',
#   'democratic',
#   'presidential',
#   'primary',
#   'support',
#   'aca',
#   'grew',
#   'american',
#   'february',
#   'highest',
#   'since',
#   'law',
#   'enacted',
#   'year',
#   'ago',
#   'according',
#   'kaiser',
#   'family',
#   'foundation',
#   'support',
#   'also',
#   'october',
#   'coronavirus',
#   'case',
#   'emerged',
#   'democratic',
#   'congressional',
#   'campaign',
#   'committee',
#   'ran',
#   'digital',
#   'ad',
#   'critical',
#   'official',
#   'initially',
#   'declined',
#   'ensure',
#   'vaccine',
#   'affordable',
#   'house',
#   'minority',
#   'leader',
#   'kevin',
#   'mccarthy',
#   'california',
#   'criticized',
#   'ad',
#   'playing',
#   'politics',
#   'coronavirus',
#   'criticism',
#   'tap',
#   'growing',
#   'public',
#   'angst',
#   'virus',
#   'administration',
#   'response',
#   'people',
#   'see',
#   'making',
#   'easier',
#   'get',
#   'coronavirus',
#   'harder',
#   'get',
#   'health',
#   'care',
#   'jesse',
#   'ferguson',
#   'democratic',
#   'strategist',
#   'seems',
#   'like',
#   'challenging',
#   'agenda',
#   'sell',
#   'voter',
#   'according',
#   'quinnipiac',
#   'university',
#   'poll',
#   'released',
#   'march',
#   'voter',
#   'disapprove',
#   'handling',
#   'coronavirus',
#   'response',
#   'approve',
#   'sharp',
#   'divide',
#   'along',
#   'political',
#   'party',
#   'similar',
#   'president',
#   'overall',
#   'job',
#   'approval',
#   'rating',
#   'republican',
#   'approve',
#   'democrat',
#   'disapprove',
#   'independent',
#   'disapprove',
#   'stephanie',
#   'armour',
#   'john',
#   'mccormick'],
#  ['bernie',
#   'early',
#   'strength',
#   'putting',
#   'track',
#   'scoop',
#   'delegate',
#   'super',
#   'tuesday',
#   'photo',
#   'victor',
#   'j',
#   'blue',
#   'wall',
#   'street',
#   'journal',
#   'joe',
#   'betting',
#   'victory',
#   'south',
#   'carolina',
#   'revitalize',
#   'campaign',
#   'amy',
#   'klobuchar',
#   'say',
#   'still',
#   'momentum',
#   'hampshire',
#   'elizabeth',
#   'warren',
#   'belief',
#   'recent',
#   'debate',
#   'performance',
#   'gave',
#   'fresh',
#   'boost',
#   'pete',
#   'buttigieg',
#   'delegate',
#   'hunt',
#   'race',
#   'michael',
#   'bloomberg',
#   'ballot',
#   'series',
#   'state',
#   'spent',
#   'million',
#   'advertising',
#   'democratic',
#   'presidential',
#   'candidate',
#   'different',
#   'reason',
#   'staying',
#   'race',
#   'bound',
#   'common',
#   'goal',
#   'stop',
#   'bernie',
#   'amassing',
#   'majority',
#   'delegate',
#   'share',
#   'thought',
#   'think',
#   'many',
#   'democrat',
#   'remain',
#   'race',
#   'join',
#   'conversation',
#   'early',
#   'strength',
#   'centrist',
#   'rival',
#   'splitting',
#   'vote',
#   'doe',
#   'go',
#   'putting',
#   'vermont',
#   'senator',
#   'track',
#   'scoop',
#   'delegate',
#   'voter',
#   'across',
#   'state',
#   'territory',
#   'party',
#   'member',
#   'living',
#   'abroad',
#   'head',
#   'poll',
#   'march',
#   'known',
#   'super',
#   'tuesday',
#   'rise',
#   'fueled',
#   'concern',
#   'within',
#   'establishment',
#   'among',
#   'party',
#   'moderate',
#   'identity',
#   'democratic',
#   'socialist',
#   'liberal',
#   'policy',
#   'agenda',
#   'doom',
#   'democrat',
#   'general',
#   'election',
#   'say',
#   'beat',
#   'president',
#   'recent',
#   'wall',
#   'street',
#   'news',
#   'poll',
#   'winning',
#   'hypothetical',
#   'matchup',
#   'small',
#   'percentage',
#   'delegate',
#   'awarded',
#   'far',
#   'trajectory',
#   'change',
#   'another',
#   'candidate',
#   'could',
#   'overtake',
#   'maintains',
#   'lead',
#   'hoping',
#   'picking',
#   'delegate',
#   'needed',
#   'secure',
#   'nomination',
#   'outright',
#   'prompting',
#   'contested',
#   'summer',
#   'convention',
#   'milwaukee',
#   'another',
#   'candidate',
#   'could',
#   'emerge',
#   'top',
#   'tuesday',
#   'contest',
#   'represent',
#   'coming',
#   'test',
#   'could',
#   'determine',
#   'whether',
#   'cruise',
#   'commanding',
#   'delegate',
#   'lead',
#   'california',
#   'texas',
#   'biggest',
#   'delegate',
#   'prize',
#   'offer',
#   'combined',
#   'delegate',
#   'nearly',
#   'half',
#   'delegate',
#   'awarded',
#   'tuesday',
#   'leading',
#   'california',
#   'poll',
#   'near',
#   'top',
#   'texas',
#   'candidate',
#   'cross',
#   'threshold',
#   'necessary',
#   'earn',
#   'delegate',
#   'could',
#   'give',
#   'much',
#   'easier',
#   'path',
#   'multiple',
#   'people',
#   'win',
#   'delegate',
#   'state',
#   'elizabeth',
#   'warren',
#   'address',
#   'crowd',
#   'rally',
#   'greenville',
#   'friday',
#   'photo',
#   'victor',
#   'j',
#   'blue',
#   'wall',
#   'street',
#   'journal',
#   'winning',
#   'minimize',
#   'margin',
#   'super',
#   'tuesday',
#   'rack',
#   'delegate',
#   'following',
#   'contest',
#   'field',
#   'winnow',
#   'buttigieg',
#   'campaign',
#   'memo',
#   'released',
#   'week',
#   'coming',
#   'schedule',
#   'trying',
#   'thwart',
#   'challenger',
#   'senator',
#   'set',
#   'hold',
#   'rally',
#   'friday',
#   'saturday',
#   'massachusetts',
#   'warren',
#   'home',
#   'state',
#   'monday',
#   'klobuchar',
#   'home',
#   'state',
#   'minnesota',
#   'returning',
#   'home',
#   'vermont',
#   'three',
#   'march',
#   'primary',
#   'flexing',
#   'think',
#   'every',
#   'reason',
#   'ian',
#   'sam',
#   'worked',
#   'presidential',
#   'campaign',
#   'kamala',
#   'harris',
#   'hillary',
#   'clinton',
#   'really',
#   'put',
#   'elizabeth',
#   'amy',
#   'corner',
#   'say',
#   'ca',
#   'even',
#   'win',
#   'home',
#   'state',
#   'still',
#   'pressing',
#   'race',
#   'came',
#   'third',
#   'place',
#   'hampshire',
#   'campaigned',
#   'practical',
#   'scheduled',
#   'super',
#   'tuesday',
#   'night',
#   'party',
#   'paul',
#   'also',
#   'competing',
#   'state',
#   'colorado',
#   'north',
#   'carolina',
#   'tennessee',
#   'virginia',
#   'aide',
#   'warren',
#   'believe',
#   'fiery',
#   'performance',
#   'debate',
#   'la',
#   'vega',
#   'improved',
#   'standing',
#   'race',
#   'touted',
#   'fundraising',
#   'haul',
#   'million',
#   'month',
#   'warren',
#   'also',
#   'received',
#   'giant',
#   'lift',
#   'committee',
#   'supporting',
#   'campaign',
#   'known',
#   'persist',
#   'pac',
#   'announced',
#   'million',
#   'television',
#   'digital',
#   'ad',
#   'buy',
#   'late',
#   'thursday',
#   'ad',
#   'run',
#   'nine',
#   'medium',
#   'market',
#   'across',
#   'three',
#   'super',
#   'tuesday',
#   'state',
#   'california',
#   'massachusetts',
#   'texas',
#   'seeking',
#   'comeback',
#   'banking',
#   'south',
#   'carolina',
#   'help',
#   'give',
#   'momentum',
#   'aide',
#   'believe',
#   'strength',
#   'voter',
#   'half',
#   'democratic',
#   'primary',
#   'electorate',
#   'south',
#   'carolina',
#   'could',
#   'help',
#   'win',
#   'delegate',
#   'group',
#   'southern',
#   'state',
#   'voting',
#   'march',
#   'people',
#   'super',
#   'tuesday',
#   'state',
#   'already',
#   'voted',
#   'many',
#   'voter',
#   'still',
#   'making',
#   'mind',
#   'cast',
#   'ballot',
#   'election',
#   'day',
#   'south',
#   'carolina',
#   'could',
#   'important',
#   'marker',
#   'happens',
#   'becca',
#   'siegel',
#   'campaign',
#   'chief',
#   'analytics',
#   'officer',
#   'related',
#   'bernie',
#   'aim',
#   'tax',
#   'hike',
#   'executive',
#   'retirement',
#   'plan',
#   'bernie',
#   'win',
#   'hampshire',
#   'primary',
#   'bernie',
#   'presidency',
#   'mean',
#   'business',
#   'received',
#   'boost',
#   'week',
#   'endorsed',
#   'james',
#   'clyburn',
#   'south',
#   'carolina',
#   'lawmaker',
#   'house',
#   'picked',
#   'support',
#   'friday',
#   'tim',
#   'kaine',
#   'virginia',
#   'former',
#   'governor',
#   'served',
#   'hillary',
#   'clinton',
#   'running',
#   'mate',
#   'campaign',
#   'launched',
#   'million',
#   'broadcast',
#   'digital',
#   'ad',
#   'buy',
#   'eight',
#   'state',
#   'amount',
#   'well',
#   'behind',
#   'many',
#   'rival',
#   'bloomberg',
#   'spent',
#   'million',
#   'tv',
#   'radio',
#   'advertising',
#   'state',
#   'billionaire',
#   'businessman',
#   'tom',
#   'steyer',
#   'spent',
#   'million',
#   'spent',
#   'nearly',
#   'million',
#   'according',
#   'data',
#   'division',
#   'pick',
#   'nominee',
#   'secures',
#   'majority',
#   'delegate',
#   'also',
#   'pitted',
#   'field',
#   'stood',
#   'alone',
#   'arguing',
#   'candidate',
#   'vote',
#   'top',
#   'even',
#   'individual',
#   'fails',
#   'win',
#   'majority',
#   'pledged',
#   'delegate',
#   'rival',
#   'nominee',
#   'chosen',
#   'democratic',
#   'convention',
#   'july',
#   'candidate',
#   'achieves',
#   'majority',
#   'delegate',
#   'primary',
#   'caucus',
#   'person',
#   'win',
#   'delegate',
#   'vote',
#   'nominee',
#   'ari',
#   'deputy',
#   'campaign',
#   'manager',
#   'democratic',
#   'national',
#   'committee',
#   'rule',
#   'stipulate',
#   'nominee',
#   'must',
#   'win',
#   'majority',
#   'delegate',
#   'doe',
#   'delegate',
#   'free',
#   'support',
#   'candidate',
#   'vote',
#   'mostly',
#   'party',
#   'insider',
#   'elected',
#   'weigh',
#   'speaking',
#   'cnn',
#   'town',
#   'hall',
#   'wednesday',
#   'warren',
#   'accused',
#   'reversing',
#   'position',
#   'argued',
#   'nomination',
#   'awarded',
#   'candidate',
#   'plurality',
#   'delegate',
#   'see',
#   'rule',
#   'know',
#   'everybody',
#   'stand',
#   'stick',
#   'rule',
#   'warren',
#   'warren',
#   'added',
#   'prepared',
#   'stay',
#   'race',
#   'fight',
#   'convention',
#   'floor',
#   'bloomberg',
#   'also',
#   'laying',
#   'groundwork',
#   'divided',
#   'convention',
#   'quietly',
#   'reaching',
#   'party',
#   'leader',
#   'donor',
#   'bid',
#   'corral',
#   'support',
#   'nominating',
#   'contest',
#   'go',
#   'ballot',
#   'according',
#   'people',
#   'familiar',
#   'matter',
#   'dynamic',
#   'drawn',
#   'contrast',
#   'insurgent',
#   'campaign',
#   'shocked',
#   'republican',
#   'establishment',
#   'similarly',
#   'left',
#   'crowded',
#   'field',
#   'rival',
#   'pinning',
#   'hope',
#   'brokered',
#   'convention',
#   'scenario',
#   'never',
#   'came',
#   'pas',
#   'terry',
#   'sullivan',
#   'former',
#   'senior',
#   'adviser',
#   'florida',
#   'marco',
#   'rubio',
#   'presidential',
#   'campaign',
#   'contested',
#   'convention',
#   'wishful',
#   'thinking',
#   'democrat',
#   'hanging',
#   'onto',
#   'thread',
#   'like',
#   'hanging',
#   'onto',
#   'hope',
#   'prayer',
#   'go',
#   'contested',
#   'convention',
#   'guy',
#   'gal',
#   'people',
#   'turn',
#   'end',
#   'day',
#   'bernie',
#   'lose',
#   'added',
#   'chad',
#   'day',
#   'contributed',
#   'sabrina',
#   'siddiqui',
#   'ken',
#   'thomas',
#   'sabrina',
#   'siddiqui',
#   'raleigh',
#   'ken',
#   'thomas',
#   'conway'],
#  ['many',
#   'voter',
#   'going',
#   'poll',
#   'tuesday',
#   'three',
#   'state',
#   'trip',
#   'time',
#   'home',
#   'since',
#   'started',
#   'practicing',
#   'social',
#   'distancing',
#   'deal',
#   'coronavirus',
#   'pandemic',
#   'successful',
#   'casting',
#   'hand',
#   'sanitizer',
#   'ready',
#   'others',
#   'trouble',
#   'even',
#   'locating',
#   'operating',
#   'polling',
#   'site',
#   'mike',
#   'kontos',
#   'agent',
#   'cast',
#   'ballot',
#   'fire',
#   'station',
#   'miami',
#   'voted',
#   'former',
#   'vice',
#   'president',
#   'joe',
#   'glove',
#   'disinfectant',
#   'wipe',
#   'brought',
#   'cooped',
#   'home',
#   'several',
#   'day',
#   'could',
#   'boosted',
#   'administration',
#   'handling',
#   'coronavirus',
#   'outbreak',
#   'play',
#   'could',
#   'good',
#   'chance',
#   'kontos',
#   'voter',
#   'trickled',
#   'polling',
#   'site',
#   'line',
#   'least',
#   'five',
#   'state',
#   'postponed',
#   'primary',
#   'pandemic',
#   'voter',
#   'florida',
#   'illinois',
#   'arizona',
#   'headed',
#   'poll',
#   'tuesday',
#   'many',
#   'county',
#   'reporting',
#   'low',
#   'turnout',
#   'voting',
#   'ohio',
#   'primary',
#   'also',
#   'scheduled',
#   'tuesday',
#   'governor',
#   'postponed',
#   'voting',
#   'polling',
#   'place',
#   'closed',
#   'democratic',
#   'presidential',
#   'primary',
#   'field',
#   'narrowed',
#   'recent',
#   'week',
#   'vermont',
#   'bernie',
#   'poll',
#   'three',
#   'state',
#   'shown',
#   'lead',
#   'stephen',
#   'watson',
#   'executive',
#   'also',
#   'voted',
#   'miami',
#   'trip',
#   'polling',
#   'station',
#   'outing',
#   'week',
#   'symptom',
#   'consistent',
#   'disease',
#   'caused',
#   'coronavirus',
#   'temperature',
#   'degree',
#   'cough',
#   'shortness',
#   'breath',
#   'able',
#   'confirm',
#   'virus',
#   'could',
#   'get',
#   'tested',
#   'watson',
#   'also',
#   'voted',
#   'need',
#   'revolution',
#   'echoing',
#   'line',
#   'need',
#   'good',
#   'leadership',
#   'illinois',
#   'widespread',
#   'report',
#   'voter',
#   'able',
#   'cast',
#   'ballot',
#   'polling',
#   'place',
#   'closed',
#   'election',
#   'judge',
#   'found',
#   'handwritten',
#   'sign',
#   'telling',
#   'polling',
#   'site',
#   'closed',
#   'posted',
#   'photo',
#   'social',
#   'medium',
#   'election',
#   'organizer',
#   'scrambling',
#   'find',
#   'worker',
#   'chicago',
#   'suburban',
#   'county',
#   'hundred',
#   'dropped',
#   'concern',
#   'virus',
#   'matthew',
#   'lindner',
#   'work',
#   'marketing',
#   'chicago',
#   'polling',
#   'site',
#   'moved',
#   'senior',
#   'citizen',
#   'home',
#   'church',
#   'neighborhood',
#   'communication',
#   'election',
#   'official',
#   'change',
#   'sign',
#   'senior',
#   'citizen',
#   'home',
#   'election',
#   'website',
#   'confirmed',
#   'location',
#   'got',
#   'church',
#   'vote',
#   'poll',
#   'worker',
#   'told',
#   'voting',
#   'made',
#   'site',
#   'yet',
#   'livid',
#   'state',
#   'election',
#   'chicago',
#   'think',
#   'related',
#   'pandemic',
#   'never',
#   'seen',
#   'anything',
#   'like',
#   'lindner',
#   'returned',
#   'polling',
#   'site',
#   'five',
#   'hour',
#   'later',
#   'cast',
#   'ballot',
#   'equipment',
#   'arrived',
#   'le',
#   'hour',
#   'dozen',
#   'people',
#   'spaced',
#   'foot',
#   'apart',
#   'hand',
#   'sanitizer',
#   'sight',
#   'reached',
#   'front',
#   'line',
#   'others',
#   'told',
#   'precinct',
#   'moved',
#   'local',
#   'library',
#   'ladonna',
#   'miller',
#   'clinical',
#   'counselor',
#   'chicago',
#   'voted',
#   'early',
#   'monday',
#   'hearing',
#   'official',
#   'still',
#   'trying',
#   'find',
#   'enough',
#   'election',
#   'worker',
#   'tuesday',
#   'shortage',
#   'judge',
#   'fear',
#   'polling',
#   'place',
#   'properly',
#   'staffed',
#   'miller',
#   'waited',
#   'hour',
#   'line',
#   'voter',
#   'grew',
#   'concerned',
#   'condition',
#   'faced',
#   'clustered',
#   'together',
#   'following',
#   'center',
#   'disease',
#   'control',
#   'prevention',
#   'guideline',
#   'christina',
#   'cosentino',
#   'graduate',
#   'student',
#   'joliet',
#   'decided',
#   'mail',
#   'ballot',
#   'instead',
#   'going',
#   'poll',
#   'outbreak',
#   'actually',
#   'know',
#   'people',
#   'voted',
#   'today',
#   'wsj',
#   'newsletter',
#   'get',
#   'coronavirus',
#   'briefing',
#   'weekday',
#   'plus',
#   'update',
#   'friday',
#   'sign',
#   'tarini',
#   'parti',
#   'arian',
#   'tarini',
#   'parti',
#   'washington',
#   'arian',
#   'miami']]

# %%
# create empty dictionaries for each canididate

bernie_tokens_dict = {}
biden_tokens_dict = {}
trump_tokens_dict = {}

# %%
# create empty dictionaries for each canididate NYT

bernie_NYT_tokens_dict = {}
biden_NYT_tokens_dict = {}
trump_NYT_tokens_dict = {}

# %%
# create empty dictionaries for each canididate TWP

bernie_TWP_tokens_dict = {}
biden_TWP_tokens_dict = {}
trump_TWP_tokens_dict = {}

# %%
# create empty dictionaries for each canididate WSJ

bernie_WSJ_tokens_dict = {}
biden_WSJ_tokens_dict = {}
trump_WSJ_tokens_dict = {}

# %%
# create empty dictionaries for each news outlet

NYT_tokens_dict = {}
TWP_tokens_dict = {}
WSJ_tokens_dict = {}

# %%
# Create dictionaries with word frequency as value

for article in bernie_tokens:
    for words in article:
        if words in bernie_tokens_dict.keys():
            bernie_tokens_dict[words] += 1
        else:
            bernie_tokens_dict[words] = 1
        
for article in biden_tokens:
    for words in article:
        if words in biden_tokens_dict.keys():
            biden_tokens_dict[words] += 1
        else:
            biden_tokens_dict[words] = 1

for article in trump_tokens:
    for words in article:
        if words in trump_tokens_dict.keys():
            trump_tokens_dict[words] += 1
        else:
            trump_tokens_dict[words] = 1

# %%
# Create dictionaries with word frequency as value NYT

for article in bernie_NYT_tokens:
    for words in article:
        if words in bernie_NYT_tokens_dict.keys():
            bernie_NYT_tokens_dict[words] += 1
        else:
            bernie_NYT_tokens_dict[words] = 1
        
for article in biden_NYT_tokens:
    for words in article:
        if words in biden_NYT_tokens_dict.keys():
            biden_NYT_tokens_dict[words] += 1
        else:
            biden_NYT_tokens_dict[words] = 1

for article in trump_NYT_tokens:
    for words in article:
        if words in trump_NYT_tokens_dict.keys():
            trump_NYT_tokens_dict[words] += 1
        else:
            trump_NYT_tokens_dict[words] = 1

# %%
# Create dictionaries with word frequency as value _TWP

for article in bernie_TWP_tokens:
    for words in article:
        if words in bernie_TWP_tokens_dict.keys():
            bernie_TWP_tokens_dict[words] += 1
        else:
            bernie_TWP_tokens_dict[words] = 1
        
for article in biden_TWP_tokens:
    for words in article:
        if words in biden_TWP_tokens_dict.keys():
            biden_TWP_tokens_dict[words] += 1
        else:
            biden_TWP_tokens_dict[words] = 1

for article in trump_TWP_tokens:
    for words in article:
        if words in trump_TWP_tokens_dict.keys():
            trump_TWP_tokens_dict[words] += 1
        else:
            trump_TWP_tokens_dict[words] = 1

# %%
# Create dictionaries with word frequency as value _WSJ

for article in bernie_WSJ_tokens:
    for words in article:
        if words in bernie_WSJ_tokens_dict.keys():
            bernie_WSJ_tokens_dict[words] += 1
        else:
            bernie_WSJ_tokens_dict[words] = 1
        
for article in biden_WSJ_tokens:
    for words in article:
        if words in biden_WSJ_tokens_dict.keys():
            biden_WSJ_tokens_dict[words] += 1
        else:
            biden_WSJ_tokens_dict[words] = 1

for article in trump_WSJ_tokens:
    for words in article:
        if words in trump_WSJ_tokens_dict.keys():
            trump_WSJ_tokens_dict[words] += 1
        else:
            trump_WSJ_tokens_dict[words] = 1

# %%
# create dictionary with word frequency value for each news outlet
for article in NYT_tokens:
    for words in article:
        if words in NYT_tokens_dict.keys():
            NYT_tokens_dict[words] += 1
        else:
            NYT_tokens_dict[words] = 1
            
for article in TWP_tokens:
    for words in article:
        if words in TWP_tokens_dict.keys():
            TWP_tokens_dict[words] += 1
        else:
            TWP_tokens_dict[words] = 1
            
for article in WSJ_tokens:
    for words in article:
        if words in WSJ_tokens_dict.keys():
            WSJ_tokens_dict[words] += 1
        else:
            WSJ_tokens_dict[words] = 1

# %%
# take a look at dictionary
bernie_tokens_dict
# Out:
# {'hitas': 5,
#  'primary': 1390,
#  'race': 1068,
#  'becomes': 42,
#  'battle': 94,
#  'field': 313,
#  'suddenly': 26,
#  'seems': 85,
#  'constricting': 2,
#  'divisiveness': 10,
#  'negative': 61,
#  'attack': 348,
#  'tagged': 3,
#  'rival': 358,
#  'nickname': 6,
#  'like': 950,
#  'sleepy': 9,
#  'liddle': 1,
#  'push': 84,
#  'come': 346,
#  'shove': 5,
#  'democratic': 2661,
#  'candidate': 2284,
#  'surrogate': 98,
#  'descended': 8,
#  'level': 113,
#  'personal': 111,
#  'animus': 2,
#  'rare': 16,
#  'era': 47,
#  'president': 2156,
#  'monday': 315,
#  'joseph': 186,
#  'launched': 33,
#  'digital': 78,
#  'ad': 355,
#  'south': 730,
#  'carolina': 521,
#  'saying': 271,
#  'bernie': 1193,
#  'ca': 170,
#  'trusted': 15,
#  'weighing': 21,
#  'barack': 138,
#  'pete': 338,
#  'buttigieg': 1118,
#  'attacked': 49,
#  'victory': 343,
#  'nevada': 483,
#  'mayor': 565,
#  'bill': 157,
#  'de': 148,
#  'blasio': 7,
#  'york': 736,
#  'lectured': 1,
#  'twitter': 163,
#  'smug': 1,
#  'got': 223,
#  'kicked': 7,
#  'lest': 1,
#  'last': 749,
#  'week': 817,
#  'debate': 777,
#  'recede': 1,
#  'history': 163,
#  'five': 123,
#  'day': 706,
#  'ago': 245,
#  'memorable': 7,
#  'searing': 6,
#  'moment': 223,
#  'highly': 43,
#  'exchange': 52,
#  'amy': 271,
#  'klobuchar': 531,
#  'dripped': 1,
#  'contempt': 5,
#  'wish': 30,
#  'everyone': 87,
#  'perfect': 34,
#  'hunger': 5,
#  'game': 43,
#  'rising': 74,
#  'commanding': 20,
#  'win': 859,
#  'earned': 28,
#  'pledged': 57,
#  'delegate': 631,
#  'final': 175,
#  'result': 513,
#  'tallied': 2,
#  'taking': 123,
#  'nine': 44,
#  'three': 427,
#  'triggered': 16,
#  'alarm': 30,
#  'among': 690,
#  'official': 504,
#  'voter': 2045,
#  'moderate': 430,
#  'challenger': 42,
#  'sought': 130,
#  'vain': 1,
#  'another': 342,
#  'exit': 87,
#  'consolidate': 31,
#  'presidential': 887,
#  'certainly': 60,
#  'share': 233,
#  'campaigning': 110,
#  'much': 510,
#  'intraparty': 24,
#  'warfare': 7,
#  'used': 161,
#  'waged': 4,
#  'behind': 239,
#  'scene': 21,
#  'oppo': 2,
#  'dump': 2,
#  'compromising': 3,
#  'research': 96,
#  'opponent': 183,
#  'anonymous': 5,
#  'criticism': 142,
#  'newspaper': 12,
#  'story': 92,
#  'today': 103,
#  'combination': 11,
#  'social': 236,
#  'medium': 245,
#  'democratization': 1,
#  'habit': 8,
#  'lobbing': 2,
#  'nasty': 11,
#  'removed': 23,
#  'filter': 3,
#  'always': 120,
#  'tried': 111,
#  'stay': 106,
#  'never': 161,
#  'get': 515,
#  'deeply': 39,
#  'mud': 2,
#  'joe': 445,
#  'lockhart': 3,
#  'former': 1411,
#  'press': 104,
#  'secretary': 77,
#  'clinton': 486,
#  'changed': 64,
#  'modeled': 2,
#  'idea': 218,
#  'sharpest': 7,
#  'bottom': 25,
#  'saturday': 265,
#  'night': 449,
#  'tweeted': 86,
#  'dude': 7,
#  'humility': 2,
#  'immediately': 51,
#  'replied': 32,
#  'care': 413,
#  'think': 606,
#  'four': 356,
#  'year': 1123,
#  'interview': 198,
#  'phone': 94,
#  'reporter': 187,
#  'weigh': 14,
#  'mainstream': 33,
#  'acting': 35,
#  'gatekeeper': 3,
#  'might': 266,
#  'quoted': 9,
#  'ability': 91,
#  'people': 1167,
#  'platform': 97,
#  'back': 418,
#  'dinner': 33,
#  'david': 62,
#  'pepper': 6,
#  'chairman': 130,
#  'ohio': 122,
#  'party': 1859,
#  'lamented': 4,
#  'smashed': 1,
#  'record': 281,
#  'watched': 35,
#  'ever': 117,
#  'intensely': 10,
#  'worry': 103,
#  'looked': 39,
#  'mad': 6,
#  'every': 233,
#  'person': 188,
#  'stage': 198,
#  'ready': 77,
#  'go': 271,
#  'delivers': 4,
#  'ferocity': 2,
#  'individual': 79,
#  'skirmish': 3,
#  'giving': 83,
#  'away': 166,
#  'bigger': 59,
#  'picture': 39,
#  'need': 424,
#  'inspired': 15,
#  'yes': 27,
#  'many': 834,
#  'example': 68,
#  'turning': 32,
#  'past': 383,
#  'strategist': 151,
#  'hillary': 241,
#  'dangled': 1,
#  'obama': 395,
#  'youthful': 9,
#  'drug': 106,
#  'accused': 67,
#  'smearing': 1,
#  'receiving': 19,
#  'donation': 68,
#  'rich': 32,
#  'dig': 7,
#  'feel': 167,
#  'pretty': 43,
#  'innocent': 1,
#  'compared': 95,
#  'burst': 17,
#  'negativity': 4,
#  'prospect': 83,
#  'staunchly': 3,
#  'leftist': 16,
#  'nominee': 410,
#  'late': 175,
#  'entry': 7,
#  'michael': 232,
#  'bloomberg': 1144,
#  'fierce': 24,
#  'fight': 183,
#  'ought': 12,
#  'leading': 231,
#  'sunday': 292,
#  'praised': 37,
#  'fidel': 28,
#  'castro': 72,
#  'cuba': 50,
#  'literacy': 19,
#  'program': 169,
#  'minute': 67,
#  'response': 107,
#  'fellow': 57,
#  'democrat': 1740,
#  'congresswoman': 16,
#  'florida': 210,
#  'sizable': 22,
#  'cuban': 28,
#  'electorate': 163,
#  'american': 657,
#  'immigrant': 46,
#  'member': 307,
#  'congress': 174,
#  'proudly': 8,
#  'represents': 33,
#  'thousand': 58,
#  'find': 123,
#  'senator': 868,
#  'comment': 200,
#  'absolutely': 23,
#  'unacceptable': 14,
#  'representative': 158,
#  'debbi': 1,
#  'amandi': 4,
#  'pollster': 43,
#  'political': 738,
#  'consultant': 33,
#  'went': 116,
#  'nominating': 190,
#  'man': 88,
#  'realdonaldtrump': 1,
#  'end': 224,
#  'constitutional': 18,
#  'republic': 8,
#  'seven': 47,
#  'set': 155,
#  'appear': 77,
#  'tuesday': 1141,
#  'unlikely': 42,
#  'let': 118,
#  'previewed': 1,
#  'continue': 116,
#  'try': 131,
#  'undermine': 29,
#  'choice': 172,
#  'disastrous': 14,
#  'nominate': 46,
#  'socialist': 252,
#  'looking': 127,
#  'horror': 6,
#  'cozied': 3,
#  'dictator': 13,
#  'election': 1294,
#  'aggressive': 49,
#  'belief': 91,
#  'inflexible': 3,
#  'ideological': 66,
#  'revolution': 89,
#  'leaf': 16,
#  'mention': 43,
#  'mr': 211,
#  'also': 1153,
#  'likely': 304,
#  'broad': 63,
#  'target': 87,
#  'elizabeth': 405,
#  'warren': 1373,
#  'pushed': 67,
#  'hard': 134,
#  'derogatory': 6,
#  'made': 424,
#  'woman': 487,
#  'settlement': 5,
#  'employee': 66,
#  'kept': 35,
#  'discussing': 23,
#  'incident': 10,
#  'blowback': 5,
#  'led': 132,
#  'later': 218,
#  'release': 54,
#  'nondisclosure': 14,
#  'unhappy': 2,
#  'gov': 56,
#  'terry': 18,
#  'mcauliffe': 37,
#  'virginia': 164,
#  'entirely': 28,
#  'reasonable': 9,
#  'probing': 3,
#  'vulnerability': 20,
#  'current': 151,
#  'faced': 63,
#  'true': 57,
#  'sustained': 15,
#  'scrutiny': 42,
#  'either': 111,
#  'run': 260,
#  'better': 190,
#  'understand': 53,
#  'electability': 92,
#  'know': 374,
#  'facing': 58,
#  'donald': 254,
#  'smear': 3,
#  'jesse': 9,
#  'ferguson': 4,
#  'glad': 10,
#  'tenor': 3,
#  'reveals': 8,
#  'steel': 1,
#  'coming': 176,
#  'showdown': 10,
#  'general': 416,
#  'thing': 279,
#  'tell': 80,
#  'agenda': 118,
#  'starting': 37,
#  'time': 1284,
#  'worked': 99,
#  'lead': 311,
#  'u': 266,
#  'continued': 82,
#  'going': 689,
#  'promote': 15,
#  'someone': 135,
#  'role': 147,
#  'unless': 35,
#  'proven': 27,
#  'photographsenator': 10,
#  'vice': 558,
#  'la': 93,
#  'vega': 88,
#  'attacking': 59,
#  'trustworthiness': 3,
#  'approach': 96,
#  'photograph': 180,
#  'erin': 34,
#  'feb': 110,
#  'hitin': 4,
#  'contentious': 8,
#  'far': 404,
#  'challenged': 25,
#  'gun': 95,
#  'regulation': 38,
#  'presenting': 13,
#  'cool': 7,
#  'newcomer': 28,
#  'manchester': 56,
#  'victor': 20,
#  'iowa': 1422,
#  'caucus': 890,
#  'vermont': 328,
#  'bend': 229,
#  'came': 244,
#  'sharp': 57,
#  'friday': 210,
#  'stop': 157,
#  'momentum': 156,
#  'assailing': 2,
#  'opposition': 54,
#  'control': 141,
#  'targeting': 38,
#  'thin': 7,
#  'tie': 47,
#  'big': 264,
#  'place': 281,
#  'hampshire': 593,
#  'charged': 14,
#  'appeared': 133,
#  'best': 269,
#  'position': 183,
#  'top': 416,
#  'perhaps': 89,
#  'command': 19,
#  'several': 285,
#  'significant': 131,
#  'advantage': 132,
#  'showed': 211,
#  'give': 156,
#  'especially': 129,
#  'bruising': 1,
#  'treatment': 18,
#  'drawing': 28,
#  'tough': 48,
#  'challenge': 161,
#  'onstage': 41,
#  'failure': 32,
#  'appeal': 175,
#  'black': 463,
#  'latino': 219,
#  'seeking': 106,
#  'recover': 5,
#  'limp': 1,
#  'finish': 117,
#  'raised': 213,
#  'issue': 405,
#  'lack': 65,
#  'support': 954,
#  'minority': 88,
#  'opening': 54,
#  'shown': 71,
#  'could': 1166,
#  'scope': 14,
#  'repeatedly': 82,
#  'alluded': 6,
#  'throughout': 64,
#  'evening': 93,
#  'base': 161,
#  'whose': 158,
#  'month': 487,
#  'considered': 64,
#  'firewall': 14,
#  'flagging': 4,
#  'campaign': 2808,
#  'doe': 401,
#  'warned': 75,
#  'taint': 1,
#  'label': 25,
#  'socialism': 71,
#  'blunt': 30,
#  'rebuked': 5,
#  'opposed': 45,
#  'legislation': 61,
#  'long': 323,
#  'since': 374,
#  'disavowed': 5,
#  'stance': 25,
#  'called': 246,
#  'function': 11,
#  'representing': 25,
#  'rural': 84,
#  'state': 2465,
#  'major': 190,
#  'point': 440,
#  'bid': 127,
#  'nomination': 507,
#  'part': 279,
#  'entered': 74,
#  'main': 38,
#  'divide': 44,
#  'whether': 298,
#  'enact': 14,
#  'incremental': 7,
#  'policy': 583,
#  'step': 82,
#  'pursue': 15,
#  'transformational': 2,
#  'change': 361,
#  'vivid': 6,
#  'display': 23,
#  'question': 300,
#  'appealing': 20,
#  'massachusetts': 214,
#  'minnesota': 142,
#  'crucial': 66,
#  'opportunity': 107,
#  'reassert': 2,
#  'prevent': 29,
#  'establishing': 4,
#  'tight': 25,
#  'grip': 10,
#  'respective': 6,
#  'wing': 80,
#  'left': 338,
#  'closer': 46,
#  'despite': 126,
#  'high': 128,
#  'stake': 59,
#  'standout': 8,
#  'sort': 37,
#  'transformed': 8,
#  'polling': 233,
#  'well': 421,
#  'benefited': 20,
#  'slicing': 1,
#  'enjoyed': 18,
#  'speaking': 90,
#  'reprise': 4,
#  'progressive': 248,
#  'argument': 129,
#  'often': 174,
#  'assailed': 5,
#  'declined': 100,
#  'multiple': 93,
#  'however': 95,
#  'taken': 120,
#  'heat': 9,
#  'apparently': 12,
#  'joint': 13,
#  'winner': 81,
#  'strenuous': 4,
#  'test': 67,
#  'reprising': 2,
#  'familiar': 108,
#  'sternest': 1,
#  'critic': 65,
#  'dismissing': 9,
#  'value': 49,
#  'government': 286,
#  'experience': 125,
#  'easy': 45,
#  'washington': 483,
#  'popular': 145,
#  'harder': 50,
#  'difficult': 88,
#  'added': 169,
#  'white': 514,
#  'house': 657,
#  'look': 223,
#  'deflected': 3,
#  'moderator': 32,
#  'racial': 37,
#  'disparity': 14,
#  'arrest': 17,
#  'police': 27,
#  'flatly': 6,
#  'given': 115,
#  'substantial': 20,
#  'answer': 80,
#  'fact': 127,
#  'took': 185,
#  'largely': 128,
#  'ignored': 12,
#  'previous': 83,
#  'signature': 39,
#  'health': 511,
#  'proposal': 205,
#  'known': 88,
#  'medicare': 190,
#  'swiped': 2,
#  'close': 202,
#  'money': 293,
#  'interest': 109,
#  'unlike': 38,
#  'billionaire': 202,
#  'contributing': 7,
#  'even': 666,
#  'andrew': 97,
#  'yang': 118,
#  'tech': 48,
#  'entrepreneur': 33,
#  'rarely': 31,
#  'appearance': 38,
#  'saw': 84,
#  'fundamentally': 11,
#  'lesson': 9,
#  'denounced': 23,
#  'presidency': 123,
#  'cause': 41,
#  'problem': 180,
#  'making': 209,
#  'mistake': 43,
#  'act': 93,
#  'gave': 89,
#  'ground': 99,
#  'arguing': 80,
#  'determinedly': 1,
#  'distinctive': 1,
#  'batted': 1,
#  'skepticism': 15,
#  'service': 85,
#  'highest': 31,
#  'rejected': 25,
#  'demand': 28,
#  'purity': 9,
#  'eventual': 40,
#  'immense': 3,
#  'war': 219,
#  'chest': 23,
#  'everything': 76,
#  'sign': 217,
#  'confidence': 48,
#  'positioning': 6,
#  'outsider': 41,
#  'conceded': 7,
#  'traditional': 69,
#  'qualification': 7,
#  'seeming': 10,
#  'imply': 3,
#  'profile': 25,
#  'already': 197,
#  'option': 94,
#  'freely': 7,
#  'admit': 11,
#  'establishment': 176,
#  'belt': 18,
#  'course': 95,
#  'countered': 3,
#  'minimizing': 2,
#  'work': 326,
#  'respectfully': 2,
#  'relegating': 1,
#  'accomplishment': 17,
#  'achievement': 12,
#  'phenomenally': 2,
#  'important': 178,
#  'met': 60,
#  'meet': 82,
#  'different': 168,
#  'flurry': 13,
#  'reprisal': 2,
#  'unsurprising': 3,
#  'poll': 835,
#  'showing': 129,
#  'striking': 26,
#  'though': 231,
#  'finishing': 17,
#  'distant': 11,
#  'third': 147,
#  'recited': 2,
#  'corruption': 39,
#  'shied': 5,
#  'confronting': 13,
#  'chance': 223,
#  'offered': 83,
#  'glancing': 3,
#  'critique': 33,
#  'returning': 18,
#  'broader': 66,
#  'tumult': 5,
#  'anxiety': 52,
#  'leadoff': 3,
#  'contest': 477,
#  'turned': 105,
#  'fiasco': 5,
#  'technical': 17,
#  'breakdown': 12,
#  'stalled': 5,
#  'fumbled': 1,
#  'accusation': 17,
#  'electoral': 86,
#  'illegitimacy': 1,
#  'afternoon': 62,
#  'claimed': 54,
#  'brandishing': 1,
#  'vote': 1048,
#  'staking': 2,
#  'hairbreadth': 1,
#  'metric': 25,
#  'judging': 3,
#  'expectation': 32,
#  'captured': 16,
#  'easily': 40,
#  'probably': 113,
#  'adding': 98,
#  'discussion': 71,
#  'confined': 7,
#  'hammering': 2,
#  'theme': 28,
#  'define': 8,
#  'argued': 86,
#  'unite': 85,
#  'crossover': 6,
#  'bring': 104,
#  'independent': 143,
#  'republican': 897,
#  'hate': 22,
#  'tom': 131,
#  'steyer': 133,
#  'wealthy': 61,
#  'investor': 56,
#  'able': 176,
#  'feat': 7,
#  'noted': 91,
#  'yet': 220,
#  'managed': 31,
#  'contrast': 100,
#  'awkwardly': 1,
#  'clinical': 5,
#  'turn': 161,
#  'phrase': 8,
#  'recent': 395,
#  'percent': 585,
#  'supporting': 104,
#  'involved': 53,
#  'defending': 27,
#  'poor': 48,
#  'rating': 46,
#  'national': 680,
#  'rifle': 2,
#  'association': 12,
#  'owed': 4,
#  'tradition': 11,
#  'represented': 32,
#  'perspective': 16,
#  'world': 170,
#  'sensing': 1,
#  'owner': 21,
#  'delaware': 23,
#  'still': 441,
#  'pushing': 43,
#  'brady': 14,
#  'background': 29,
#  'check': 56,
#  'voted': 213,
#  'alluding': 9,
#  'wave': 36,
#  'violence': 30,
#  'constituency': 35,
#  'lot': 228,
#  'around': 311,
#  'citing': 47,
#  'getting': 122,
#  'killed': 43,
#  'period': 47,
#  'counterattacked': 1,
#  'gusto': 1,
#  'saved': 12,
#  'played': 70,
#  'live': 92,
#  'audience': 82,
#  'campus': 30,
#  'anselm': 3,
#  'college': 204,
#  'urging': 40,
#  'stand': 111,
#  'applaud': 4,
#  'alexander': 31,
#  'vindman': 5,
#  'decorated': 3,
#  'iraq': 60,
#  'veteran': 89,
#  'security': 233,
#  'council': 25,
#  'testified': 3,
#  'impeachment': 300,
#  'hearing': 37,
#  'marched': 4,
#  'clap': 2,
#  'series': 73,
#  'foreign': 121,
#  'expressed': 55,
#  'overlapping': 7,
#  'continuing': 36,
#  'military': 106,
#  'involvement': 16,
#  'afghanistan': 14,
#  'departing': 3,
#  'usual': 11,
#  'focus': 193,
#  'domestic': 46,
#  'believed': 59,
#  'endless': 14,
#  'noting': 57,
#  'naming': 7,
#  'name': 135,
#  'willing': 46,
#  'leave': 54,
#  'troop': 23,
#  'wait': 23,
#  'corner': 20,
#  'number': 299,
#  'supported': 106,
#  'invasion': 13,
#  'disagreed': 20,
#  'administration': 229,
#  'totally': 10,
#  'whole': 54,
#  'notion': 25,
#  'possible': 115,
#  'region': 47,
#  'united': 192,
#  'sweeping': 58,
#  'expression': 7,
#  'engagement': 13,
#  'overseas': 20,
#  'stood': 47,
#  'strike': 38,
#  'qassim': 9,
#  'suleimani': 18,
#  'iranian': 20,
#  'commander': 19,
#  'characterized': 9,
#  'assassination': 5,
#  'bad': 84,
#  'guy': 71,
#  'assassinate': 1,
#  'predicting': 8,
#  'international': 51,
#  'anarchy': 1,
#  'photographfrom': 3,
#  'start': 120,
#  'frantz': 4,
#  'supporter': 743,
#  'great': 103,
#  'north': 177,
#  'aleworks': 1,
#  'fan': 44,
#  'gathered': 28,
#  'breezeway': 1,
#  'pub': 5,
#  'ruth': 14,
#  'alyssa': 6,
#  'schukar': 3,
#  'hitthe': 33,
#  'rift': 2,
#  'rose': 35,
#  'surface': 5,
#  'sparred': 9,
#  'moines': 140,
#  'clashed': 11,
#  'starkly': 8,
#  'defeat': 206,
#  'highlighting': 29,
#  'success': 81,
#  'female': 88,
#  'fraught': 11,
#  'elected': 107,
#  'caused': 33,
#  'serious': 70,
#  'breach': 6,
#  'relationship': 52,
#  'confirmed': 24,
#  'report': 203,
#  'told': 358,
#  'private': 166,
#  'meeting': 117,
#  'trumpeted': 2,
#  'senate': 350,
#  'incumbent': 72,
#  'gestured': 2,
#  'toward': 154,
#  'male': 25,
#  'collectively': 11,
#  'lost': 148,
#  'acknowledging': 8,
#  'present': 40,
#  'single': 85,
#  'beaten': 13,
#  'denied': 47,
#  'lawmaker': 128,
#  'aide': 272,
#  'incomprehensible': 1,
#  'le': 275,
#  'iowan': 51,
#  'affair': 27,
#  'keeping': 20,
#  'middle': 109,
#  'east': 68,
#  'trade': 137,
#  'deal': 145,
#  'america': 150,
#  'aggressively': 32,
#  'tackle': 4,
#  'climate': 125,
#  'animating': 3,
#  'shaped': 13,
#  'formidable': 20,
#  'contender': 104,
#  'increasingly': 100,
#  'revolved': 1,
#  'matter': 225,
#  'become': 181,
#  'urgent': 22,
#  'hostility': 8,
#  'increased': 47,
#  'tehran': 2,
#  'killing': 13,
#  'powerful': 63,
#  'featured': 16,
#  'six': 86,
#  'remaining': 63,
#  'touched': 7,
#  'excoriated': 3,
#  'urged': 52,
#  'caution': 15,
#  'laid': 29,
#  'mantle': 9,
#  'potential': 144,
#  'standing': 88,
#  'merited': 2,
#  'voting': 357,
#  'begin': 79,
#  'notable': 16,
#  'slipped': 7,
#  'seemed': 113,
#  'satisfied': 5,
#  'case': 165,
#  'sharply': 32,
#  'criticizing': 30,
#  'roughly': 66,
#  'split': 72,
#  'criticized': 106,
#  'cost': 139,
#  'plan': 538,
#  'ambition': 10,
#  'stretch': 17,
#  'scant': 2,
#  'unfolded': 5,
#  'extraordinarily': 3,
#  'volatile': 11,
#  'politics': 263,
#  'looming': 25,
#  'escalated': 8,
#  'tension': 37,
#  'iran': 66,
#  'befitting': 3,
#  'setting': 30,
#  'eager': 58,
#  'invoke': 1,
#  'specific': 30,
#  'along': 122,
#  'trail': 127,
#  'tailoring': 4,
#  'pitch': 42,
#  'contretemps': 1,
#  'remarkable': 22,
#  'friend': 118,
#  'labored': 2,
#  'abide': 4,
#  'facto': 5,
#  'nonaggression': 3,
#  'pact': 7,
#  'crystallized': 1,
#  'competing': 62,
#  'positioned': 42,
#  'flashed': 4,
#  'smile': 7,
#  'defeated': 34,
#  'straight': 32,
#  'running': 344,
#  'pointed': 85,
#  'doubt': 72,
#  'john': 124,
#  'kennedy': 14,
#  'addressed': 30,
#  'catholicism': 1,
#  'recently': 132,
#  'overcome': 31,
#  'stepped': 18,
#  'unusual': 35,
#  'closing': 42,
#  'contention': 18,
#  'basis': 15,
#  'reflected': 34,
#  'urgency': 30,
#  'reverse': 14,
#  'decline': 18,
#  'seem': 55,
#  'rattled': 12,
#  'confrontation': 16,
#  'least': 159,
#  'forum': 32,
#  'immediate': 26,
#  'aftermath': 14,
#  'cnn': 97,
#  'camera': 16,
#  'appearing': 19,
#  'refuse': 6,
#  ...}

# %%
bernie_WSJ_tokens_dict
# Out:
# {'increasingly': 20,
#  'strict': 3,
#  'measure': 16,
#  'designed': 7,
#  'slow': 3,
#  'spread': 16,
#  'coronavirus': 93,
#  'raising': 9,
#  'concern': 76,
#  'feasibility': 6,
#  'holding': 32,
#  'remaining': 12,
#  'democratic': 962,
#  'presidential': 258,
#  'primary': 488,
#  'contest': 191,
#  'well': 123,
#  'logistics': 4,
#  'november': 95,
#  'general': 126,
#  'election': 487,
#  'pandemic': 38,
#  'still': 96,
#  'nation': 30,
#  'complicated': 18,
#  'thicket': 2,
#  'state': 777,
#  'federal': 76,
#  'law': 34,
#  'process': 66,
#  'selecting': 3,
#  'nominee': 111,
#  'fact': 15,
#  'political': 176,
#  'party': 610,
#  'private': 32,
#  'organization': 17,
#  'set': 47,
#  'internal': 10,
#  'rule': 54,
#  'depending': 5,
#  'jurisdiction': 4,
#  'official': 134,
#  'leader': 85,
#  'flexibility': 2,
#  'altering': 2,
#  'date': 17,
#  'possibly': 7,
#  'format': 2,
#  'response': 31,
#  'growing': 24,
#  'expert': 36,
#  'say': 220,
#  'five': 35,
#  'already': 57,
#  'done': 30,
#  'ohio': 41,
#  'brief': 5,
#  'struggle': 14,
#  'governor': 33,
#  'supreme': 16,
#  'court': 34,
#  'voting': 153,
#  'follow': 15,
#  'persists': 2,
#  'fall': 32,
#  'fear': 35,
#  'could': 347,
#  'congress': 60,
#  'need': 127,
#  'step': 21,
#  'picture': 7,
#  'significant': 28,
#  'alteration': 2,
#  'fixed': 6,
#  'tuesday': 382,
#  'act': 27,
#  'president': 579,
#  'absent': 2,
#  'legislation': 19,
#  'granted': 2,
#  'strong': 100,
#  'protection': 3,
#  'citizen': 9,
#  'cast': 76,
#  'ballot': 125,
#  'even': 105,
#  'order': 33,
#  'sweeping': 23,
#  'emergency': 11,
#  'authority': 5,
#  'level': 41,
#  'government': 121,
#  'limit': 14,
#  'gathering': 16,
#  'impose': 6,
#  'quarantine': 2,
#  'trumped': 2,
#  'think': 160,
#  'reasonable': 3,
#  'ensure': 18,
#  'public': 138,
#  'safety': 18,
#  'ultimately': 10,
#  'yield': 5,
#  'vote': 342,
#  'marc': 2,
#  'elia': 2,
#  'lawyer': 16,
#  'worked': 16,
#  'numerous': 5,
#  'campaign': 700,
#  'affected': 12,
#  'virus': 44,
#  'joe': 184,
#  'defeated': 10,
#  'bernie': 414,
#  'trio': 4,
#  'turnout': 82,
#  'appeared': 33,
#  'low': 25,
#  'compared': 38,
#  'similar': 43,
#  'held': 72,
#  'past': 91,
#  'wall': 164,
#  'street': 158,
#  'journal': 128,
#  'reported': 31,
#  'many': 183,
#  'voter': 591,
#  'venturing': 2,
#  'home': 60,
#  'time': 190,
#  'day': 184,
#  'abate': 2,
#  'coming': 50,
#  'week': 200,
#  'asia': 2,
#  'life': 31,
#  'slowly': 4,
#  'returning': 4,
#  'normal': 4,
#  'early': 103,
#  'outbreak': 26,
#  'site': 21,
#  'like': 207,
#  'china': 16,
#  'doe': 124,
#  'diminish': 2,
#  'return': 20,
#  'expressed': 15,
#  'might': 56,
#  'hold': 63,
#  'middle': 21,
#  'deadly': 2,
#  'whether': 65,
#  'extremely': 7,
#  'seen': 47,
#  'legitimate': 9,
#  'raise': 19,
#  'additional': 17,
#  'reliable': 6,
#  'elderly': 2,
#  'group': 111,
#  'risk': 33,
#  'complication': 2,
#  'addition': 27,
#  'poll': 273,
#  'worker': 107,
#  'volunteer': 26,
#  'staff': 32,
#  'across': 45,
#  'country': 108,
#  'older': 30,
#  'assistance': 9,
#  'commission': 18,
#  'found': 41,
#  'age': 23,
#  'newsletter': 20,
#  'get': 159,
#  'morning': 36,
#  'briefing': 22,
#  'weekday': 7,
#  'plus': 32,
#  'update': 15,
#  'friday': 41,
#  'sign': 64,
#  'proposal': 56,
#  'mandate': 2,
#  'expand': 32,
#  'program': 53,
#  'limiting': 4,
#  'sen': 29,
#  'ron': 7,
#  'wyden': 6,
#  'amy': 89,
#  'klobuchar': 142,
#  'proposed': 29,
#  'bill': 59,
#  'also': 317,
#  'provide': 24,
#  'million': 209,
#  'grant': 7,
#  'prepaid': 2,
#  'postage': 4,
#  'equipment': 13,
#  'upgrade': 2,
#  'virtually': 7,
#  'every': 43,
#  'today': 14,
#  'absentee': 4,
#  'arrangement': 4,
#  'making': 45,
#  'amount': 18,
#  'fund': 22,
#  'move': 39,
#  'american': 121,
#  'going': 207,
#  'forced': 10,
#  'choose': 21,
#  'health': 163,
#  'msnbc': 7,
#  'ample': 2,
#  'precedent': 6,
#  'action': 25,
#  'previously': 16,
#  'mandated': 2,
#  'allow': 33,
#  'military': 20,
#  'mail': 19,
#  'register': 10,
#  'renewing': 2,
#  'obtaining': 2,
#  'driver': 2,
#  'example': 9,
#  'washington': 96,
#  'reason': 30,
#  'place': 110,
#  'requesting': 2,
#  'controversial': 6,
#  'though': 49,
#  'liberal': 90,
#  'activist': 29,
#  'believe': 56,
#  'dampens': 2,
#  'among': 181,
#  'demographic': 8,
#  'include': 28,
#  'paid': 23,
#  'conservative': 35,
#  'fraud': 2,
#  'simply': 17,
#  'support': 264,
#  'single': 13,
#  'nationwide': 8,
#  'opponent': 46,
#  'universal': 15,
#  'year': 320,
#  'exception': 3,
#  'particularly': 33,
#  'important': 32,
#  'balloting': 13,
#  'run': 69,
#  'orderly': 2,
#  'personally': 7,
#  'extensive': 6,
#  'good': 58,
#  'idea': 66,
#  'hate': 6,
#  'see': 98,
#  'crisis': 52,
#  'sneak': 2,
#  'permanent': 2,
#  'bradley': 2,
#  'smith': 14,
#  'former': 410,
#  'republican': 262,
#  'appointee': 2,
#  'teach': 2,
#  'capital': 44,
#  'university': 79,
#  'school': 32,
#  'probably': 18,
#  'current': 55,
#  'circumstance': 4,
#  'pas': 19,
#  'limited': 10,
#  'providing': 9,
#  'kind': 29,
#  'byron': 4,
#  'tau': 4,
#  'informed': 6,
#  'russia': 46,
#  'actively': 3,
#  'trying': 33,
#  'nomination': 215,
#  'part': 41,
#  'moscow': 10,
#  'broader': 24,
#  'effort': 55,
#  'interfere': 12,
#  'according': 141,
#  'people': 291,
#  'familiar': 21,
#  'matter': 67,
#  'small': 31,
#  'number': 53,
#  'lawmaker': 40,
#  'briefed': 5,
#  'intelligence': 35,
#  'classified': 2,
#  'fbi': 5,
#  'type': 8,
#  'routinely': 2,
#  'given': 25,
#  'security': 77,
#  'reaction': 12,
#  'considered': 31,
#  'compelling': 2,
#  'enough': 48,
#  'needed': 13,
#  'alerted': 2,
#  'suggested': 22,
#  'russian': 25,
#  'bolster': 4,
#  'approached': 3,
#  'scale': 22,
#  'scope': 2,
#  'operation': 29,
#  'person': 37,
#  'post': 7,
#  'earlier': 37,
#  'received': 47,
#  'seeking': 31,
#  'speaking': 15,
#  'reporter': 44,
#  'acknowledged': 24,
#  'taken': 29,
#  'clear': 42,
#  'role': 40,
#  'attempting': 4,
#  'play': 32,
#  'told': 90,
#  'maybe': 8,
#  'getting': 24,
#  'involved': 12,
#  'bakersfield': 2,
#  'look': 71,
#  'message': 41,
#  'criticized': 28,
#  'online': 29,
#  'vitriol': 2,
#  'supporter': 181,
#  'directed': 2,
#  'statement': 54,
#  'possible': 16,
#  'ugly': 2,
#  'stuff': 7,
#  'attributed': 8,
#  'actually': 21,
#  'fake': 2,
#  'internet': 10,
#  'account': 5,
#  'office': 59,
#  'director': 66,
#  'national': 210,
#  'bureau': 13,
#  'investigation': 17,
#  'department': 18,
#  'homeland': 12,
#  'declined': 32,
#  'comment': 57,
#  'report': 55,
#  'emerged': 15,
#  'month': 116,
#  'nevada': 187,
#  'caucus': 323,
#  'currently': 17,
#  'leading': 60,
#  'rival': 81,
#  'following': 48,
#  'finish': 23,
#  'hampshire': 222,
#  'positioned': 8,
#  'let': 21,
#  'guess': 7,
#  'came': 38,
#  'asked': 56,
#  'last': 174,
#  'house': 174,
#  'committee': 85,
#  'apparent': 2,
#  'preference': 8,
#  'oval': 4,
#  'meeting': 31,
#  'lashed': 2,
#  'joseph': 2,
#  'maguire': 2,
#  'acting': 4,
#  'replaced': 3,
#  'irate': 2,
#  'information': 21,
#  'agitated': 7,
#  'indicated': 10,
#  'seek': 20,
#  'electoral': 15,
#  'prospect': 29,
#  'determined': 8,
#  'precise': 3,
#  'motive': 2,
#  'social': 73,
#  'medium': 36,
#  'repeatedly': 11,
#  'denied': 14,
#  'interfering': 2,
#  'rally': 119,
#  'la': 18,
#  'vega': 16,
#  'dismissed': 17,
#  'agency': 9,
#  'behalf': 2,
#  'calling': 21,
#  'disinformation': 6,
#  'vladimir': 2,
#  'putin': 4,
#  'wait': 4,
#  'democrat': 485,
#  'pick': 36,
#  'honeymooned': 2,
#  'remark': 21,
#  'candidate': 597,
#  'warned': 13,
#  'interest': 32,
#  'aiding': 2,
#  'sequence': 2,
#  'pointed': 11,
#  'wife': 17,
#  'traveled': 7,
#  'delegation': 4,
#  'burlington': 16,
#  'mayor': 163,
#  'establish': 5,
#  'city': 106,
#  'yaroslavl': 2,
#  'celebrated': 2,
#  'honeymoon': 4,
#  'warning': 8,
#  'others': 37,
#  'likely': 88,
#  'special': 10,
#  'counsel': 10,
#  'robert': 16,
#  'mueller': 6,
#  'interfered': 4,
#  'systematic': 6,
#  'fashion': 2,
#  'help': 84,
#  'denigrate': 2,
#  'challenger': 14,
#  'hillary': 70,
#  'clinton': 114,
#  'probe': 6,
#  'operative': 6,
#  'spreading': 11,
#  'propaganda': 2,
#  'showed': 82,
#  'favoritism': 2,
#  'opportunity': 34,
#  'criticize': 14,
#  'except': 7,
#  'quoting': 2,
#  'saying': 70,
#  'indictment': 2,
#  'elizabeth': 118,
#  'warren': 292,
#  'much': 121,
#  'transparency': 6,
#  'interference': 9,
#  'understand': 10,
#  'fight': 53,
#  'call': 75,
#  'give': 39,
#  'everyone': 18,
#  'quickly': 20,
#  'otherwise': 4,
#  'continue': 31,
#  'influence': 16,
#  'struggled': 29,
#  'respond': 14,
#  'indication': 13,
#  'foreign': 20,
#  'adversary': 2,
#  'meddling': 4,
#  'obama': 96,
#  'administration': 59,
#  'alike': 2,
#  'disclosing': 5,
#  'outlined': 4,
#  'plan': 169,
#  'notify': 2,
#  'framework': 6,
#  'criticism': 44,
#  'vague': 4,
#  'argued': 24,
#  'notification': 2,
#  'decision': 28,
#  'made': 88,
#  'protect': 15,
#  'integrity': 4,
#  'discourse': 2,
#  'summary': 2,
#  'joshua': 34,
#  'jamerson': 34,
#  'rebecca': 10,
#  'ballhaus': 4,
#  'eliza': 72,
#  'collins': 73,
#  'contributed': 84,
#  'dustin': 12,
#  'volz': 12,
#  'jolting': 2,
#  'debate': 195,
#  'care': 112,
#  'arguing': 10,
#  'damage': 17,
#  'net': 18,
#  'coverage': 38,
#  'top': 139,
#  'issue': 102,
#  'began': 23,
#  'case': 32,
#  'platform': 33,
#  'highlight': 9,
#  'high': 32,
#  'medical': 10,
#  'cost': 50,
#  'lack': 15,
#  'policy': 197,
#  'fix': 3,
#  'expected': 39,
#  'sunday': 80,
#  'night': 98,
#  'counter': 7,
#  'expanded': 19,
#  'access': 23,
#  'affordable': 21,
#  'sought': 45,
#  'polarizing': 9,
#  'aspect': 9,
#  'undocumented': 2,
#  'immigrant': 12,
#  'side': 21,
#  'extreme': 14,
#  'coin': 4,
#  'tweeted': 18,
#  'march': 87,
#  'family': 30,
#  'pay': 56,
#  'illegal': 2,
#  'alien': 2,
#  'argue': 18,
#  'change': 117,
#  'weakened': 6,
#  'leave': 16,
#  'treatment': 2,
#  'point': 142,
#  'expansion': 13,
#  'deny': 4,
#  'cover': 11,
#  'aca': 6,
#  'minimum': 10,
#  'benefit': 28,
#  'back': 93,
#  'medicaid': 5,
#  'funding': 6,
#  'block': 6,
#  'hurt': 27,
#  'enrollment': 2,
#  'praised': 7,
#  'white': 101,
#  'accused': 7,
#  'score': 4,
#  'mark': 26,
#  'meadow': 2,
#  'chief': 58,
#  'tweet': 18,
#  'left': 69,
#  'control': 42,
#  'reference': 9,
#  'recently': 27,
#  'started': 15,
#  'appear': 18,
#  'advertising': 40,
#  'aligned': 5,
#  'try': 22,
#  'leverage': 5,
#  'topic': 18,
#  'tv': 42,
#  'ad': 87,
#  'mention': 12,
#  'critical': 24,
#  'steve': 12,
#  'daines': 7,
#  'montana': 16,
#  'thursday': 62,
#  'data': 71,
#  'firm': 37,
#  'spot': 17,
#  'sponsored': 3,
#  'go': 50,
#  'sleep': 2,
#  'worried': 13,
#  'billing': 2,
#  'missoula': 2,
#  'absolutely': 9,
#  'ken': 54,
#  'goldstein': 4,
#  'san': 10,
#  'francisco': 6,
#  'professor': 27,
#  'studied': 3,
#  'decade': 32,
#  'question': 54,
#  'strategist': 44,
#  'maker': 12,
#  'share': 148,
#  'thought': 81,
#  'join': 77,
#  'conversation': 68,
#  'related': 38,
#  'mind': 8,
#  'running': 96,
#  'advantage': 23,
#  'disadvantage': 4,
#  'best': 76,
#  'inject': 2,
#  'hand': 39,
#  'watching': 20,
#  'lot': 72,
#  'television': 22,
#  'seeing': 2,
#  'record': 86,
#  'usage': 4,
#  'video': 11,
#  'rating': 16,
#  'offensive': 2,
#  'trail': 50,
#  'vermont': 148,
#  'proponent': 10,
#  'medicare': 80,
#  'insanity': 3,
#  'ca': 41,
#  'afford': 7,
#  'doctor': 4,
#  'vice': 155,
#  'pushed': 15,
#  'add': 21,
#  'option': 29,
#  'buy': 12,
#  'blamed': 2,
#  'taking': 5,
#  'weaken': 4,
#  'protecting': 8,
#  'job': 64,
#  'unfortunately': 2,
#  'laid': 10,
#  'bare': 3,
#  'severe': 3,
#  'shortcoming': 2,
#  'ability': 26,
#  'effectively': 8,
#  'undermined': 2,
#  'disparagement': 2,
#  'billionaire': 47,
#  'york': 101,
#  'michael': 81,
#  'bloomberg': 330,
#  'ran': 21,
#  'different': 39,
#  'three': 99,
#  'minute': 15,
#  'long': 62,
#  'dropped': 15,
#  'grew': 8,
#  'february': 33,
#  'highest': 6,
#  'since': 93,
#  'enacted': 13,
#  'ago': 62,
#  'kaiser': 2,
#  'foundation': 2,
#  'october': 9,
#  'congressional': 33,
#  'digital': 24,
#  'initially': 4,
#  'vaccine': 2,
#  'minority': 30,
#  'kevin': 18,
#  'mccarthy': 9,
#  'california': 82,
#  'playing': 10,
#  'politics': 45,
#  'tap': 2,
#  'angst': 2,
#  'easier': 16,
#  'harder': 18,
#  'jesse': 2,
#  'ferguson': 2,
#  'seems': 15,
#  'challenging': 7,
#  'agenda': 30,
#  'sell': 6,
#  'quinnipiac': 5,
#  'released': 45,
#  'disapprove': 9,
#  'handling': 21,
#  'approve': 12,
#  'sharp': 8,
#  'divide': 8,
#  'along': 36,
#  'overall': 10,
#  'approval': 16,
#  'independent': 49,
#  'stephanie': 13,
#  'armour': 2,
#  'john': 43,
#  'mccormick': 28,
#  'strength': 43,
#  'putting': 17,
#  'track': 19,
#  'scoop': 15,
#  'delegate': 203,
#  'super': 157,
#  'photo': 83,
#  'victor': 15,
#  'j': 13,
#  'blue': 32,
#  'betting': 24,
#  'victory': 78,
#  'south': 203,
#  'carolina': 164,
#  'revitalize': 5,
#  'momentum': 53,
#  'belief': 18,
#  'recent': 109,
#  'performance': 66,
#  'gave': 37,
#  'fresh': 8,
#  'boost': 47,
#  'pete': 97,
#  'buttigieg': 246,
#  'hunt': 11,
#  'race': 293,
#  'series': 24,
#  'spent': 81,
#  'staying': 7,
#  'bound': 3,
#  'common': 15,
#  'goal': 25,
#  'stop': 30,
#  'amassing': 5,
#  'majority': 64,
#  'remain': 23,
#  'centrist': 60,
#  'splitting': 2,
#  'senator': 129,
#  'territory': 5,
#  'member': 95,
#  'living': 20,
#  'abroad': 8,
#  'head': 21,
#  'known': 26,
#  'rise': 24,
#  'fueled': 10,
#  'within': 23,
#  'establishment': 39,
#  'moderate': 109,
#  'identity': 8,
#  'socialist': 101,
#  'doom': 4,
#  'beat': 69,
#  'news': 99,
#  'winning': 64,
#  'hypothetical': 13,
#  'matchup': 21,
#  'percentage': 49,
#  'awarded': 11,
#  'far': 98,
#  'trajectory': 8,
#  'another': 71,
#  'overtake': 9,
#  'maintains': 2,
#  'lead': 102,
#  'hoping': 22,
#  'picking': 14,
#  'secure': 14,
#  'outright': 14,
#  'prompting': 4,
#  'contested': 12,
#  'summer': 16,
#  'convention': 59,
#  'milwaukee': 12,
#  'emerge': 2,
#  'represent': 15,
#  'test': 30,
#  'determine': 18,
#  'cruise': 2,
#  'commanding': 2,
#  'texas': 69,
#  'biggest': 23,
#  'prize': 9,
#  'offer': 20,
#  'combined': 12,
#  'nearly': 65,
#  'half': 44,
#  'near': 12,
#  'cross': 5,
#  'threshold': 15,
#  'necessary': 14,
#  'earn': 5,
#  'path': 34,
#  'multiple': 25,
#  'win': 281,
#  'address': 36,
#  'crowd': 29,
#  'greenville': 2,
#  'minimize': 3,
#  'margin': 47,
#  'rack': 5,
#  'field': 102,
#  'winnow': 3,
#  'memo': 26,
#  'schedule': 4,
#  'thwart': 2,
#  'saturday': 62,
#  'massachusetts': 70,
#  'monday': 96,
#  'minnesota': 56,
#  'flexing': 2,
#  'ian': 12,
#  'sam': 2,
#  'kamala': 9,
#  'harris': 12,
#  'really': 28,
#  'put': 73,
#  'corner': 4,
#  'pressing': 8,
#  'third': 51,
#  'campaigned': 12,
#  'practical': 4,
#  'scheduled': 23,
#  'paul': 4,
#  'competing': 17,
#  'colorado': 21,
#  'north': 63,
#  'tennessee': 6,
#  'virginia': 31,
#  'aide': 90,
#  'fiery': 5,
#  'improved': 6,
#  'standing': 19,
#  'touted': 4,
#  'fundraising': 55,
#  'haul': 19,
#  'giant': 4,
#  'lift': 4,
#  'supporting': 17,
#  'persist': 2,
#  'pac': 14,
#  'announced': 32,
#  'late': 51,
#  'nine': 12,
#  'market': 136,
#  'comeback': 3,
#  'banking': 17,
#  'electorate': 54,
#  'southern': 20,
#  'voted': 92,
#  'marker': 2,
#  'happens': 7,
#  'becca': 2,
#  'siegel': 3,
#  'analytics': 6,
#  'officer': 10,
#  'aim': 21,
#  'tax': 104,
#  'hike': 8,
#  'executive': 67,
#  'retirement': 11,
#  'presidency': 20,
#  'mean': 38,
#  'business': 96,
#  'endorsed': 41,
#  'james': 15,
#  'clyburn': 7,
#  'picked': 7,
#  'tim': 10,
#  'kaine': 2,
#  'served': 25,
#  'mate': 5,
#  'launched': 10,
#  'broadcast': 7,
#  'eight': 11,
#  'behind': 63,
#  'radio': 24,
#  'businessman': 16,
#  'tom': 45,
#  'steyer': 29,
#  'division': 6,
#  'secures': 3,
#  'pitted': 2,
#  'stood': 13,
#  'alone': 18,
#  'individual': 32,
#  'fails': 4,
#  'pledged': 13,
#  'chosen': 8,
#  'july': 9,
#  'achieves': 3,
#  'ari': 11,
#  'deputy': 18,
#  'manager': 42,
#  'stipulate': 2,
#  'must': 22,
#  'free': 39,
#  'mostly': 16,
#  'insider': 9,
#  'elected': 29,
#  'weigh': 8,
#  'cnn': 22,
#  'town': 21,
#  'hall': 27,
#  'wednesday': 79,
#  'reversing': 2,
#  'position': 63,
#  'plurality': 5,
#  'know': 62,
#  'everybody': 13,
#  'stand': 32,
#  'stick': 14,
#  'added': 28,
#  'prepared': 5,
#  'stay': 28,
#  'floor': 2,
#  'laying': 4,
#  'groundwork': 4,
#  'divided': 15,
#  'quietly': 2,
#  'reaching': 7,
#  'donor': 49,
#  'bid': 56,
#  'corral': 2,
#  'nominating': 68,
#  'dynamic': 11,
#  'drawn': 18,
#  'contrast': 30,
#  'insurgent': 2,
#  'shocked': 3,
#  'similarly': 6,
#  'crowded': 26,
#  'pinning': 2,
#  'hope': 30,
#  'brokered': 5,
#  'scenario': 22,
#  'never': 43,
#  'terry': 3,
#  'sullivan': 5,
#  'senior': 28,
#  'adviser': 53,
#  'florida': 60,
#  'marco': 11,
#  'rubio': 14,
#  'wishful': 2,
#  'thinking': 19,
#  'hanging': 4,
#  'onto': 12,
#  'thread': 2,
#  'prayer': 2,
#  'guy': 15,
#  'gal': 2,
#  'turn': 29,
#  'end': 47,
#  'lose': 28,
#  'chad': 42,
#  'sabrina': 36,
#  'siddiqui': 34,
#  'thomas': 44,
#  'raleigh': 18,
#  'conway': 3,
#  'trip': 8,
#  'practicing': 2,
#  'distancing': 2,
#  'deal': 42,
#  'successful': 13,
#  'casting': 13,
#  'sanitizer': 7,
#  'ready': 22,
#  'trouble': 10,
#  'locating': 2,
#  ...}

# %%
TWP_tokens_dict
# Out:
# {'democrat': 1914,
#  'michigan': 156,
#  'scrolled': 2,
#  'surge': 40,
#  'nasty': 11,
#  'facebook': 277,
#  'meme': 44,
#  'elizabeth': 246,
#  'warren': 920,
#  'last': 735,
#  'week': 797,
#  'fixing': 2,
#  'captured': 10,
#  'growing': 92,
#  'dislike': 9,
#  'candidate': 1774,
#  'depicted': 7,
#  'smiling': 4,
#  'face': 260,
#  'mask': 17,
#  'behind': 241,
#  'hillary': 214,
#  'clinton': 487,
#  'matt': 45,
#  'walter': 37,
#  'retired': 61,
#  'factory': 10,
#  'worker': 110,
#  'supporter': 506,
#  'bernie': 522,
#  'shared': 54,
#  'image': 66,
#  'onward': 2,
#  'eight': 55,
#  'group': 502,
#  'ten': 31,
#  'thousand': 67,
#  'potential': 193,
#  'eyeball': 5,
#  'tap': 12,
#  'smartphone': 10,
#  'popular': 88,
#  'technique': 7,
#  'allows': 30,
#  'ordinary': 12,
#  'american': 921,
#  'operate': 15,
#  'speed': 10,
#  'reminiscent': 7,
#  'russian': 196,
#  'bot': 3,
#  'troll': 8,
#  'small': 121,
#  'contributed': 202,
#  'massive': 89,
#  'wave': 35,
#  'hostile': 13,
#  'democratic': 1870,
#  'rival': 266,
#  'reflects': 33,
#  'rising': 60,
#  'divisiveness': 8,
#  'party': 1549,
#  'nominating': 100,
#  'contest': 338,
#  'view': 202,
#  'social': 223,
#  'medium': 319,
#  'expert': 108,
#  'exacerbates': 3,
#  'call': 426,
#  'force': 143,
#  'multiplier': 2,
#  'onetime': 13,
#  'union': 211,
#  'activist': 117,
#  'volume': 8,
#  'viciousness': 2,
#  'portraying': 6,
#  'snake': 10,
#  'backstabber': 3,
#  'liar': 19,
#  'reflect': 32,
#  'identifies': 5,
#  'reward': 12,
#  'emotionally': 4,
#  'charged': 59,
#  'generate': 16,
#  'reaction': 32,
#  'billion': 53,
#  'user': 66,
#  'serf': 16,
#  'business': 177,
#  'model': 19,
#  'equates': 2,
#  'engagement': 14,
#  'profit': 10,
#  'also': 1255,
#  'study': 49,
#  'effect': 58,
#  'political': 929,
#  'speech': 227,
#  'distorts': 2,
#  'debate': 600,
#  'confirming': 9,
#  'bias': 29,
#  'sharpening': 3,
#  'division': 105,
#  'elevating': 3,
#  'glib': 3,
#  'visual': 10,
#  'logic': 8,
#  'reasoned': 3,
#  'discussion': 148,
#  'aggregate': 2,
#  'people': 1382,
#  'activates': 2,
#  'accentuates': 2,
#  'extremism': 3,
#  'george': 84,
#  'washington': 911,
#  'university': 179,
#  'professor': 57,
#  'steven': 16,
#  'livingston': 4,
#  'director': 227,
#  'institute': 24,
#  'data': 118,
#  'democracy': 100,
#  'politics': 297,
#  'inflames': 4,
#  'passion': 26,
#  'nature': 41,
#  'discourse': 7,
#  'spokesman': 102,
#  'andy': 12,
#  'stone': 156,
#  'declined': 122,
#  'comment': 268,
#  'story': 112,
#  'since': 408,
#  'beginning': 80,
#  'nearly': 247,
#  'active': 39,
#  'page': 72,
#  'supporting': 101,
#  'million': 470,
#  'interaction': 27,
#  'meaning': 29,
#  'share': 82,
#  'like': 929,
#  'action': 272,
#  'according': 586,
#  'analysis': 47,
#  'trevor': 7,
#  'davis': 28,
#  'research': 61,
#  'contrast': 85,
#  'devoted': 17,
#  'former': 1431,
#  'vice': 592,
#  'president': 3803,
#  'joe': 601,
#  'come': 433,
#  'breakdown': 8,
#  'vastly': 10,
#  'sync': 7,
#  'projected': 17,
#  'support': 714,
#  'poll': 593,
#  'gaining': 11,
#  'ground': 100,
#  'still': 472,
#  'average': 42,
#  'survey': 103,
#  'underscore': 16,
#  'reality': 70,
#  'give': 229,
#  'individual': 89,
#  'power': 385,
#  'public': 482,
#  'disproportionate': 4,
#  'authority': 51,
#  'ballot': 244,
#  'box': 35,
#  'outsized': 8,
#  'influence': 71,
#  'required': 51,
#  'significant': 144,
#  'resource': 63,
#  'money': 327,
#  'printed': 17,
#  'material': 48,
#  'access': 64,
#  'broadcast': 23,
#  'studio': 13,
#  'time': 1150,
#  'reach': 87,
#  'requires': 24,
#  'introduced': 35,
#  'spring': 60,
#  'sharing': 25,
#  'multiple': 96,
#  'simple': 26,
#  'mobile': 19,
#  'device': 8,
#  'allowing': 35,
#  'enthusiast': 3,
#  'even': 778,
#  'quickly': 125,
#  'popularity': 24,
#  'tactic': 60,
#  'among': 630,
#  'help': 328,
#  'explain': 31,
#  'score': 29,
#  'bashing': 7,
#  'opponent': 176,
#  'appeared': 118,
#  'simultaneous': 4,
#  'burst': 13,
#  'recent': 361,
#  'pushed': 79,
#  'highly': 52,
#  'networked': 2,
#  'cluster': 7,
#  'find': 162,
#  'evidence': 240,
#  'campaign': 2696,
#  'involved': 108,
#  'activity': 47,
#  'focusing': 45,
#  'instead': 159,
#  'informal': 13,
#  'engaged': 30,
#  'behavior': 73,
#  'similar': 133,
#  'scale': 31,
#  'characteristic': 6,
#  'online': 168,
#  'movement': 124,
#  'galvanized': 7,
#  'aide': 306,
#  'credited': 7,
#  'victory': 282,
#  'poured': 10,
#  'advertising': 124,
#  'platform': 91,
#  'organic': 7,
#  'post': 739,
#  'speak': 118,
#  'directly': 107,
#  'follower': 24,
#  'responded': 73,
#  'torrent': 10,
#  'backing': 57,
#  'lacerating': 2,
#  'similarly': 24,
#  'embraced': 25,
#  'tool': 44,
#  'revolution': 51,
#  'promise': 65,
#  'described': 103,
#  'part': 427,
#  'cult': 6,
#  'personality': 29,
#  'though': 229,
#  'hardly': 28,
#  'echo': 11,
#  'personal': 215,
#  'insult': 17,
#  'lobbed': 4,
#  'senator': 643,
#  'distanced': 5,
#  'attack': 362,
#  'loudly': 14,
#  'clearly': 45,
#  'room': 176,
#  'abuse': 96,
#  'harassment': 13,
#  'sarah': 10,
#  'ford': 11,
#  'spokeswoman': 62,
#  'forum': 33,
#  'focus': 195,
#  'range': 34,
#  'theme': 40,
#  'independence': 28,
#  'corporate': 46,
#  'interest': 182,
#  'opposition': 58,
#  'many': 847,
#  'fill': 27,
#  'strikingly': 3,
#  'negative': 29,
#  'depicting': 4,
#  'south': 472,
#  'bend': 150,
#  'mayor': 399,
#  'pete': 195,
#  'buttigieg': 672,
#  'cia': 24,
#  'plant': 7,
#  'republican': 1463,
#  'leaning': 31,
#  'feckless': 4,
#  'politician': 141,
#  'prey': 4,
#  'woman': 589,
#  'dozen': 98,
#  'circulating': 9,
#  'recently': 126,
#  'several': 332,
#  'portrayed': 10,
#  'coming': 197,
#  'whose': 221,
#  'bid': 114,
#  'become': 229,
#  'female': 96,
#  'ended': 64,
#  'defeat': 162,
#  'version': 44,
#  'reposted': 5,
#  'reached': 28,
#  'began': 218,
#  'september': 62,
#  'promising': 14,
#  'detente': 2,
#  'accused': 138,
#  'saying': 357,
#  'private': 227,
#  'meeting': 285,
#  'could': 1053,
#  'win': 694,
#  'white': 1074,
#  'house': 1663,
#  'denied': 55,
#  'done': 242,
#  'memo': 34,
#  'received': 105,
#  'denizen': 2,
#  'digital': 100,
#  'world': 255,
#  'interview': 258,
#  'disenchantment': 2,
#  'concern': 241,
#  'might': 306,
#  'rigged': 13,
#  'already': 166,
#  'crusade': 6,
#  'spawned': 3,
#  'calling': 187,
#  'protest': 40,
#  'national': 705,
#  'convention': 224,
#  'july': 110,
#  'emerge': 25,
#  'nominee': 387,
#  'bernieorvest': 4,
#  'rallying': 24,
#  'cry': 15,
#  'echoing': 19,
#  'yellow': 12,
#  'vest': 8,
#  'demonstration': 9,
#  'roiled': 6,
#  'france': 15,
#  'december': 85,
#  'wore': 23,
#  'picture': 49,
#  'proceeded': 7,
#  'upload': 2,
#  'claiming': 28,
#  'falsely': 17,
#  'endorsed': 87,
#  'controversy': 33,
#  'gotten': 33,
#  'vote': 1062,
#  'sure': 144,
#  'november': 301,
#  'another': 424,
#  'clinch': 9,
#  'nomination': 325,
#  'cast': 181,
#  'green': 41,
#  'jill': 26,
#  'stein': 6,
#  'either': 142,
#  'distrust': 15,
#  'enthusiasm': 46,
#  'inspires': 5,
#  'see': 438,
#  'advantage': 102,
#  'tip': 13,
#  'worked': 129,
#  'year': 1348,
#  'emphasizing': 10,
#  'aftermath': 16,
#  'election': 1422,
#  'founder': 36,
#  'ceo': 17,
#  'mark': 105,
#  'zuckerberg': 27,
#  'heralded': 4,
#  'community': 231,
#  'intimate': 11,
#  'connect': 20,
#  'touted': 49,
#  'feature': 25,
#  'redress': 2,
#  'misstep': 6,
#  'broadly': 37,
#  'around': 334,
#  'whole': 71,
#  'decline': 14,
#  'membership': 7,
#  'seen': 224,
#  'decade': 123,
#  'wrote': 226,
#  'june': 50,
#  'change': 356,
#  'elevated': 11,
#  'forefront': 16,
#  'tweak': 4,
#  'sought': 175,
#  'emphasize': 10,
#  'news': 488,
#  'feed': 22,
#  'amid': 105,
#  'shift': 107,
#  'spam': 6,
#  'hyperactive': 2,
#  'posting': 18,
#  'cottage': 19,
#  'industry': 57,
#  'emerged': 50,
#  'efficiently': 4,
#  'plastering': 2,
#  'space': 43,
#  'scheduling': 7,
#  'automation': 8,
#  'technology': 42,
#  'advice': 41,
#  'proliferated': 3,
#  'rapidly': 24,
#  'eluding': 2,
#  'detector': 3,
#  'enforce': 3,
#  'policy': 512,
#  'excessive': 4,
#  'confuse': 2,
#  'anger': 39,
#  'hectic': 5,
#  'pace': 30,
#  'spreading': 23,
#  'made': 537,
#  'researcher': 24,
#  'suspect': 9,
#  'widespread': 28,
#  'possibly': 44,
#  'operation': 174,
#  'conspiratorial': 5,
#  'operative': 26,
#  'corruption': 124,
#  'reemerged': 2,
#  'fury': 13,
#  'season': 43,
#  'point': 411,
#  'frenetic': 5,
#  'work': 323,
#  'aggrieved': 8,
#  'distrustful': 7,
#  'mainstream': 22,
#  'gatekeeper': 2,
#  'information': 180,
#  'turn': 171,
#  'traditional': 43,
#  'guardrail': 2,
#  'exist': 12,
#  'divisive': 32,
#  'audience': 94,
#  'far': 315,
#  'beyond': 102,
#  'central': 51,
#  'experience': 137,
#  'surprising': 22,
#  'used': 229,
#  'actor': 41,
#  'voter': 1588,
#  'philip': 7,
#  'howard': 41,
#  'head': 132,
#  'oxford': 5,
#  'computational': 2,
#  'propaganda': 19,
#  'project': 49,
#  'appear': 101,
#  'deeply': 39,
#  'linked': 8,
#  'top': 365,
#  'single': 101,
#  'direct': 58,
#  'connection': 54,
#  'others': 275,
#  'universe': 11,
#  'entail': 2,
#  'friendship': 18,
#  'following': 122,
#  'overall': 96,
#  'estimated': 26,
#  'unique': 21,
#  'question': 454,
#  'member': 328,
#  'obscure': 3,
#  'origin': 6,
#  'called': 329,
#  'example': 125,
#  'mainly': 15,
#  'photography': 4,
#  'evocative': 3,
#  'poetry': 2,
#  'army': 30,
#  'hundred': 102,
#  'case': 486,
#  'untangling': 2,
#  'web': 7,
#  'common': 47,
#  'ownership': 4,
#  'reveals': 9,
#  'unseemly': 5,
#  'linkage': 2,
#  'continues': 78,
#  'owns': 24,
#  'rare': 22,
#  'repository': 3,
#  'anti': 2,
#  'includes': 58,
#  'zionism': 2,
#  'well': 441,
#  'positive': 50,
#  'saw': 117,
#  'freelance': 2,
#  'journalist': 38,
#  'cara': 2,
#  'rogoff': 2,
#  'greenberg': 14,
#  'life': 271,
#  'york': 301,
#  'city': 216,
#  'series': 55,
#  'regularly': 73,
#  'posted': 39,
#  'bernstorming': 4,
#  'network': 79,
#  'day': 872,
#  'showing': 91,
#  'placed': 33,
#  'jail': 15,
#  'colloquial': 2,
#  'describe': 60,
#  'imposed': 11,
#  'often': 175,
#  'frequently': 42,
#  'remains': 103,
#  'uncertain': 13,
#  'violated': 5,
#  'cartoon': 6,
#  'bar': 48,
#  'thought': 151,
#  'abusing': 12,
#  'privilege': 37,
#  'commented': 4,
#  'timeline': 11,
#  'able': 185,
#  'happening': 45,
#  'contributor': 9,
#  'generating': 5,
#  'technical': 18,
#  'block': 53,
#  'prevent': 44,
#  'repression': 4,
#  'fb': 2,
#  'uncredited': 2,
#  'false': 58,
#  'info': 3,
#  'spread': 68,
#  'concerned': 69,
#  'unable': 25,
#  'easily': 26,
#  'figure': 135,
#  'really': 241,
#  'going': 752,
#  'long': 336,
#  'likely': 248,
#  'lifted': 10,
#  'temporary': 15,
#  'later': 301,
#  'aggressive': 73,
#  'threaten': 17,
#  'divide': 53,
#  'desperate': 20,
#  'avoid': 70,
#  'repeat': 21,
#  'asset': 23,
#  'vermont': 90,
#  'independent': 136,
#  'vying': 18,
#  'compete': 33,
#  'television': 166,
#  'star': 41,
#  'every': 273,
#  'thinking': 75,
#  'keegan': 2,
#  'goudiss': 4,
#  'directed': 22,
#  'conversation': 191,
#  'real': 182,
#  'stoked': 5,
#  'true': 74,
#  'matter': 316,
#  'emphatically': 3,
#  'say': 980,
#  'comparison': 29,
#  'imperfect': 5,
#  'added': 249,
#  'plainly': 6,
#  'parallel': 5,
#  'energizing': 7,
#  'projection': 5,
#  'strength': 80,
#  'siege': 4,
#  'energy': 117,
#  'shifted': 42,
#  'january': 105,
#  'critical': 90,
#  'name': 182,
#  'focused': 195,
#  'kamala': 43,
#  'harris': 92,
#  'october': 79,
#  'month': 514,
#  'exit': 63,
#  'race': 695,
#  'faded': 11,
#  'away': 196,
#  'target': 101,
#  'meanwhile': 118,
#  'whereas': 7,
#  'commanded': 2,
#  'le': 223,
#  'attention': 113,
#  'half': 122,
#  'disparaging': 5,
#  'include': 102,
#  'photoshopped': 5,
#  'dark': 29,
#  'wig': 3,
#  'booker': 98,
#  'gone': 66,
#  'read': 71,
#  'referring': 88,
#  'cory': 39,
#  'jersey': 23,
#  'black': 502,
#  'taking': 173,
#  'blade': 3,
#  'back': 518,
#  'mock': 16,
#  'native': 12,
#  'ancestry': 4,
#  'ally': 316,
#  'rejoinder': 2,
#  'oblique': 4,
#  'repurposing': 2,
#  'serpent': 6,
#  'jibe': 3,
#  'account': 144,
#  'twitter': 189,
#  'fighting': 82,
#  'rolling': 8,
#  'misha': 2,
#  'leybovich': 2,
#  'tech': 37,
#  'entrepreneur': 24,
#  'mckinsey': 3,
#  'consultant': 46,
#  'organizing': 59,
#  'team': 373,
#  'collection': 18,
#  'formal': 36,
#  'link': 28,
#  'downplayed': 9,
#  'significance': 10,
#  'onslaught': 17,
#  'arguing': 90,
#  'vast': 46,
#  'majority': 330,
#  'great': 157,
#  'u': 278,
#  'office': 537,
#  'owner': 24,
#  'administrator': 17,
#  'present': 72,
#  'complex': 20,
#  'buck': 13,
#  'bewley': 4,
#  'run': 258,
#  'repair': 6,
#  'shop': 19,
#  'near': 54,
#  'louisville': 5,
#  'soured': 5,
#  'massachusetts': 70,
#  'let': 150,
#  'visage': 5,
#  'rack': 6,
#  'get': 546,
#  'mad': 8,
#  'thing': 429,
#  'probably': 141,
#  'acknowledged': 64,
#  'outrage': 24,
#  'unintended': 3,
#  'consequence': 48,
#  'estranging': 2,
#  'put': 248,
#  'think': 725,
#  'ripple': 5,
#  'tate': 9,
#  'tony': 15,
#  'romm': 4,
#  'report': 382,
#  'wp': 450,
#  'llc': 452,
#  'jan': 148,
#  'presidential': 903,
#  'contender': 72,
#  'faced': 79,
#  'tuesday': 841,
#  'carolina': 342,
#  'final': 154,
#  'state': 2134,
#  'primary': 805,
#  'saturday': 222,
#  'super': 353,
#  'clear': 322,
#  'early': 338,
#  'stage': 193,
#  'winner': 54,
#  'loser': 13,
#  'performance': 134,
#  'spanning': 4,
#  'past': 393,
#  'strongest': 44,
#  'built': 65,
#  'bark': 6,
#  'mike': 287,
#  'bloomberg': 675,
#  'followed': 67,
#  'studied': 10,
#  'detailed': 31,
#  'picked': 26,
#  'left': 281,
#  'pointing': 31,
#  'lindsey': 34,
#  'graham': 89,
#  'scott': 74,
#  'brown': 39,
#  'mass': 48,
#  'defeated': 21,
#  'senate': 975,
#  'argued': 141,
#  'sufficiently': 8,
#  'addressed': 22,
#  'treatment': 21,
#  'went': 149,
#  'china': 56,
#  'perhaps': 84,
#  'forceful': 14,
#  'better': 193,
#  'staff': 218,
#  'dug': 2,
#  'trashed': 2,
#  'need': 390,
#  'dig': 11,
#  'hard': 131,
#  'actually': 87,
#  'wonder': 38,
#  'whether': 516,
#  'much': 480,
#  'especially': 124,
#  'given': 144,
#  'seem': 69,
#  'couple': 54,
#  'least': 216,
#  'remain': 95,
#  'radar': 7,
#  'list': 99,
#  'somewhat': 18,
#  'uneven': 4,
#  'night': 464,
#  'leading': 172,
#  'player': 32,
#  'march': 157,
#  'seemed': 128,
#  'continue': 160,
#  'good': 304,
#  'moment': 255,
#  'appeal': 152,
#  'noted': 91,
#  'secure': 59,
#  'funding': 29,
#  'charleston': 19,
#  'port': 3,
#  'talked': 39,
#  'gentrification': 1,
#  'heard': 111,
#  'detracted': 1,
#  'little': 251,
#  'repeatedly': 112,
#  'complaining': 8,
#  'getting': 157,
#  'enough': 235,
#  'blaming': 7,
#  'catholic': 32,
#  'upbringing': 5,
#  'obedience': 1,
#  'rule': 173,
#  'length': 10,
#  'answer': 110,
#  'eye': 54,
#  'asked': 365,
#  'press': 107,
#  'doe': 446,
#  'transparency': 24,
#  'kind': 159,
#  'unspoken': 1,
#  'bargain': 2,
#  'play': 148,
#  'go': 341,
#  'something': 212,
#  'ideal': 11,
#  'oh': 9,
#  'dollar': 79,
#  'pocket': 13,
#  'spend': 78,
#  'came': 309,
#  'closer': 52,
#  'spoken': 31,
#  'pitched': 5,
#  'record': 285,
#  'spent': 223,
#  'elect': 36,
#  'almost': 141,
#  'ad': 397,
#  'commercial': 23,
#  'break': 91,
#  'threatening': 24,
#  'represented': 31,
#  'attacked': 74,
#  'ineffective': 3,
#  'russia': 276,
#  'helping': 57,
#  'intelligence': 278,
#  'stated': 11,
#  'chaos': 41,
#  'spending': 247,
#  'versus': 23,
#  'donald': 268,
#  'tom': 90,
#  'steyer': 69,
#  'warned': 91,
#  'government': 333,
#  'sector': 6,
#  'mentioned': 39,
#  'shooting': 16,
#  'church': 56,
#  'voted': 146,
#  'brady': 4,
#  'bill': 155,
#  'five': 126,
#  'prompted': 44,
#  'acknowledge': 24,
#  'mistake': 35,
#  'ganged': 2,
#  'praising': 25,
#  'authoritarian': 8,
#  'socialist': 132,
#  'regime': 24,
#  'hearing': 102,
#  'bit': 46,
#  'indeed': 22,
#  'late': 175,
#  'affirmative': 3,
#  'electability': 72,
#  'front': 81,
#  'offered': 120,
#  'rebuttal': 15,
#  'downplaying': 4,
#  'complained': 32,
#  'wrong': 148,
#  'joke': 30,
#  'remember': 52,
#  'pressed': 23,
#  'trouble': 33,
#  'never': 265,
#  'thank': 16,
#  'released': 154,
#  'three': 439,
#  'nondisclosure': 2,
#  'forward': 105,
#  'moderator': 15,
#  'big': 270,
#  'problem': 193,
#  'complete': 28,
#  'talking': 113,
#  'enforcing': 1,
#  'playing': 61,
#  'loose': 8,
#  'mean': 208,
#  'allowed': 78,
#  'talk': 240,
#  'game': 89,
#  'speaking': 139,
#  'gaming': 10,
#  'booing': 1,
#  'cheering': 12,
#  'control': 139,
#  'reason': 141,
#  'prohibit': 6,
#  'outward': 1,
#  'dissent': 7,
#  'encourages': 1,
#  'stock': 44,
#  'camera': 35,
#  'yet': 218,
#  'know': 506,
#  'happened': 92,
#  'vocal': 26,
#  'found': 203,
#  'booed': 9,
#  'amount': 100,
#  'competing': 45,
#  'feb': 169,
#  'vowed': 25,
#  'billionaire': 143,
#  'bankroll': 3,
#  'secures': 1,
#  'hope': 228,
#  'chance': 204,
#  'beating': 39,
#  'wednesday': 306,
#  'la': 60,
#  'vega': 45,
#  'contradiction': 4,
#  'twisted': 1,
#  'set': 198,
#  'dominate': 12,
#  'six': 109,
#  'onstage': 41,
#  'blunt': 20,
#  'momentum': 93,
#  'track': 25,
#  'insurmountable': 6,
#  'lead': 255,
#  'delegate': 424,
#  'hunt': 35,
#  'giving': 95,
#  'pas': 44,
#  'launch': 42,
#  'undermine': 52,
#  'becomes': 52,
#  'risk': 134,
#  'backlash': 23,
#  'punished': 4,
#  'always': 168,
#  'reticence': 1,
#  'bad': 103,
#  'side': 251,
#  'someone': 150,
#  'tim': 64,
#  'miller': 17,
#  'advised': 21,
#  'florida': 215,
#  'governor': 124,
#  'jeb': 5,
#  'bush': 86,
#  'position': 204,
#  'gop': 324,
#  'looming': 16,
#  'skittish': 5,
#  'anything': 138,
#  'absolutely': 28,
#  'loathed': 4,
#  'incumbent': 69,
#  'result': 322,
#  'moving': 69,
#  'gingerly': 2,
#  'message': 283,
#  'swept': 13,
#  ...}

# %%
# create dataframe with word and frequency as col
# sort them by frequency
pd_bernie_tokens=pd.DataFrame(list(bernie_tokens_dict.items()), columns=['bernie_word', 'bernie_freq'])
pd_bernie_tokens=pd_bernie_tokens.sort_values(by="bernie_freq" , ascending=False).reset_index(drop=True)[:40]

pd_biden_tokens=pd.DataFrame(list(biden_tokens_dict.items()), columns=['biden_word', 'biden_freq'])
pd_biden_tokens=pd_biden_tokens.sort_values(by="biden_freq" , ascending=False).reset_index(drop=True)[:40]

pd_trump_tokens=pd.DataFrame(list(trump_tokens_dict.items()), columns=['trump_word', 'trump_freq'])
pd_trump_tokens=pd_trump_tokens.sort_values(by="trump_freq" , ascending=False).reset_index(drop=True)[:40]

# %%
# create dataframe with word and frequency as col _NYT
# sort them by frequency
pd_bernie_NYT_tokens=pd.DataFrame(list(bernie_NYT_tokens_dict.items()), columns=['bernie_NYT_word', 'bernie_NYT_freq'])
pd_bernie_NYT_tokens=pd_bernie_NYT_tokens.sort_values(by="bernie_NYT_freq" , ascending=False).reset_index(drop=True)[:40]

pd_biden_NYT_tokens=pd.DataFrame(list(biden_NYT_tokens_dict.items()), columns=['biden_NYT_word', 'biden_NYT_freq'])
pd_biden_NYT_tokens=pd_biden_NYT_tokens.sort_values(by="biden_NYT_freq" , ascending=False).reset_index(drop=True)[:40]

pd_trump_NYT_tokens=pd.DataFrame(list(trump_NYT_tokens_dict.items()), columns=['trump_NYT_word', 'trump_NYT_freq'])
pd_trump_NYT_tokens=pd_trump_NYT_tokens.sort_values(by="trump_NYT_freq" , ascending=False).reset_index(drop=True)[:40]

# %%
# create dataframe with word and frequency as col _TWP
# sort them by frequency
pd_bernie_TWP_tokens=pd.DataFrame(list(bernie_TWP_tokens_dict.items()), columns=['bernie_TWP_word', 'bernie_TWP_freq'])
pd_bernie_TWP_tokens=pd_bernie_TWP_tokens.sort_values(by="bernie_TWP_freq" , ascending=False).reset_index(drop=True)[:40]

pd_biden_TWP_tokens=pd.DataFrame(list(biden_TWP_tokens_dict.items()), columns=['biden_TWP_word', 'biden_TWP_freq'])
pd_biden_TWP_tokens=pd_biden_TWP_tokens.sort_values(by="biden_TWP_freq" , ascending=False).reset_index(drop=True)[:40]

pd_trump_TWP_tokens=pd.DataFrame(list(trump_TWP_tokens_dict.items()), columns=['trump_TWP_word', 'trump_TWP_freq'])
pd_trump_TWP_tokens=pd_trump_TWP_tokens.sort_values(by="trump_TWP_freq" , ascending=False).reset_index(drop=True)[:40]

# %%
# create dataframe with word and frequency as col _WSJ
# sort them by frequency
pd_bernie_WSJ_tokens=pd.DataFrame(list(bernie_WSJ_tokens_dict.items()), columns=['bernie_WSJ_word', 'bernie_WSJ_freq'])
pd_bernie_WSJ_tokens=pd_bernie_WSJ_tokens.sort_values(by="bernie_WSJ_freq" , ascending=False).reset_index(drop=True)[:40]

pd_biden_WSJ_tokens=pd.DataFrame(list(biden_WSJ_tokens_dict.items()), columns=['biden_WSJ_word', 'biden_WSJ_freq'])
pd_biden_WSJ_tokens=pd_biden_WSJ_tokens.sort_values(by="biden_WSJ_freq" , ascending=False).reset_index(drop=True)[:40]

pd_trump_WSJ_tokens=pd.DataFrame(list(trump_WSJ_tokens_dict.items()), columns=['trump_WSJ_word', 'trump_WSJ_freq'])
pd_trump_WSJ_tokens=pd_trump_WSJ_tokens.sort_values(by="trump_WSJ_freq" , ascending=False).reset_index(drop=True)[:40]

# %%
# create df with word frew as col for each news outlet

pd_NYT_tokens=pd.DataFrame(list(NYT_tokens_dict.items()), columns=['NYT_word', 'NYT_freq'])
pd_NYT_tokens=pd_NYT_tokens.sort_values(by="NYT_freq" , ascending=False).reset_index(drop=True)[:40]

pd_TWP_tokens=pd.DataFrame(list(TWP_tokens_dict.items()), columns=['TWP_word', 'TWP_freq'])
pd_TWP_tokens=pd_TWP_tokens.sort_values(by="TWP_freq" , ascending=False).reset_index(drop=True)[:40]

pd_WSJ_tokens=pd.DataFrame(list(WSJ_tokens_dict.items()), columns=['WSJ_word', 'WSJ_freq'])
pd_WSJ_tokens=pd_WSJ_tokens.sort_values(by="WSJ_freq" , ascending=False).reset_index(drop=True)[:40]

# %%
# create df to display top words for each candidate
candidate_word_freq = pd.concat([pd_bernie_tokens, pd_biden_tokens, pd_trump_tokens], axis=1)
candidate_word_freq.head(20)
# Out:
#    bernie_word  bernie_freq  biden_word  biden_freq   trump_word  trump_freq
# 0     campaign         2808    campaign        3178    president        5547
# 1   democratic         2661   president        3008        house        2475
# 2        state         2465       state        2457   republican        2003
# 3    candidate         2284  democratic        2193  impeachment        1774
# 4    president         2156       voter        2083     democrat        1715
# 5        voter         2045   candidate        1919     campaign        1672
# 6        party         1859    democrat        1717        state        1499
# 7     democrat         1740      former        1473       senate        1477
# 8         iowa         1422    election        1453        white        1407
# 9       former         1411        time        1339         time        1333
# 10     primary         1390     primary        1309     official        1246
# 11      warren         1373        iowa        1265     election        1203
# 12    election         1294       party        1265   democratic        1168
# 13        time         1284  republican        1148        trial        1145
# 14      bernie         1193        also        1145       former        1143
# 15      people         1167      people        1137       people        1121
# 16       could         1166     tuesday        1125         year        1077
# 17        also         1153      warren        1094         also        1071
# 18   bloomberg         1144        vote        1064      senator        1003
# 19     tuesday         1141       could        1054      ukraine         961

# %%
bernie_news = pd.concat([pd_bernie_NYT_tokens.head(20),
                        pd_bernie_TWP_tokens.head(20),pd_bernie_WSJ_tokens.head(20)], axis=1)
bernie_news
# Out:
#    bernie_NYT_word  bernie_NYT_freq bernie_TWP_word  bernie_TWP_freq  \
# 0         campaign             1134        campaign              974
# 1            state              949       candidate              826
# 2       democratic              901      democratic              798
# 3        candidate              861       president              780
# 4            voter              845           state              739
# 5        president              797           party              700
# 6             time              741        democrat              678
# 7             iowa              622           voter              609
# 8           warren              607          people              477
# 9          primary              580          warren              474
# 10        democrat              577            year              465
# 11          former              570          former              431
# 12           party              549            also              425
# 13         senator              535            iowa              394
# 14            york              532      republican              386
# 15       bloomberg              518           could              376
# 16       buttigieg              507             say              373
# 17          bernie              502       buttigieg              365
# 18            race              480        election              364
# 19         tuesday              452            vote              364
#
#    bernie_WSJ_word  bernie_WSJ_freq
# 0       democratic              962
# 1            state              777
# 2         campaign              700
# 3            party              610
# 4        candidate              597
# 5            voter              591
# 6        president              579
# 7          primary              488
# 8         election              487
# 9         democrat              485
# 10          bernie              414
# 11          former              410
# 12            iowa              406
# 13         tuesday              382
# 14           could              347
# 15            vote              342
# 16       bloomberg              330
# 17          caucus              323
# 18            year              320
# 19            also              317

# %%
biden_news = pd.concat([pd_biden_NYT_tokens.head(20),
                        pd_biden_TWP_tokens.head(20),pd_biden_WSJ_tokens.head(20)], axis=1)
biden_news
# Out:
#    biden_NYT_word  biden_NYT_freq biden_TWP_word  biden_TWP_freq  \
# 0        campaign            1190       campaign            1137
# 1       president            1046      president            1107
# 2           voter             907          state             862
# 3           state             890      candidate             727
# 4      democratic             766     democratic             716
# 5            time             744       democrat             683
# 6       candidate             735          voter             668
# 7         senator             580       election             613
# 8         primary             544         former             540
# 9        democrat             536          party             521
# 10         former             525          house             500
# 11         warren             522     republican             486
# 12           iowa             492           also             441
# 13           york             474           year             435
# 14           like             428         people             435
# 15         people             424           vote             413
# 16          could             414         warren             405
# 17           race             412           time             402
# 18           also             407          could             386
# 19        tuesday             404           iowa             384
#
#    biden_WSJ_word  biden_WSJ_freq
# 0       president             855
# 1        campaign             851
# 2      democratic             711
# 3           state             705
# 4           voter             508
# 5        democrat             498
# 6        election             482
# 7       candidate             457
# 8          former             408
# 9         primary             397
# 10           iowa             389
# 11          party             378
# 12     republican             358
# 13    impeachment             351
# 14          house             348
# 15        tuesday             339
# 16   presidential             309
# 17           also             297
# 18           vote             286
# 19            joe             283

# %%
trump_news = pd.concat([pd_trump_NYT_tokens.head(20),
                        pd_trump_TWP_tokens.head(20),pd_trump_WSJ_tokens.head(20)], axis=1)
trump_news
# Out:
#    trump_NYT_word  trump_NYT_freq trump_TWP_word  trump_TWP_freq  \
# 0       president            2143      president            1916
# 1      republican             870          house             868
# 2           house             834     republican             591
# 3            time             730       campaign             585
# 4     impeachment             595       official             582
# 5        campaign             590          white             559
# 6        democrat             570       democrat             553
# 7           state             562          state             533
# 8         senator             524         senate             506
# 9            york             492    impeachment             493
# 10         senate             471         people             470
# 11          white             455         former             460
# 12       american             409           year             448
# 13         former             391       election             445
# 14          trial             385           time             395
# 15         people             383           also             389
# 16      political             381      political             363
# 17       election             372     democratic             356
# 18     democratic             368     washington             354
# 19       official             360          trial             344
#
#    trump_WSJ_word  trump_WSJ_freq
# 0       president            1488
# 1           house             773
# 2     impeachment             686
# 3        democrat             592
# 4      republican             542
# 5          senate             500
# 6        campaign             497
# 7      democratic             444
# 8           trial             416
# 9           state             404
# 10          white             393
# 11       election             386
# 12           also             352
# 13        ukraine             304
# 14       official             304
# 15         former             292
# 16           year             289
# 17         people             268
# 18      bloomberg             268
# 19        witness             261

# %%
# create df to display top words for each news outlet
news_word_freq = pd.concat([pd_NYT_tokens, pd_TWP_tokens, pd_WSJ_tokens], axis=1)
news_word_freq.head(20)
# Out:
#       NYT_word  NYT_freq    TWP_word  TWP_freq     WSJ_word  WSJ_freq
# 0    president      3986   president      3803    president      2922
# 1     campaign      2914    campaign      2696   democratic      2117
# 2        state      2401       state      2134     campaign      2048
# 3         time      2215    democrat      1914        state      1886
# 4   democratic      2035  democratic      1870     democrat      1575
# 5        voter      2014   candidate      1774     election      1355
# 6    candidate      1801       house      1663        voter      1320
# 7     democrat      1683       voter      1588        house      1295
# 8      senator      1639       party      1549    candidate      1242
# 9         york      1498  republican      1463        party      1233
# 10      former      1486      former      1431   republican      1162
# 11  republican      1423    election      1422  impeachment      1112
# 12     primary      1258      people      1382       former      1110
# 13        iowa      1227        year      1348      primary       985
# 14       party      1224        also      1255         iowa       984
# 15       house      1214        time      1150         also       966
# 16      people      1206       white      1074      tuesday       914
# 17      warren      1181        vote      1062         vote       888
# 18    election      1173       could      1053    bloomberg       873
# 19       could      1161    official       995       senate       839

# %%
# find words that are only associated with each candidate
# trying to see if there is jargon or topics associated with certain candidates

bernie_only = {}
for key in bernie_tokens_dict.keys():
    if key not in biden_tokens_dict.keys():
        if key not in trump_tokens_dict.keys():
            bernie_only[key] = bernie_tokens_dict[key]

biden_only = {}
for key in biden_tokens_dict.keys():
    if key not in bernie_tokens_dict.keys():
        if key not in trump_tokens_dict.keys():
            biden_only[key] = biden_tokens_dict[key]
            
trump_only = {}
for key in trump_tokens_dict.keys():
    if key not in biden_tokens_dict.keys():
        if key not in bernie_tokens_dict.keys():
            trump_only[key] = trump_tokens_dict[key]

# %%
# create dataframe with word and frequency as col
# sort them by frequency
pd_bernie_only=pd.DataFrame(list(bernie_only.items()), columns=['bernie_word_only', 'freq'])
pd_bernie_only=pd_bernie_only.sort_values(by="freq" , ascending=False).reset_index(drop=True)[:40]

pd_biden_only=pd.DataFrame(list(biden_only.items()), columns=['biden_word_only', 'freq'])
pd_biden_only=pd_biden_only.sort_values(by="freq" , ascending=False).reset_index(drop=True)[:40]

pd_trump_only=pd.DataFrame(list(trump_only.items()), columns=['trump_word_only', 'freq'])
pd_trump_only=pd_trump_only.sort_values(by="freq" , ascending=False).reset_index(drop=True)[:40]

# %%
# these are all garbage words
only_candidates = pd.concat([pd_bernie_only, pd_biden_only, pd_trump_only],axis=1)
only_candidates.head()
# Out:
#   bernie_word_only  freq biden_word_only  freq trump_word_only  freq
# 0             flav    57           navin    26            modi   109
# 1            uygur    26           amana    20       klitschko    50
# 2          gadsden    25          jotzke    18        clemency    44
# 3           wilkie    24          zuberi    17        abinader    32
# 4            mfume    20          torner    17         richter    29

# %%
# find words that are only associated with each NEWS OUTLET
# trying to see if there is jargon or topics associated with certain NEWS OUTLETS

bernie_NYT_only = {}
for key in bernie_NYT_tokens_dict.keys():
    if key not in bernie_TWP_tokens_dict.keys():
        if key not in bernie_WSJ_tokens_dict.keys():
            bernie_NYT_only[key] = bernie_NYT_tokens_dict[key]
bernie_TWP_only = {}
for key in bernie_TWP_tokens_dict.keys():
    if key not in bernie_NYT_tokens_dict.keys():
        if key not in bernie_WSJ_tokens_dict.keys():
            bernie_TWP_only[key] = bernie_TWP_tokens_dict[key]
bernie_WSJ_only = {}
for key in bernie_WSJ_tokens_dict.keys():
    if key not in bernie_TWP_tokens_dict.keys():
        if key not in bernie_NYT_tokens_dict.keys():
            bernie_WSJ_only[key] = bernie_WSJ_tokens_dict[key]

#BIDEN
biden_NYT_only = {}
for key in biden_NYT_tokens_dict.keys():
    if key not in biden_TWP_tokens_dict.keys():
        if key not in biden_WSJ_tokens_dict.keys():
            biden_NYT_only[key] = biden_NYT_tokens_dict[key]
biden_TWP_only = {}
for key in biden_TWP_tokens_dict.keys():
    if key not in biden_NYT_tokens_dict.keys():
        if key not in biden_WSJ_tokens_dict.keys():
            biden_TWP_only[key] = biden_TWP_tokens_dict[key]
biden_WSJ_only = {}
for key in biden_WSJ_tokens_dict.keys():
    if key not in biden_TWP_tokens_dict.keys():
        if key not in biden_NYT_tokens_dict.keys():
            biden_WSJ_only[key] = biden_WSJ_tokens_dict[key]
            

#TRUMP
trump_NYT_only = {}
for key in trump_NYT_tokens_dict.keys():
    if key not in trump_TWP_tokens_dict.keys():
        if key not in trump_WSJ_tokens_dict.keys():
            trump_NYT_only[key] = trump_NYT_tokens_dict[key]
trump_TWP_only = {}
for key in trump_TWP_tokens_dict.keys():
    if key not in trump_NYT_tokens_dict.keys():
        if key not in trump_WSJ_tokens_dict.keys():
            trump_TWP_only[key] = trump_TWP_tokens_dict[key]
trump_WSJ_only = {}
for key in trump_WSJ_tokens_dict.keys():
    if key not in trump_TWP_tokens_dict.keys():
        if key not in trump_NYT_tokens_dict.keys():
            trump_WSJ_only[key] = trump_WSJ_tokens_dict[key]

# %%
#create df for each news 'only' words for each candidate
pd_bernie_NYT_only=pd.DataFrame(list(bernie_NYT_only.items()), columns=['bernie_NYT_word_only', 'freq'])
pd_bernie_NYT_only=pd_bernie_NYT_only.sort_values(by="freq" , ascending=False).reset_index(drop=True)[:40]

pd_bernie_TWP_only=pd.DataFrame(list(bernie_TWP_only.items()), columns=['bernie_TWP_word_only', 'freq'])
pd_bernie_TWP_only=pd_bernie_TWP_only.sort_values(by="freq" , ascending=False).reset_index(drop=True)[:40]

pd_bernie_WSJ_only=pd.DataFrame(list(bernie_WSJ_only.items()), columns=['bernie_WSJ_word_only', 'freq'])
pd_bernie_WSJ_only=pd_bernie_WSJ_only.sort_values(by="freq" , ascending=False).reset_index(drop=True)[:40]

# %%
bernie_news_only = pd.concat([pd_bernie_NYT_only, pd_bernie_TWP_only,pd_bernie_WSJ_only], axis=1)
bernie_news_only.head()
# Out:
#   bernie_NYT_word_only  freq bernie_TWP_word_only  freq bernie_WSJ_word_only  \
# 0           photograph   180                   wp   150                eliza
# 1                 erin    34               dawson    51                 flav
# 2               hitthe    33             mcdowell    31              sabrina
# 3              grenell    28         evangelicals    30             jamerson
# 4                ember    27            tzintzãºn    28             siddiqui
#
#    freq
# 0    72
# 1    57
# 2    36
# 3    34
# 4    34

# %%
# biden
pd_biden_NYT_only=pd.DataFrame(list(biden_NYT_only.items()), columns=['biden_NYT_word_only', 'freq'])
pd_biden_NYT_only=pd_biden_NYT_only.sort_values(by="freq" , ascending=False).reset_index(drop=True)[:40]

pd_biden_TWP_only=pd.DataFrame(list(biden_TWP_only.items()), columns=['biden_TWP_word_only', 'freq'])
pd_biden_TWP_only=pd_biden_TWP_only.sort_values(by="freq" , ascending=False).reset_index(drop=True)[:40]

pd_biden_WSJ_only=pd.DataFrame(list(biden_WSJ_only.items()), columns=['biden_WSJ_word_only', 'freq'])
pd_biden_WSJ_only=pd_biden_WSJ_only.sort_values(by="freq" , ascending=False).reset_index(drop=True)[:40]

# %%
biden_news_only = pd.concat([pd_biden_NYT_only, pd_biden_TWP_only,pd_biden_WSJ_only], axis=1)
biden_news_only.head()
# Out:
#   biden_NYT_word_only  freq biden_TWP_word_only  freq biden_WSJ_word_only  \
# 0              hitthe    29                  wp   150               eliza
# 1              glover    25             firtash    63            siddiqui
# 2              glueck    24               doocy    33             sabrina
# 3          onpolitics    21            mcdowell    31               parti
# 4                paso    20               navin    26              tarini
#
#    freq
# 0    48
# 1    41
# 2    41
# 3    38
# 4    38

# %%
# biden
pd_trump_NYT_only=pd.DataFrame(list(trump_NYT_only.items()), columns=['trump_NYT_word_only', 'freq'])
pd_trump_NYT_only=pd_trump_NYT_only.sort_values(by="freq" , ascending=False).reset_index(drop=True)[:40]

pd_trump_TWP_only=pd.DataFrame(list(trump_TWP_only.items()), columns=['trump_TWP_word_only', 'freq'])
pd_trump_TWP_only=pd_trump_TWP_only.sort_values(by="freq" , ascending=False).reset_index(drop=True)[:40]

pd_trump_WSJ_only=pd.DataFrame(list(trump_WSJ_only.items()), columns=['trump_WSJ_word_only', 'freq'])
pd_trump_WSJ_only=pd_trump_WSJ_only.sort_values(by="freq" , ascending=False).reset_index(drop=True)[:40]

# %%
trump_news_only = pd.concat([pd_trump_NYT_only, pd_trump_TWP_only,pd_trump_WSJ_only], axis=1)
trump_news_only.head()
# Out:
#   trump_NYT_word_only  freq trump_TWP_word_only  freq trump_WSJ_word_only  \
# 0           suleimani    61                  wp   150            ballhaus
# 1              hitthe    41           klitschko    50               lucey
# 2                erin    35            abinader    32           restuccia
# 3             richter    29             assange    22             lindsay
# 4                anna    28           dominican    20               leary
#
#    freq
# 0    60
# 1    55
# 2    29
# 3    27
# 4    26

# %%
# find words that are only associated with each news outlet
# trying to see if there is jargon or topics associated with certain news outlet

NYT_only = {}
for key in NYT_tokens_dict.keys():
    if key not in WSJ_tokens_dict.keys():
        if key not in TWP_tokens_dict.keys():
            NYT_only[key] = NYT_tokens_dict[key]

TWP_only = {}
for key in TWP_tokens_dict.keys():
    if key not in NYT_tokens_dict.keys():
        if key not in WSJ_tokens_dict.keys():
            TWP_only[key] = TWP_tokens_dict[key]
            
WSJ_only = {}
for key in WSJ_tokens_dict.keys():
    if key not in TWP_tokens_dict.keys():
        if key not in NYT_tokens_dict.keys():
            WSJ_only[key] = WSJ_tokens_dict[key]

# %%
# biden
pd_NYT_only=pd.DataFrame(list(NYT_only.items()), columns=['NYT_word_only', 'freq'])
pd_NYT_only=pd_NYT_only.sort_values(by="freq" , ascending=False).reset_index(drop=True)[:40]

pd_TWP_only=pd.DataFrame(list(TWP_only.items()), columns=['TWP_word_only', 'freq'])
pd_TWP_only=pd_TWP_only.sort_values(by="freq" , ascending=False).reset_index(drop=True)[:40]

pd_WSJ_only=pd.DataFrame(list(WSJ_only.items()), columns=['WSJ_word_only', 'freq'])
pd_WSJ_only=pd_WSJ_only.sort_values(by="freq" , ascending=False).reset_index(drop=True)[:40]

# %%
news_only = pd.concat([pd_NYT_only, pd_TWP_only, pd_WSJ_only],axis=1)
news_only
# Out:
#                         NYT_word_only  freq TWP_word_only  freq  \
# 0                              hitthe   103            wp   450
# 1                           suleimani    90       firtash    65
# 2                               ember    49      mcdowell    62
# 3                              glueck    43        dawson    52
# 4                            haberman    37     klitschko    50
# 5                              qassim    36         doocy    34
# 6                              sydney    32      abinader    32
# 7                             richter    29     tzintzãºn    29
# 8                          onpolitics    29        wagner    27
# 9                          corasaniti    29         navin    26
# 10  highlightingabstracttranslateundo    27       gadsden    25
# 11                            allfull    27          kane    25
# 12                               gale    25         evans    25
# 13                             kalifa    24        wilkie    24
# 14                              tamir    24     reelected    23
# 15                           cochrane    23       costume    22
# 16                        fitzpatrick    22      brambila    22
# 17                              hitmr    20       assange    22
# 18                               hita    20      itkowitz    22
# 19                       hitpresident    20         cleve    20
# 20                             astead    20       wootson    20
# 21                              lerer    20         amana    20
# 22                              hitas    19         mfume    20
# 23                  photographsenator    19     dominican    20
# 24                            shelton    19       cottage    19
# 25                             meehan    18       debonis    19
# 26                              shear    18        jotzke    18
# 27                            hitwith    18        ritter    18
# 28                             tamayo    17        sonmez    18
# 29                       stranglehold    17          rome    17
# 30                        kirkpatrick    17        torner    17
# 31                             fandos    17       clement    17
# 32                              hitin    17         viser    17
# 33                          chooljian    16           dni    16
# 34                              chang    16         janes    16
# 35                           wildwood    14         luntz    14
# 36                              karni    14       ousting    14
# 37                          hitbernie    14    stereotype    13
# 38                          brittainy    14     classmate    12
# 39                            dvorsky    13    bloodworth    12
#
#         WSJ_word_only  freq
# 0               eliza   139
# 1                 wsj    90
# 2               lucey    88
# 3             sabrina    88
# 4            siddiqui    86
# 5            ballhaus    86
# 6               parti    80
# 7              tarini    80
# 8            jamerson    76
# 9                flav    57
# 10             glazer    50
# 11              leary    50
# 12              alexa    38
# 13              corse    38
# 14            tracker    37
# 15          restuccia    35
# 16             bender    34
# 17          predictit    30
# 18               volz    29
# 19             dustin    29
# 20             zitner    28
# 21          mcinturff    27
# 22          mccormack    21
# 23            duehren    19
# 24             bostic    18
# 25             forgey    18
# 26             zuberi    17
# 27          bauerlein    16
# 28                tau    16
# 29              arian    16
# 30            cassino    15
# 31            horwitt    14
# 32             zaucha    14
# 33             broten    14
# 34                gdp    13
# 35            mcadams    12
# 36             kibbel    12
# 37  antiestablishment    12
# 38            szuggar    12
# 39        wsjpolitics    12
